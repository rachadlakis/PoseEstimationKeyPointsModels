# %%
import tensorflow as tf
import tensorflow_hub as hub

import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import zipfile
import sys
import random
import os
from PIL import Image
import pickle#to save the weights of the model
import time
import shutil #to create a zip file

from tensorflow.keras.applications import VGG19, ResNet50, MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import Model, Input 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.image import resize_with_crop_or_pad
from tensorflow import cast, expand_dims, int32, convert_to_tensor, float32
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.preprocessing.image import load_img
# from tensorflow.keras.applications.vgg19 import preprocess_input as vgg19_preprocess #preprocess the images before passing to the model to be as eeach model expects
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet50_preprocess
# from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mobilenet_preprocess #rescale images from [0,255] to [-1,1]
from tensorflow.keras import metrics 
from tensorflow.io import read_file
from tensorflow.compat.v1.image import decode_jpeg
from numpy import squeeze
from tensorflow.keras.models import load_model
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
#### Determine fixed variables for model

(img_width, img_height) = (224,224) 
batch_size = 64 # small batch size because the datasset in small

# %%
#Load the model from TF hub
pose_model = hub.load('https://tfhub.dev/google/movenet/singlepose/thunder/4') #Thunder is the more accurate version but also larger and slower than Lightning
movenet = pose_model.signatures['serving_default']

# %%
def print_parameters_count(model_):
    import tensorflow.keras.backend as K
    trainable_count = np.sum([K.count_params(w) for w in model_.trainable_weights])
    non_trainable_count = np.sum([K.count_params(w) for w in model_.non_trainable_weights])

    print('Total params: {:,}'.format(trainable_count + non_trainable_count))
    print('Trainable params: {:,}'.format(trainable_count))
    print('Non-trainable params: {:,}'.format(non_trainable_count))

def draw_keypoints(image, keypoints, confidence_threshold):
    # Get the height, width, and channels of the input image
    height, width, channels = image.shape
    # Scale the keypoints to match the size of the input image
    _shaped_keypoints = np.squeeze(np.multiply(keypoints, [height,width,1]))
    
    for kp in _shaped_keypoints:
        ky, kx, kp_conf = kp
        if kp_conf > confidence_threshold:
            cv2.circle(image, (int(kx), int(ky)), 4, (0,255,0), -1)


EDGES = {
    (0, 1): 'm',    (0, 2): 'c',    (1, 3): 'm',    (2, 4): 'c',
    (0, 5): 'm',    (0, 6): 'c',    (5, 7): 'm',    (7, 9): 'm',
    (6, 8): 'c',    (8, 10): 'c',    (5, 6): 'y',    (5, 11): 'm',
    (6, 12): 'c',    (11, 12): 'y',    (11, 13): 'm',    (13, 15): 'm',
    (12, 14): 'c',    (14, 16): 'c'}

def draw_connections(image, keypoints, edges, confidence_threshold):
    # Get the height, width, and channels of the input image
    height,  width, c = image.shape
    # Scale the keypoints to match the size of the input image
    _shaped_keypoints = np.squeeze(np.multiply(keypoints, [height, width,1]))
    
    for edge, color in edges.items():
        p1, p2 = edge
        y1, x1, c1 = _shaped_keypoints[p1]
        y2, x2, c2 = _shaped_keypoints[p2]
        
        if (c1 > confidence_threshold) & (c2 > confidence_threshold):      
            cv2.line(image, (int(x1), int(y1)), (int(x2), int(y2)), (0,0,255), 2)


def print_performance_report(model, test_generator):
    """takes as input a model and DirectoryIterator
    and prints the classification report and the Confusion matrix"""
    y_pred = model.predict(test_generator)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = test_generator.classes
    class_labels=list(test_generator.class_indices.keys())

    print("Classification Report:\n", classification_report(y_true, y_pred_classes, target_names=class_labels))
    print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred_classes))

def get_size(model_path):
        # Get the size of the saved model file in MB
    file_size = os.path.getsize(model_path) / (1024 * 1024)
    return file_size
def delete_files_inside(folder):
    for file in os.listdir(folder):
        os.remove(os.path.join(folder,file)) 

    #Confusion_matrix
def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions>0.5 )
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('Adults Detected (True Negatives): ', cm[0][0])
    print('Child Incorrectly Detected (False Positives): ', cm[0][1])
    print('Child Missed (False Negatives): ', cm[1][0])
    print('Child Detected (True Positives): ', cm[1][1])
    
    
def zip_delete(model_name, path):
    """makes a ziped folder of all the results
    and deleted all the initial folder to make it easier to load the data in /kaggle/working"""
    shutil.make_archive(model_name, 'zip', path)
    delete_files_inside(path)
    os.rmdir(path)
    
def delete_folder_contents(folder_path):
    for root, dirs, files in os.walk(folder_path, topdown=False):
        for file in files:
            os.remove(os.path.join(root, file))
        for dir in dirs:
            os.rmdir(os.path.join(root, dir))
    os.rmdir(folder_path)
    

def plot_save_results(model_, model_name, fine_tuning,with_keypoints, num_epcohs, batch_size, history, save=True, loaded=False):
    #create folder for this model

    dir_name = model_name
    model_detailed_name = f"{model_name}__{with_keypoints}__{fine_tuning}__{num_epcohs}epcohs__{batch_size}batch"
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    mpl.rcParams['figure.figsize'] = (12, 10)
    
    if loaded:
        epochs = range(1, len(history['loss'])+1)
        history_dict = history
    else:
        epochs = range(1, len(history.history['loss'])+1)
        history_dict = history.history
    metrics = [ 'loss','accuracy',  'precision', 'recall','prc', 'auc', 'tp', 'fp', 'tn', 'fn',]
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(len(metrics)//2,2,n +1)
        plt.plot(epochs, history_dict[metric], color=colors[0], label='Train')
        plt.plot(epochs, history_dict['val_'+metric],
                 color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.8,1.1])
        elif metric=='tp' or metric=='fp' or metric=='tn' or metric=='fn':
            plt.ylim([1,np.max(history_dict[metric]) *  1.1 ])
        else:
            plt.ylim([0,1.1])
        
        plt.legend()
    if save:    
        plt.savefig(f"{dir_name}/{model_detailed_name}_{metric}.png")
        # Save the entire model to a file
        model_.save(f"{dir_name}/{model_detailed_name}.h5")

        # Save history to a file
        with open(f"{dir_name}/history_{model_detailed_name}.pickle", "wb") as f:
            pickle.dump(history.history, f)

# %%
# def create_base_VGG19():
#     return VGG19(weights='imagenet',input_shape=(224, 224, 3),include_top=False)
def create_base_ResNet():
    return  ResNet50(weights='imagenet', input_shape=(224, 224, 3),include_top=False)
# def create_base_MobileNetV2():
#     return  MobileNetV2(weights='imagenet', input_shape=(224, 224,3),  include_top=False)

# %%
# Define a preprocessing function to be applied to each image
def preprocess_image_add_pose_keypoints(image_, pose_model=movenet, image_output_shape=(224,224), confidence_threshold=0.15, circle_thickness=3, line_thickness=2 ):
    #check if image is corrupted
    """The function reads a PIL image, converts to numpy array, resize to be able to be processed by the pose model,
    then the pose estimation keypoints are added, then reshaped as the NN model expects.
    source of image transformations: https://tfhub.dev/google/movenet/singlepose/lightning/4"""
#     image_ = cast(resize_with_crop_or_pad(expand_dims(image_, axis=0), 256, 256), dtype=int32)
    image_ = tf.convert_to_tensor(image_, dtype=tf.float32)

    image_ = tf.expand_dims(image_, axis=0)
    # Resize and pad the image to keep the aspect ratio and fit the expected size.
    image_ = tf.cast(tf.image.resize_with_crop_or_pad(image_, 256, 256), dtype=tf.int32)
    if image_.shape[1] != 256 or image_.shape[2] != 256:
        return None
    outputs = pose_model(image_)
    # Reshape the image from (1, 256, 256, 3) to (256, 256, 3) and return an nd-array
    image_ = np.squeeze(image_)
    # Output is a [1, 1, 17, 3] tensor. to numpy array then take the points and reshape
    keypoints_with_scores = outputs['output_0'].numpy()[0,0,:,:51].reshape((17,3))
    #transform to numpy array to add the points and lines since tensorflow does not do that easily
    (height,width) = (image_.shape[0],image_.shape[1])
    #multiply x by height, y by weight (and score by 1)to get the real position on the image
    shaped_keypoints =  np.multiply(keypoints_with_scores, [height,width,1])     
    #########################################################################################################3
    for kp in shaped_keypoints:
        ky, kx, kp_conf = kp
        #print(kp)
        if kp_conf > confidence_threshold:
            cv2.circle(image_, (int(kx), int(ky)), 2, (0,0,0), 3)
    #draw_keypoints(image_array, outputs, confidence_threshold=0.3)
    for edge, color in EDGES.items():
        p1, p2 = edge
        y1, x1, c1 = shaped_keypoints[p1]
        y2, x2, c2 = shaped_keypoints[p2]
        if (c1 > confidence_threshold) & (c2 > confidence_threshold):      
            cv2.line(image_, (int(x1), int(y1)), (int(x2), int(y2)), (0,0,0), 2)
 
    #Resize iamge to fit the model of training
    #should change the output shape of the ouput to be fit to the pretrained mode
    image_ = image_.astype(np.float32)#image does not change
    #When the image is of type float, plt expects it to be in rannge[0,1]
    #ImageDataGenerator class expects a NumPy array as input,
    image_  = cv2.resize(image_,dsize=(image_output_shape[0], image_output_shape[1]))
#     tensor = tf.convert_to_tensor(x_np)

    return image_

# %%
path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/test/Adult/ch1_NVR_ch1_main_20220820210000_20220820220000.mp4_000698bf-a7f8-4572-be6d-6e39b5ee8195.jpg'
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread(path)

# Display the original image
plt.imshow(img)
plt.show()

# Apply the preprocess function
processed_img = preprocess_image_add_pose_keypoints(img)

# Display the processed image
plt.imshow(processed_img/255)
plt.show()

# %%
train_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/train'
validation_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/val'
test_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/test'

############################################################################################################################################
# Create a data generator to load and augment the training data
#Removed rescale from Image data generators, since Using pre
train_datagen_without_preprocessing = ImageDataGenerator(  
    #rescale=1.0/255,  #If using the pre processing fn of the pre trainde models, no need to rescale, and should add featurewise_center=False if so.
    featurewise_center=False, # if using the pre processing of the pre trained models, no need to make featurewise center, and if not false, should fit it before use
    rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest'
)

train_generator_without_preprocessing = train_datagen_without_preprocessing.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False)
# Create a data generator to load the validation data
val_datagen_without_preprocessing = ImageDataGenerator( featurewise_center=False)

val_generator_without_preprocessing = val_datagen_without_preprocessing.flow_from_directory(
    validation_path,
    target_size= (img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
shuffle=False)

#######################################################################################################################################
# Create a data generator to accept the trainign data with the preprocessing function
train_datagen_with_preprocessing = ImageDataGenerator(
    featurewise_center=False,
     rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest',  # fill any missing pixels with the nearest value
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet,
                                                                         image_output_shape=(img_width, img_height),
                                                                         confidence_threshold= 0.05)
)

train_generator_with_preprocessing = train_datagen_with_preprocessing.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)


# Create a data generator to load the validation data with the preprocessing function
val_datagen_with_preprocessing = ImageDataGenerator( 
    featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold=0.05)
)

val_generator_with_preprocessing = val_datagen_with_preprocessing.flow_from_directory(
    validation_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

#######################################################################################################################################
test_datagen_without_preprocessing = ImageDataGenerator( featurewise_center=False,)

#Load the training data
test_generator_without_preprocessing = test_datagen_without_preprocessing.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
###################################
# Create a data generator to accept the trainign data with the preprocessing function
test_datagen_with_preprocessing = ImageDataGenerator( featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold= 0.05)
)

# Load the training data
test_generator_with_preprocessing = test_datagen_with_preprocessing.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 5642 images belonging to 2 classes.
# Found 720 images belonging to 2 classes.
# Found 5642 images belonging to 2 classes.
# Found 720 images belonging to 2 classes.
# Found 674 images belonging to 2 classes.
# Found 674 images belonging to 2 classes.

# %% [markdown]
# # First Approach

# %% [markdown]
# ## Without Pose Estimation key points

# %% [markdown]
# ### Train before Tune

# %%
train_generator = train_generator_without_preprocessing
val_generator = val_generator_without_preprocessing
test_generator = test_generator_without_preprocessing
preprocess_fn = resnet50_preprocess

neurons_final = 1024
base_model = create_base_ResNet()
fine_tune_limit = len(base_model.layers) - int(0.1*len(base_model.layers))
model_name= 'RESNet-50'
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_30 = 30
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################

base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Done
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_5   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_5 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_5   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_10 (Dropout)        (None, 2048)              0
#
#  dense_10 (Dense)            (None, 1024)              2098176
#
#  dropout_11 (Dropout)        (None, 1024)              0
#
#  dense_11 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 25,686,913
# Trainable params: 2,099,201
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Model Summary:  None

# %%
counter = Counter(train_generator.classes)
print(str(counter.items())+"\n") # dict_items([(0, 1648), (1, 3614)])
Adult = 3997
Child = 1645
total = Adult + Child
weight_for_Adult =   (total / Adult) 
weight_for_Child =   (total /Child)
weight_for_Adult /= (weight_for_Adult +  weight_for_Child)
weight_for_Child /= (weight_for_Adult +  weight_for_Child)

class_weight = {0: weight_for_Adult, 1: weight_for_Child}
print('Class Weights: ', class_weight)

METRICS = [
      metrics.TruePositives(name='tp'),
      metrics.FalsePositives(name='fp'),
      metrics.TrueNegatives(name='tn'),
      metrics.FalseNegatives(name='fn'), 
      metrics.BinaryAccuracy(name='accuracy'),
      metrics.Precision(name='precision'),
      metrics.Recall(name='recall'),
      metrics.AUC(name='auc'),
      metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]
# Out:
# dict_items([(0, 3997), (1, 1645)])
#
# Class Weights:  {0: 0.2915632754342432, 1: 0.9216512191765469}

# %%
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS)

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################
# Out:
# Training Started
#
# Epoch 1/10
# 88/88 [==============================] - 122s 1s/step - loss: 0.3109 - tp: 1412.0000 - fp: 599.0000 - tn: 3334.0000 - fn: 233.0000 - accuracy: 0.8508 - precision: 0.7021 - recall: 0.8584 - auc: 0.9104 - prc: 0.7788 - val_loss: 0.1469 - val_tp: 179.0000 - val_fp: 25.0000 - val_tn: 492.0000 - val_fn: 8.0000 - val_accuracy: 0.9531 - val_precision: 0.8775 - val_recall: 0.9572 - val_auc: 0.9868 - val_prc: 0.9726 - lr: 0.0010
# Epoch 2/10
# 88/88 [==============================] - 80s 909ms/step - loss: 0.0919 - tp: 1512.0000 - fp: 342.0000 - tn: 3591.0000 - fn: 133.0000 - accuracy: 0.9148 - precision: 0.8155 - recall: 0.9191 - auc: 0.9763 - prc: 0.9605 - val_loss: 0.1239 - val_tp: 180.0000 - val_fp: 25.0000 - val_tn: 492.0000 - val_fn: 7.0000 - val_accuracy: 0.9545 - val_precision: 0.8780 - val_recall: 0.9626 - val_auc: 0.9942 - val_prc: 0.9859 - lr: 0.0010
# Epoch 3/10
# 88/88 [==============================] - 80s 911ms/step - loss: 0.0694 - tp: 1548.0000 - fp: 281.0000 - tn: 3652.0000 - fn: 97.0000 - accuracy: 0.9322 - precision: 0.8464 - recall: 0.9410 - auc: 0.9868 - prc: 0.9746 - val_loss: 0.0917 - val_tp: 154.0000 - val_fp: 2.0000 - val_tn: 515.0000 - val_fn: 33.0000 - val_accuracy: 0.9503 - val_precision: 0.9872 - val_recall: 0.8235 - val_auc: 0.9951 - val_prc: 0.9876 - lr: 0.0010
# Epoch 4/10
# 88/88 [==============================] - 80s 904ms/step - loss: 0.0541 - tp: 1565.0000 - fp: 211.0000 - tn: 3722.0000 - fn: 80.0000 - accuracy: 0.9478 - precision: 0.8812 - recall: 0.9514 - auc: 0.9920 - prc: 0.9840 - val_loss: 0.0774 - val_tp: 180.0000 - val_fp: 11.0000 - val_tn: 506.0000 - val_fn: 7.0000 - val_accuracy: 0.9744 - val_precision: 0.9424 - val_recall: 0.9626 - val_auc: 0.9968 - val_prc: 0.9913 - lr: 0.0010
# Epoch 5/10
# 88/88 [==============================] - 79s 892ms/step - loss: 0.0550 - tp: 1569.0000 - fp: 231.0000 - tn: 3702.0000 - fn: 76.0000 - accuracy: 0.9450 - precision: 0.8717 - recall: 0.9538 - auc: 0.9917 - prc: 0.9832 - val_loss: 0.0847 - val_tp: 184.0000 - val_fp: 21.0000 - val_tn: 496.0000 - val_fn: 3.0000 - val_accuracy: 0.9659 - val_precision: 0.8976 - val_recall: 0.9840 - val_auc: 0.9971 - val_prc: 0.9924 - lr: 0.0010
# Epoch 6/10
# 88/88 [==============================] - 81s 914ms/step - loss: 0.0490 - tp: 1583.0000 - fp: 186.0000 - tn: 3747.0000 - fn: 62.0000 - accuracy: 0.9555 - precision: 0.8949 - recall: 0.9623 - auc: 0.9934 - prc: 0.9861 - val_loss: 0.0801 - val_tp: 182.0000 - val_fp: 16.0000 - val_tn: 501.0000 - val_fn: 5.0000 - val_accuracy: 0.9702 - val_precision: 0.9192 - val_recall: 0.9733 - val_auc: 0.9977 - val_prc: 0.9937 - lr: 0.0010
# Epoch 7/10
# 88/88 [==============================] - 77s 873ms/step - loss: 0.0465 - tp: 1597.0000 - fp: 201.0000 - tn: 3732.0000 - fn: 48.0000 - accuracy: 0.9554 - precision: 0.8882 - recall: 0.9708 - auc: 0.9938 - prc: 0.9879 - val_loss: 0.0630 - val_tp: 170.0000 - val_fp: 4.0000 - val_tn: 513.0000 - val_fn: 17.0000 - val_accuracy: 0.9702 - val_precision: 0.9770 - val_recall: 0.9091 - val_auc: 0.9975 - val_prc: 0.9934 - lr: 0.0010
# Epoch 8/10
# 88/88 [==============================] - 80s 903ms/step - loss: 0.0573 - tp: 1576.0000 - fp: 212.0000 - tn: 3721.0000 - fn: 69.0000 - accuracy: 0.9496 - precision: 0.8814 - recall: 0.9581 - auc: 0.9904 - prc: 0.9800 - val_loss: 0.0785 - val_tp: 185.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 2.0000 - val_accuracy: 0.9716 - val_precision: 0.9113 - val_recall: 0.9893 - val_auc: 0.9978 - val_prc: 0.9940 - lr: 0.0010
# Epoch 9/10
# 88/88 [==============================] - 80s 906ms/step - loss: 0.0473 - tp: 1589.0000 - fp: 175.0000 - tn: 3758.0000 - fn: 56.0000 - accuracy: 0.9586 - precision: 0.9008 - recall: 0.9660 - auc: 0.9937 - prc: 0.9858 - val_loss: 0.0569 - val_tp: 180.0000 - val_fp: 7.0000 - val_tn: 510.0000 - val_fn: 7.0000 - val_accuracy: 0.9801 - val_precision: 0.9626 - val_recall: 0.9626 - val_auc: 0.9980 - val_prc: 0.9946 - lr: 0.0010
# Epoch 10/10
# 88/88 [==============================] - 81s 914ms/step - loss: 0.0411 - tp: 1605.0000 - fp: 183.0000 - tn: 3750.0000 - fn: 40.0000 - accuracy: 0.9600 - precision: 0.8977 - recall: 0.9757 - auc: 0.9953 - prc: 0.9896 - val_loss: 0.0571 - val_tp: 170.0000 - val_fp: 4.0000 - val_tn: 513.0000 - val_fn: 17.0000 - val_accuracy: 0.9702 - val_precision: 0.9770 - val_recall: 0.9091 - val_auc: 0.9981 - val_prc: 0.9947 - lr: 0.0010
# Training Finished

# %%
# delete_folder_contents('/kaggle/working/')

# %%
################################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# /kaggle/working/RESNet-50_without_keypoints_before_tuning_10epochs.h5

# %%
model.load_weights('/kaggle/working/RESNet-50_without_keypoints_before_tuning_10epochs.h5')
model.compile(optimizer=Adam(learning_rate=lr_2), loss= 'binary_crossentropy', metrics=METRICS)

# %%
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)
# Out:
# Evaluation of test Data Generator:
#
#
# 11/11 [==============================] - 4s 244ms/step - loss: 0.0468 - tp: 182.0000 - fp: 0.0000e+00 - tn: 482.0000 - fn: 10.0000 - accuracy: 0.9852 - precision: 1.0000 - recall: 0.9479 - auc: 0.9989 - prc: 0.9978
# [0.046771228313446045,
#  182.0,
#  0.0,
#  482.0,
#  10.0,
#  0.9851632118225098,
#  1.0,
#  0.9479166865348816,
#  0.9989356398582458,
#  0.9978183507919312]

# %% [markdown]
# ### Fine Tuning

# %%
print_parameters_count(base_model)
# Out:
# Total params: 23,587,712.0
# Trainable params: 0.0
# Non-trainable params: 23,587,712

# %%
base_model.trainable = True
for layer in base_model.layers[:fine_tune_limit]:
    layer.trainable=False
print_parameters_count(base_model)

model.compile(optimizer=Adam(learning_rate=lr_2), loss= 'binary_crossentropy', metrics=METRICS)
print('#######################################################################\n')
print(model.summary())
# Out:
# Total params: 23,587,712
# Trainable params: 7,881,216
# Non-trainable params: 15,706,496
# #######################################################################
#
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 25,686,913
# Trainable params: 9,980,417
# Non-trainable params: 15,706,496
# _________________________________________________________________
# None

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_fine_tuning,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)

################################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_fine_tuning, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_fine_tuning)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/20
# 89/89 [==============================] - 90s 898ms/step - loss: 0.0349 - tp: 1795.0000 - fp: 122.0000 - tn: 4357.0000 - fn: 42.0000 - accuracy: 0.9740 - precision: 0.9364 - recall: 0.9771 - auc: 0.9964 - prc: 0.9927 - val_loss: 0.0648 - val_tp: 201.0000 - val_fp: 16.0000 - val_tn: 501.0000 - val_fn: 2.0000 - val_accuracy: 0.9750 - val_precision: 0.9263 - val_recall: 0.9901 - val_auc: 0.9980 - val_prc: 0.9948
# Epoch 2/20
# 89/89 [==============================] - 79s 885ms/step - loss: 0.0300 - tp: 1619.0000 - fp: 137.0000 - tn: 3860.0000 - fn: 26.0000 - accuracy: 0.9711 - precision: 0.9220 - recall: 0.9842 - auc: 0.9973 - prc: 0.9922 - val_loss: 0.0528 - val_tp: 198.0000 - val_fp: 9.0000 - val_tn: 508.0000 - val_fn: 5.0000 - val_accuracy: 0.9806 - val_precision: 0.9565 - val_recall: 0.9754 - val_auc: 0.9980 - val_prc: 0.9948
# Epoch 3/20
# 89/89 [==============================] - 80s 892ms/step - loss: 0.0277 - tp: 1617.0000 - fp: 101.0000 - tn: 3896.0000 - fn: 28.0000 - accuracy: 0.9771 - precision: 0.9412 - recall: 0.9830 - auc: 0.9976 - prc: 0.9947 - val_loss: 0.0530 - val_tp: 197.0000 - val_fp: 9.0000 - val_tn: 508.0000 - val_fn: 6.0000 - val_accuracy: 0.9792 - val_precision: 0.9563 - val_recall: 0.9704 - val_auc: 0.9979 - val_prc: 0.9946
# Epoch 4/20
# 89/89 [==============================] - 78s 880ms/step - loss: 0.0250 - tp: 1624.0000 - fp: 111.0000 - tn: 3886.0000 - fn: 21.0000 - accuracy: 0.9766 - precision: 0.9360 - recall: 0.9872 - auc: 0.9979 - prc: 0.9952 - val_loss: 0.0482 - val_tp: 198.0000 - val_fp: 8.0000 - val_tn: 509.0000 - val_fn: 5.0000 - val_accuracy: 0.9819 - val_precision: 0.9612 - val_recall: 0.9754 - val_auc: 0.9982 - val_prc: 0.9952
# Epoch 5/20
# 89/89 [==============================] - 79s 884ms/step - loss: 0.0238 - tp: 1625.0000 - fp: 108.0000 - tn: 3889.0000 - fn: 20.0000 - accuracy: 0.9773 - precision: 0.9377 - recall: 0.9878 - auc: 0.9982 - prc: 0.9952 - val_loss: 0.0491 - val_tp: 193.0000 - val_fp: 6.0000 - val_tn: 511.0000 - val_fn: 10.0000 - val_accuracy: 0.9778 - val_precision: 0.9698 - val_recall: 0.9507 - val_auc: 0.9983 - val_prc: 0.9955
# Epoch 6/20
# 89/89 [==============================] - 81s 906ms/step - loss: 0.0250 - tp: 1617.0000 - fp: 102.0000 - tn: 3895.0000 - fn: 28.0000 - accuracy: 0.9770 - precision: 0.9407 - recall: 0.9830 - auc: 0.9980 - prc: 0.9959 - val_loss: 0.0572 - val_tp: 202.0000 - val_fp: 12.0000 - val_tn: 505.0000 - val_fn: 1.0000 - val_accuracy: 0.9819 - val_precision: 0.9439 - val_recall: 0.9951 - val_auc: 0.9966 - val_prc: 0.9854
# Epoch 7/20
# 89/89 [==============================] - 78s 876ms/step - loss: 0.0208 - tp: 1629.0000 - fp: 84.0000 - tn: 3913.0000 - fn: 16.0000 - accuracy: 0.9823 - precision: 0.9510 - recall: 0.9903 - auc: 0.9985 - prc: 0.9958 - val_loss: 0.0620 - val_tp: 202.0000 - val_fp: 13.0000 - val_tn: 504.0000 - val_fn: 1.0000 - val_accuracy: 0.9806 - val_precision: 0.9395 - val_recall: 0.9951 - val_auc: 0.9966 - val_prc: 0.9856
# Epoch 8/20
# 89/89 [==============================] - 79s 886ms/step - loss: 0.0201 - tp: 1634.0000 - fp: 82.0000 - tn: 3915.0000 - fn: 11.0000 - accuracy: 0.9835 - precision: 0.9522 - recall: 0.9933 - auc: 0.9984 - prc: 0.9959 - val_loss: 0.0481 - val_tp: 198.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 5.0000 - val_accuracy: 0.9792 - val_precision: 0.9519 - val_recall: 0.9754 - val_auc: 0.9982 - val_prc: 0.9952
# Epoch 9/20
# 89/89 [==============================] - 79s 884ms/step - loss: 0.0191 - tp: 1626.0000 - fp: 75.0000 - tn: 3922.0000 - fn: 19.0000 - accuracy: 0.9833 - precision: 0.9559 - recall: 0.9884 - auc: 0.9989 - prc: 0.9974 - val_loss: 0.0475 - val_tp: 201.0000 - val_fp: 9.0000 - val_tn: 508.0000 - val_fn: 2.0000 - val_accuracy: 0.9847 - val_precision: 0.9571 - val_recall: 0.9901 - val_auc: 0.9983 - val_prc: 0.9954
# Epoch 10/20
# 89/89 [==============================] - 80s 900ms/step - loss: 0.0191 - tp: 1625.0000 - fp: 70.0000 - tn: 3927.0000 - fn: 20.0000 - accuracy: 0.9840 - precision: 0.9587 - recall: 0.9878 - auc: 0.9988 - prc: 0.9967 - val_loss: 0.0491 - val_tp: 202.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 1.0000 - val_accuracy: 0.9847 - val_precision: 0.9528 - val_recall: 0.9951 - val_auc: 0.9969 - val_prc: 0.9860
# Epoch 11/20
# 89/89 [==============================] - 79s 889ms/step - loss: 0.0164 - tp: 1631.0000 - fp: 76.0000 - tn: 3921.0000 - fn: 14.0000 - accuracy: 0.9840 - precision: 0.9555 - recall: 0.9915 - auc: 0.9989 - prc: 0.9966 - val_loss: 0.0606 - val_tp: 202.0000 - val_fp: 12.0000 - val_tn: 505.0000 - val_fn: 1.0000 - val_accuracy: 0.9819 - val_precision: 0.9439 - val_recall: 0.9951 - val_auc: 0.9970 - val_prc: 0.9866
# Epoch 12/20
# 89/89 [==============================] - 79s 886ms/step - loss: 0.0173 - tp: 1630.0000 - fp: 72.0000 - tn: 3925.0000 - fn: 15.0000 - accuracy: 0.9846 - precision: 0.9577 - recall: 0.9909 - auc: 0.9989 - prc: 0.9966 - val_loss: 0.0535 - val_tp: 201.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 2.0000 - val_accuracy: 0.9833 - val_precision: 0.9526 - val_recall: 0.9901 - val_auc: 0.9968 - val_prc: 0.9860
# Epoch 13/20
# 89/89 [==============================] - 78s 879ms/step - loss: 0.0143 - tp: 1636.0000 - fp: 61.0000 - tn: 3936.0000 - fn: 9.0000 - accuracy: 0.9876 - precision: 0.9641 - recall: 0.9945 - auc: 0.9991 - prc: 0.9972 - val_loss: 0.0639 - val_tp: 183.0000 - val_fp: 3.0000 - val_tn: 514.0000 - val_fn: 20.0000 - val_accuracy: 0.9681 - val_precision: 0.9839 - val_recall: 0.9015 - val_auc: 0.9986 - val_prc: 0.9963
# Epoch 14/20
# 89/89 [==============================] - 78s 878ms/step - loss: 0.0159 - tp: 1631.0000 - fp: 69.0000 - tn: 3928.0000 - fn: 14.0000 - accuracy: 0.9853 - precision: 0.9594 - recall: 0.9915 - auc: 0.9992 - prc: 0.9981 - val_loss: 0.0652 - val_tp: 203.0000 - val_fp: 11.0000 - val_tn: 506.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9847 - val_precision: 0.9486 - val_recall: 1.0000 - val_auc: 0.9968 - val_prc: 0.9860
# Epoch 15/20
# 89/89 [==============================] - 79s 888ms/step - loss: 0.0158 - tp: 1633.0000 - fp: 67.0000 - tn: 3930.0000 - fn: 12.0000 - accuracy: 0.9860 - precision: 0.9606 - recall: 0.9927 - auc: 0.9985 - prc: 0.9955 - val_loss: 0.0495 - val_tp: 202.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 1.0000 - val_accuracy: 0.9847 - val_precision: 0.9528 - val_recall: 0.9951 - val_auc: 0.9969 - val_prc: 0.9863
#
#
# Evaluation of test Data Generator:
#
#
# 11/11 [==============================] - 3s 234ms/step - loss: 0.0251 - tp: 189.0000 - fp: 3.0000 - tn: 479.0000 - fn: 3.0000 - accuracy: 0.9911 - precision: 0.9844 - recall: 0.9844 - auc: 0.9994 - prc: 0.9986

# %% [markdown]
# ## With Pose Estimation key points

# %% [markdown]
# ### Train before Tune

# %%
train_generator = train_generator_with_preprocessing
val_generator = val_generator_with_preprocessing
test_generator = test_generator_with_preprocessing
preprocess_fn = resnet50_preprocess
neurons_final = 1024
base_model = create_base_ResNet()
fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))
model_name= 'RESNet-50'
fine_tuning = 'before_tuning'
keypoints_added = 'with_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_30 = 30
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")

#####################################################################3
base_model.trainable = False

inputs = Input(shape=(224,224,3))
# x = PreprocessAddKPts()(inputs)
x = preprocess_fn(inputs)
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print( model.summary())
# Out:
# Done
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_7   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_7 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_7   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_14 (Dropout)        (None, 2048)              0
#
#  dense_14 (Dense)            (None, 1024)              2098176
#
#  dropout_15 (Dropout)        (None, 1024)              0
#
#  dense_15 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 25,686,913
# Trainable params: 2,099,201
# Non-trainable params: 23,587,712
# _________________________________________________________________
# None

# %%
call_backs = [ EarlyStopping(monitor='val_loss', patience=6),
               ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5) ]

model.compile(optimizer=Adam(learning_rate=lr_1),loss= 'binary_crossentropy',metrics=METRICS)

# steps_per_epoch = train_generator.n // batch_size  
# validation_steps = val_generator.n // batch_size
print("Training Started\n\n")   
train_generator.reset()
val_generator.reset()
history = model.fit(train_generator,
                    epochs= epochs_1,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n")

##################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Training Started
#
#
# Epoch 1/10
# 89/89 [==============================] - 182s 2s/step - loss: 0.2865 - tp: 1390.0000 - fp: 819.0000 - tn: 3178.0000 - fn: 255.0000 - accuracy: 0.8096 - precision: 0.6292 - recall: 0.8450 - auc: 0.8896 - prc: 0.7607 - val_loss: 0.1614 - val_tp: 162.0000 - val_fp: 1.0000 - val_tn: 516.0000 - val_fn: 41.0000 - val_accuracy: 0.9417 - val_precision: 0.9939 - val_recall: 0.7980 - val_auc: 0.9809 - val_prc: 0.9658 - lr: 0.0010
# Epoch 2/10
# 89/89 [==============================] - 175s 2s/step - loss: 0.1222 - tp: 1432.0000 - fp: 425.0000 - tn: 3572.0000 - fn: 213.0000 - accuracy: 0.8869 - precision: 0.7711 - recall: 0.8705 - auc: 0.9555 - prc: 0.9331 - val_loss: 0.1273 - val_tp: 171.0000 - val_fp: 4.0000 - val_tn: 513.0000 - val_fn: 32.0000 - val_accuracy: 0.9500 - val_precision: 0.9771 - val_recall: 0.8424 - val_auc: 0.9885 - val_prc: 0.9775 - lr: 0.0010
# Epoch 3/10
# 89/89 [==============================] - 174s 2s/step - loss: 0.0964 - tp: 1483.0000 - fp: 310.0000 - tn: 3687.0000 - fn: 162.0000 - accuracy: 0.9163 - precision: 0.8271 - recall: 0.9015 - auc: 0.9734 - prc: 0.9567 - val_loss: 0.1186 - val_tp: 168.0000 - val_fp: 2.0000 - val_tn: 515.0000 - val_fn: 35.0000 - val_accuracy: 0.9486 - val_precision: 0.9882 - val_recall: 0.8276 - val_auc: 0.9922 - val_prc: 0.9836 - lr: 0.0010
# Epoch 4/10
# 89/89 [==============================] - 176s 2s/step - loss: 0.0806 - tp: 1494.0000 - fp: 246.0000 - tn: 3751.0000 - fn: 151.0000 - accuracy: 0.9296 - precision: 0.8586 - recall: 0.9082 - auc: 0.9824 - prc: 0.9673 - val_loss: 0.0956 - val_tp: 182.0000 - val_fp: 6.0000 - val_tn: 511.0000 - val_fn: 21.0000 - val_accuracy: 0.9625 - val_precision: 0.9681 - val_recall: 0.8966 - val_auc: 0.9932 - val_prc: 0.9850 - lr: 0.0010
# Epoch 5/10
# 89/89 [==============================] - 182s 2s/step - loss: 0.0693 - tp: 1547.0000 - fp: 266.0000 - tn: 3731.0000 - fn: 98.0000 - accuracy: 0.9355 - precision: 0.8533 - recall: 0.9404 - auc: 0.9867 - prc: 0.9751 - val_loss: 0.1385 - val_tp: 197.0000 - val_fp: 36.0000 - val_tn: 481.0000 - val_fn: 6.0000 - val_accuracy: 0.9417 - val_precision: 0.8455 - val_recall: 0.9704 - val_auc: 0.9938 - val_prc: 0.9861 - lr: 0.0010
# Epoch 6/10
# 89/89 [==============================] - 182s 2s/step - loss: 0.0831 - tp: 1514.0000 - fp: 302.0000 - tn: 3695.0000 - fn: 131.0000 - accuracy: 0.9233 - precision: 0.8337 - recall: 0.9204 - auc: 0.9810 - prc: 0.9653 - val_loss: 0.1768 - val_tp: 201.0000 - val_fp: 54.0000 - val_tn: 463.0000 - val_fn: 2.0000 - val_accuracy: 0.9222 - val_precision: 0.7882 - val_recall: 0.9901 - val_auc: 0.9935 - val_prc: 0.9856 - lr: 0.0010
# Epoch 7/10
# 89/89 [==============================] - 179s 2s/step - loss: 0.0629 - tp: 1555.0000 - fp: 247.0000 - tn: 3750.0000 - fn: 90.0000 - accuracy: 0.9403 - precision: 0.8629 - recall: 0.9453 - auc: 0.9892 - prc: 0.9785 - val_loss: 0.1855 - val_tp: 203.0000 - val_fp: 61.0000 - val_tn: 456.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9153 - val_precision: 0.7689 - val_recall: 1.0000 - val_auc: 0.9953 - val_prc: 0.9886 - lr: 0.0010
# Epoch 8/10
# 89/89 [==============================] - 180s 2s/step - loss: 0.0642 - tp: 1544.0000 - fp: 240.0000 - tn: 3757.0000 - fn: 101.0000 - accuracy: 0.9396 - precision: 0.8655 - recall: 0.9386 - auc: 0.9886 - prc: 0.9782 - val_loss: 0.1807 - val_tp: 201.0000 - val_fp: 58.0000 - val_tn: 459.0000 - val_fn: 2.0000 - val_accuracy: 0.9167 - val_precision: 0.7761 - val_recall: 0.9901 - val_auc: 0.9931 - val_prc: 0.9777 - lr: 0.0010
# Epoch 9/10
# 89/89 [==============================] - 179s 2s/step - loss: 0.0622 - tp: 1548.0000 - fp: 250.0000 - tn: 3747.0000 - fn: 97.0000 - accuracy: 0.9385 - precision: 0.8610 - recall: 0.9410 - auc: 0.9894 - prc: 0.9788 - val_loss: 0.0928 - val_tp: 194.0000 - val_fp: 14.0000 - val_tn: 503.0000 - val_fn: 9.0000 - val_accuracy: 0.9681 - val_precision: 0.9327 - val_recall: 0.9557 - val_auc: 0.9955 - val_prc: 0.9890 - lr: 0.0010
# Epoch 10/10
# 89/89 [==============================] - 176s 2s/step - loss: 0.0531 - tp: 1566.0000 - fp: 211.0000 - tn: 3786.0000 - fn: 79.0000 - accuracy: 0.9486 - precision: 0.8813 - recall: 0.9520 - auc: 0.9922 - prc: 0.9842 - val_loss: 0.0906 - val_tp: 196.0000 - val_fp: 21.0000 - val_tn: 496.0000 - val_fn: 7.0000 - val_accuracy: 0.9611 - val_precision: 0.9032 - val_recall: 0.9655 - val_auc: 0.9959 - val_prc: 0.9899 - lr: 0.0010
# Training Finished

# %%
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)

# %%
# saved_model_before_withKPts_path = '/kaggle/working/{}.h5'.format(name)
# print(saved_model_before_withKPts_path)
# Out:
# /kaggle/working/VGG19_with_keypoints_before_tuning_10epochs.h5

# %% [markdown]
# ### Fine Tuning

# %%
model.load_weights('/kaggle/working/RESNet-50_with_keypoints_before_tuning_10epochs.h5')

# %%
model.compile(optimizer=Adam(learning_rate=lr_1),loss= 'binary_crossentropy',metrics=METRICS)
model.evaluate(test_generator)
# Out:
# 11/11 [==============================] - 15s 1s/step - loss: 0.0765 - tp: 1657.0000 - fp: 152.0000 - tn: 4135.0000 - fn: 52.0000 - accuracy: 0.9660 - precision: 0.9160 - recall: 0.9696 - auc: 0.9955 - prc: 0.9904
# [0.0764586478471756,
#  1657.0,
#  152.0,
#  4135.0,
#  52.0,
#  0.9659773111343384,
#  0.9159756898880005,
#  0.9695728421211243,
#  0.9955464601516724,
#  0.9904425740242004]

# %%
fine_tuning = 'after_tuning'
base_model.trainable = True
for layer in base_model.layers[:fine_tune_limit]:
    layer.trainable=False


model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('+===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# +===================================
# Total params: 25,686,913
# Trainable params: 9,980,417
# Non-trainable params: 15,706,496
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_7   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_7 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_7   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_14 (Dropout)        (None, 2048)              0
#
#  dense_14 (Dense)            (None, 1024)              2098176
#
#  dropout_15 (Dropout)        (None, 1024)              0
#
#  dense_15 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 25,686,913
# Trainable params: 9,980,417
# Non-trainable params: 15,706,496
# _________________________________________________________________
# None

# %%
#######################################################################################################################33
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
history_after_tune = model.fit(train_generator,
                              epochs=epochs_fine_tuning,
                               #steps_per_epoch=steps_per_epoch,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                               #validation_steps=validation_steps,
                              class_weight=class_weight)

#############################################################################################################33
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)

##########################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_fine_tuning, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_fine_tuning)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/20
# 89/89 [==============================] - 189s 2s/step - loss: 0.0488 - tp: 3230.0000 - fp: 330.0000 - tn: 7954.0000 - fn: 124.0000 - accuracy: 0.9610 - precision: 0.9073 - recall: 0.9630 - auc: 0.9948 - prc: 0.9892 - val_loss: 0.0815 - val_tp: 195.0000 - val_fp: 13.0000 - val_tn: 504.0000 - val_fn: 8.0000 - val_accuracy: 0.9708 - val_precision: 0.9375 - val_recall: 0.9606 - val_auc: 0.9963 - val_prc: 0.9907
# Epoch 2/20
# 89/89 [==============================] - 180s 2s/step - loss: 0.0471 - tp: 1588.0000 - fp: 197.0000 - tn: 3800.0000 - fn: 57.0000 - accuracy: 0.9550 - precision: 0.8896 - recall: 0.9653 - auc: 0.9937 - prc: 0.9870 - val_loss: 0.0830 - val_tp: 199.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 4.0000 - val_accuracy: 0.9694 - val_precision: 0.9171 - val_recall: 0.9803 - val_auc: 0.9968 - val_prc: 0.9918
# Epoch 3/20
# 89/89 [==============================] - 182s 2s/step - loss: 0.0435 - tp: 1585.0000 - fp: 178.0000 - tn: 3819.0000 - fn: 60.0000 - accuracy: 0.9578 - precision: 0.8990 - recall: 0.9635 - auc: 0.9945 - prc: 0.9892 - val_loss: 0.1117 - val_tp: 203.0000 - val_fp: 30.0000 - val_tn: 487.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9583 - val_precision: 0.8712 - val_recall: 1.0000 - val_auc: 0.9963 - val_prc: 0.9875
# Epoch 5/20
# 89/89 [==============================] - 180s 2s/step - loss: 0.0405 - tp: 1596.0000 - fp: 163.0000 - tn: 3834.0000 - fn: 49.0000 - accuracy: 0.9624 - precision: 0.9073 - recall: 0.9702 - auc: 0.9954 - prc: 0.9906 - val_loss: 0.1121 - val_tp: 203.0000 - val_fp: 31.0000 - val_tn: 486.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9569 - val_precision: 0.8675 - val_recall: 1.0000 - val_auc: 0.9957 - val_prc: 0.9832
# Epoch 6/20
# 89/89 [==============================] - 181s 2s/step - loss: 0.0348 - tp: 1606.0000 - fp: 142.0000 - tn: 3855.0000 - fn: 39.0000 - accuracy: 0.9679 - precision: 0.9188 - recall: 0.9763 - auc: 0.9968 - prc: 0.9929 - val_loss: 0.1183 - val_tp: 203.0000 - val_fp: 34.0000 - val_tn: 483.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9528 - val_precision: 0.8565 - val_recall: 1.0000 - val_auc: 0.9951 - val_prc: 0.9789
# Epoch 7/20
# 89/89 [==============================] - 179s 2s/step - loss: 0.0327 - tp: 1609.0000 - fp: 136.0000 - tn: 3861.0000 - fn: 36.0000 - accuracy: 0.9695 - precision: 0.9221 - recall: 0.9781 - auc: 0.9970 - prc: 0.9931 - val_loss: 0.0915 - val_tp: 201.0000 - val_fp: 23.0000 - val_tn: 494.0000 - val_fn: 2.0000 - val_accuracy: 0.9653 - val_precision: 0.8973 - val_recall: 0.9901 - val_auc: 0.9952 - val_prc: 0.9793
# Epoch 8/20
# 89/89 [==============================] - 179s 2s/step - loss: 0.0357 - tp: 1603.0000 - fp: 150.0000 - tn: 3847.0000 - fn: 42.0000 - accuracy: 0.9660 - precision: 0.9144 - recall: 0.9745 - auc: 0.9965 - prc: 0.9921 - val_loss: 0.0855 - val_tp: 200.0000 - val_fp: 20.0000 - val_tn: 497.0000 - val_fn: 3.0000 - val_accuracy: 0.9681 - val_precision: 0.9091 - val_recall: 0.9852 - val_auc: 0.9961 - val_prc: 0.9840
# Epoch 9/20
# 89/89 [==============================] - 181s 2s/step - loss: 0.0338 - tp: 1617.0000 - fp: 143.0000 - tn: 3854.0000 - fn: 28.0000 - accuracy: 0.9697 - precision: 0.9187 - recall: 0.9830 - auc: 0.9964 - prc: 0.9926 - val_loss: 0.0920 - val_tp: 202.0000 - val_fp: 24.0000 - val_tn: 493.0000 - val_fn: 1.0000 - val_accuracy: 0.9653 - val_precision: 0.8938 - val_recall: 0.9951 - val_auc: 0.9955 - val_prc: 0.9797
#
#
# Evaluation of test Data Generator:
#
#
# 11/11 [==============================] - 14s 1s/step - loss: 0.0661 - tp: 190.0000 - fp: 16.0000 - tn: 466.0000 - fn: 2.0000 - accuracy: 0.9733 - precision: 0.9223 - recall: 0.9896 - auc: 0.9977 - prc: 0.9917

# %%
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_fine_tuning, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_fine_tuning)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))

# %% [markdown]
# # Second Approach: Unfreeze all layers

# %%
#define generators from second data set
#reapeat trainning of dense layers before unfreezing the model
train_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/train'
validation_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/val'
test_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/test'
############################################################################################################################################
# Create a data generator to load and augment the training data
train_datagen_without_preprocessing_2 = ImageDataGenerator(  
    #rescale=1.0/255,  #If using the pre processing fn of the pre trainde models, no need to rescale, and should add featurewise_center=False if so.
    featurewise_center=False, # if using the pre processing of the pre trained models, no need to make featurewise center, and if not false, should fit it before use
    rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest' )

train_generator_without_preprocessing_2 = train_datagen_without_preprocessing_2.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
# Create a data generator to load the validation data
val_datagen_without_preprocessing_2 = ImageDataGenerator( featurewise_center=False)

val_generator_without_preprocessing_2 = val_datagen_without_preprocessing_2.flow_from_directory(
    validation_path,
    target_size= (img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
shuffle=False )

#######################################################################################################################################
# Create a data generator to accept the trainign data with the preprocessing function
train_datagen_with_preprocessing_2 = ImageDataGenerator(
    featurewise_center=False,
     rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest',  # fill any missing pixels with the nearest value
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet,
                                                                         image_output_shape=(img_width, img_height),
                                                                         confidence_threshold= 0.05) )

train_generator_with_preprocessing_2 = train_datagen_with_preprocessing_2.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )

# Create a data generator to load the validation data with the preprocessing function
val_datagen_with_preprocessing_2 = ImageDataGenerator( 
    featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold=0.05) )

val_generator_with_preprocessing_2 = val_datagen_with_preprocessing_2.flow_from_directory(
    validation_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )

#######################################################################################################################################
test_datagen_without_preprocessing_2 = ImageDataGenerator( featurewise_center=False,)

#Load the training data
test_generator_without_preprocessing_2 = test_datagen_without_preprocessing_2.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
###################################
# Create a data generator to accept the trainign data with the preprocessing function
test_datagen_with_preprocessing_2 = ImageDataGenerator( featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold= 0.05) )

# Load the training data
test_generator_with_preprocessing_2 = test_datagen_with_preprocessing_2.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
# Out:
# Found 2535 images belonging to 2 classes.
# Found 1882 images belonging to 2 classes.
# Found 2535 images belonging to 2 classes.
# Found 1882 images belonging to 2 classes.
# Found 1849 images belonging to 2 classes.
# Found 1849 images belonging to 2 classes.

# %% [markdown]
# ## Wihtout Pose Estimation

# %%
train_generator = train_generator_without_preprocessing_2
val_generator = val_generator_without_preprocessing_2
test_generator = test_generator_without_preprocessing_2
#############################################################
preprocess_fn = resnet50_preprocess############################
neurons_final = 1024########################################
base_model = create_base_ResNet()###########################
# fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))-1
model_name= 'RESNet-50_approach2'#################################
fine_tuning = 'before_tuning'################################
keypoints_added = 'without_keypoints'
###############################################################
epochs_1 = 10
epochs_fine_tuning = 20
epochs_8 = 8
epochs_40 = 40
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################
base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)###########################################
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Done
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_8   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_8 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_8   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_16 (Dropout)        (None, 2048)              0
#
#  dense_16 (Dense)            (None, 1024)              2098176
#
#  dropout_17 (Dropout)        (None, 1024)              0
#
#  dense_17 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 25,686,913
# Trainable params: 2,099,201
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Model Summary:  None

# %%
counter = Counter(train_generator.classes)
print(str(counter.items())+"\n") # dict_items([(0, 1648), (1, 3614)])
Adult = 3997
Child = 1645
total = Adult + Child
weight_for_Adult =   (total / Adult) 
weight_for_Child =   (total /Child)
weight_for_Adult /= (weight_for_Adult +  weight_for_Child)
weight_for_Child /= (weight_for_Adult +  weight_for_Child)

class_weight = {0: weight_for_Adult, 1: weight_for_Child}
print('Class Weights: ', class_weight)

METRICS = [
      metrics.TruePositives(name='tp'),
      metrics.FalsePositives(name='fp'),
      metrics.TrueNegatives(name='tn'),
      metrics.FalseNegatives(name='fn'), 
      metrics.BinaryAccuracy(name='accuracy'),
      metrics.Precision(name='precision'),
      metrics.Recall(name='recall'),
      metrics.AUC(name='auc'),
      metrics.AUC(name='prc', curve='PR'), ]  # precision-recall curve
# Out:
# dict_items([(0, 1691), (1, 844)])
#
# Class Weights:  {0: 0.2915632754342432, 1: 0.9216512191765469}

# %%
base_model.trainable = False
#Train dense layers:
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS )

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
################################################################################################################
model_name= 'VGG19_approach2'
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# Training Started
#
# Epoch 1/10
# 40/40 [==============================] - 40s 1s/step - loss: 0.1329 - tp: 758.0000 - fp: 216.0000 - tn: 1475.0000 - fn: 86.0000 - accuracy: 0.8809 - precision: 0.7782 - recall: 0.8981 - auc: 0.9531 - prc: 0.9365 - val_loss: 0.1989 - val_tp: 595.0000 - val_fp: 129.0000 - val_tn: 1147.0000 - val_fn: 11.0000 - val_accuracy: 0.9256 - val_precision: 0.8218 - val_recall: 0.9818 - val_auc: 0.9907 - val_prc: 0.9835 - lr: 0.0010
# Epoch 5/10
# 40/40 [==============================] - 41s 1s/step - loss: 0.0866 - tp: 779.0000 - fp: 116.0000 - tn: 1575.0000 - fn: 65.0000 - accuracy: 0.9286 - precision: 0.8704 - recall: 0.9230 - auc: 0.9817 - prc: 0.9718 - val_loss: 0.2239 - val_tp: 601.0000 - val_fp: 178.0000 - val_tn: 1098.0000 - val_fn: 5.0000 - val_accuracy: 0.9028 - val_precision: 0.7715 - val_recall: 0.9917 - val_auc: 0.9923 - val_prc: 0.9863 - lr: 0.0010
# Epoch 6/10
# 40/40 [==============================] - 40s 1s/step - loss: 0.0743 - tp: 778.0000 - fp: 68.0000 - tn: 1623.0000 - fn: 66.0000 - accuracy: 0.9471 - precision: 0.9196 - recall: 0.9218 - auc: 0.9873 - prc: 0.9798 - val_loss: 0.3454 - val_tp: 604.0000 - val_fp: 255.0000 - val_tn: 1021.0000 - val_fn: 2.0000 - val_accuracy: 0.8634 - val_precision: 0.7031 - val_recall: 0.9967 - val_auc: 0.9930 - val_prc: 0.9853 - lr: 0.0010
# Epoch 8/10
# 40/40 [==============================] - 41s 1s/step - loss: 0.0941 - tp: 791.0000 - fp: 185.0000 - tn: 1506.0000 - fn: 53.0000 - accuracy: 0.9061 - precision: 0.8105 - recall: 0.9372 - auc: 0.9784 - prc: 0.9663 - val_loss: 0.1141 - val_tp: 588.0000 - val_fp: 51.0000 - val_tn: 1225.0000 - val_fn: 18.0000 - val_accuracy: 0.9633 - val_precision: 0.9202 - val_recall: 0.9703 - val_auc: 0.9949 - val_prc: 0.9907 - lr: 0.0010
# Epoch 9/10
# 40/40 [==============================] - 40s 1s/step - loss: 0.0668 - tp: 792.0000 - fp: 85.0000 - tn: 1606.0000 - fn: 52.0000 - accuracy: 0.9460 - precision: 0.9031 - recall: 0.9384 - auc: 0.9900 - prc: 0.9828 - val_loss: 0.1647 - val_tp: 602.0000 - val_fp: 130.0000 - val_tn: 1146.0000 - val_fn: 4.0000 - val_accuracy: 0.9288 - val_precision: 0.8224 - val_recall: 0.9934 - val_auc: 0.9955 - val_prc: 0.9920 - lr: 0.0010
# Epoch 10/10
# 12/40 [========>.....................] - ETA: 23s - loss: 0.0761 - tp: 317.0000 - fp: 68.0000 - tn: 380.0000 - fn: 3.0000 - accuracy: 0.9076 - precision: 0.8234 - recall: 0.9906 - auc: 0.9903 - prc: 0.9854

# %%
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
# Out:
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 20s 681ms/step - loss: 0.1496 - tp: 585.0000 - fp: 127.0000 - tn: 1132.0000 - fn: 5.0000 - accuracy: 0.9286 - precision: 0.8216 - recall: 0.9915 - auc: 0.9948 - prc: 0.9908
# [0.1495923548936844,
#  585.0,
#  127.0,
#  1132.0,
#  5.0,
#  0.92861008644104,
#  0.8216292262077332,
#  0.991525411605835,
#  0.9948257207870483,
#  0.9907978773117065]

# %%
base_model.trainable = True
# for layer in base_model.layers[:fine_tune_limit]:
#     layer.trainable=False
    
model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# ===================================
# Total params: 25,686,913
# Trainable params: 25,633,793
# Non-trainable params: 53,120
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_8   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_8 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_8   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_16 (Dropout)        (None, 2048)              0
#
#  dense_16 (Dense)            (None, 1024)              2098176
#
#  dropout_17 (Dropout)        (None, 1024)              0
#
#  dense_17 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 25,686,913
# Trainable params: 25,633,793
# Non-trainable params: 53,120
# _________________________________________________________________
# None

# %% [markdown]
# ### Fine Tuning 8 epcohs

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_8,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight )
fine_tuning = 'after_tuning_8'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'RESNet-50_approach2'#################################
fine_tuning = 'tuning_8epochs'
keypoints_added = 'without_keypoints'

plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_8, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_8)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/8
# 40/40 [==============================] - 86s 1s/step - loss: 0.2032 - tp: 1325.0000 - fp: 322.0000 - tn: 2628.0000 - fn: 109.0000 - accuracy: 0.9017 - precision: 0.8045 - recall: 0.9240 - auc: 0.9599 - prc: 0.9556 - val_loss: 0.1129 - val_tp: 531.0000 - val_fp: 9.0000 - val_tn: 1267.0000 - val_fn: 75.0000 - val_accuracy: 0.9554 - val_precision: 0.9833 - val_recall: 0.8762 - val_auc: 0.9949 - val_prc: 0.9910
# Epoch 2/8
# 40/40 [==============================] - 48s 1s/step - loss: 0.0696 - tp: 792.0000 - fp: 79.0000 - tn: 1612.0000 - fn: 52.0000 - accuracy: 0.9483 - precision: 0.9093 - recall: 0.9384 - auc: 0.9899 - prc: 0.9834 - val_loss: 0.1212 - val_tp: 599.0000 - val_fp: 74.0000 - val_tn: 1202.0000 - val_fn: 7.0000 - val_accuracy: 0.9570 - val_precision: 0.8900 - val_recall: 0.9884 - val_auc: 0.9967 - val_prc: 0.9943
# Epoch 3/8
# 40/40 [==============================] - 48s 1s/step - loss: 0.0459 - tp: 826.0000 - fp: 82.0000 - tn: 1609.0000 - fn: 18.0000 - accuracy: 0.9606 - precision: 0.9097 - recall: 0.9787 - auc: 0.9961 - prc: 0.9924 - val_loss: 0.0653 - val_tp: 574.0000 - val_fp: 19.0000 - val_tn: 1257.0000 - val_fn: 32.0000 - val_accuracy: 0.9729 - val_precision: 0.9680 - val_recall: 0.9472 - val_auc: 0.9968 - val_prc: 0.9949
# Epoch 4/8
# 40/40 [==============================] - 47s 1s/step - loss: 0.0420 - tp: 817.0000 - fp: 72.0000 - tn: 1619.0000 - fn: 27.0000 - accuracy: 0.9609 - precision: 0.9190 - recall: 0.9680 - auc: 0.9961 - prc: 0.9928 - val_loss: 0.0568 - val_tp: 591.0000 - val_fp: 28.0000 - val_tn: 1248.0000 - val_fn: 15.0000 - val_accuracy: 0.9772 - val_precision: 0.9548 - val_recall: 0.9752 - val_auc: 0.9974 - val_prc: 0.9960
# Epoch 5/8
# 40/40 [==============================] - 48s 1s/step - loss: 0.0368 - tp: 830.0000 - fp: 73.0000 - tn: 1618.0000 - fn: 14.0000 - accuracy: 0.9657 - precision: 0.9192 - recall: 0.9834 - auc: 0.9964 - prc: 0.9924 - val_loss: 0.0754 - val_tp: 603.0000 - val_fp: 47.0000 - val_tn: 1229.0000 - val_fn: 3.0000 - val_accuracy: 0.9734 - val_precision: 0.9277 - val_recall: 0.9950 - val_auc: 0.9973 - val_prc: 0.9948
# Epoch 6/8
# 40/40 [==============================] - 47s 1s/step - loss: 0.0294 - tp: 830.0000 - fp: 45.0000 - tn: 1646.0000 - fn: 14.0000 - accuracy: 0.9767 - precision: 0.9486 - recall: 0.9834 - auc: 0.9979 - prc: 0.9961 - val_loss: 0.0943 - val_tp: 605.0000 - val_fp: 60.0000 - val_tn: 1216.0000 - val_fn: 1.0000 - val_accuracy: 0.9676 - val_precision: 0.9098 - val_recall: 0.9983 - val_auc: 0.9974 - val_prc: 0.9951
# Epoch 7/8
# 40/40 [==============================] - 47s 1s/step - loss: 0.0267 - tp: 835.0000 - fp: 57.0000 - tn: 1634.0000 - fn: 9.0000 - accuracy: 0.9740 - precision: 0.9361 - recall: 0.9893 - auc: 0.9983 - prc: 0.9966 - val_loss: 0.0532 - val_tp: 597.0000 - val_fp: 31.0000 - val_tn: 1245.0000 - val_fn: 9.0000 - val_accuracy: 0.9787 - val_precision: 0.9506 - val_recall: 0.9851 - val_auc: 0.9979 - val_prc: 0.9970
# Epoch 8/8
# 40/40 [==============================] - 48s 1s/step - loss: 0.0232 - tp: 838.0000 - fp: 41.0000 - tn: 1650.0000 - fn: 6.0000 - accuracy: 0.9815 - precision: 0.9534 - recall: 0.9929 - auc: 0.9984 - prc: 0.9971 - val_loss: 0.0451 - val_tp: 597.0000 - val_fp: 20.0000 - val_tn: 1256.0000 - val_fn: 9.0000 - val_accuracy: 0.9846 - val_precision: 0.9676 - val_recall: 0.9851 - val_auc: 0.9980 - val_prc: 0.9970
#
#
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 6s 211ms/step - loss: 0.0504 - tp: 581.0000 - fp: 25.0000 - tn: 1234.0000 - fn: 9.0000 - accuracy: 0.9816 - precision: 0.9587 - recall: 0.9847 - auc: 0.9977 - prc: 0.9963

# %% [markdown]
# ### Fine Tuning 40

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune2 = model.fit(train_generator,
                              epochs=epochs_30,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'VGG19_approach2'
fine_tuning = 'tuning_40epochs'
keypoints_added = 'without_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_30, batch_size, history_after_tune2)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_30)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/30
# 40/40 [==============================] - 47s 1s/step - loss: 0.0198 - tp: 836.0000 - fp: 45.0000 - tn: 1646.0000 - fn: 8.0000 - accuracy: 0.9791 - precision: 0.9489 - recall: 0.9905 - auc: 0.9990 - prc: 0.9981 - val_loss: 0.0420 - val_tp: 593.0000 - val_fp: 13.0000 - val_tn: 1263.0000 - val_fn: 13.0000 - val_accuracy: 0.9862 - val_precision: 0.9785 - val_recall: 0.9785 - val_auc: 0.9982 - val_prc: 0.9973
# Epoch 2/30
# 40/40 [==============================] - 46s 1s/step - loss: 0.0175 - tp: 838.0000 - fp: 29.0000 - tn: 1662.0000 - fn: 6.0000 - accuracy: 0.9862 - precision: 0.9666 - recall: 0.9929 - auc: 0.9989 - prc: 0.9972 - val_loss: 0.0562 - val_tp: 576.0000 - val_fp: 6.0000 - val_tn: 1270.0000 - val_fn: 30.0000 - val_accuracy: 0.9809 - val_precision: 0.9897 - val_recall: 0.9505 - val_auc: 0.9981 - val_prc: 0.9970
# Epoch 3/30
# 40/40 [==============================] - 47s 1s/step - loss: 0.0181 - tp: 836.0000 - fp: 30.0000 - tn: 1661.0000 - fn: 8.0000 - accuracy: 0.9850 - precision: 0.9654 - recall: 0.9905 - auc: 0.9988 - prc: 0.9969 - val_loss: 0.0739 - val_tp: 602.0000 - val_fp: 45.0000 - val_tn: 1231.0000 - val_fn: 4.0000 - val_accuracy: 0.9740 - val_precision: 0.9304 - val_recall: 0.9934 - val_auc: 0.9971 - val_prc: 0.9924
# Epoch 4/30
# 40/40 [==============================] - 47s 1s/step - loss: 0.0180 - tp: 839.0000 - fp: 34.0000 - tn: 1657.0000 - fn: 5.0000 - accuracy: 0.9846 - precision: 0.9611 - recall: 0.9941 - auc: 0.9990 - prc: 0.9973 - val_loss: 0.0618 - val_tp: 599.0000 - val_fp: 30.0000 - val_tn: 1246.0000 - val_fn: 7.0000 - val_accuracy: 0.9803 - val_precision: 0.9523 - val_recall: 0.9884 - val_auc: 0.9979 - val_prc: 0.9969
# Epoch 5/30
# 40/40 [==============================] - 46s 1s/step - loss: 0.0166 - tp: 840.0000 - fp: 36.0000 - tn: 1655.0000 - fn: 4.0000 - accuracy: 0.9842 - precision: 0.9589 - recall: 0.9953 - auc: 0.9988 - prc: 0.9962 - val_loss: 0.0444 - val_tp: 596.0000 - val_fp: 15.0000 - val_tn: 1261.0000 - val_fn: 10.0000 - val_accuracy: 0.9867 - val_precision: 0.9755 - val_recall: 0.9835 - val_auc: 0.9974 - val_prc: 0.9966
# Epoch 6/30
# 40/40 [==============================] - 48s 1s/step - loss: 0.0161 - tp: 838.0000 - fp: 28.0000 - tn: 1663.0000 - fn: 6.0000 - accuracy: 0.9866 - precision: 0.9677 - recall: 0.9929 - auc: 0.9991 - prc: 0.9974 - val_loss: 0.0624 - val_tp: 601.0000 - val_fp: 33.0000 - val_tn: 1243.0000 - val_fn: 5.0000 - val_accuracy: 0.9798 - val_precision: 0.9479 - val_recall: 0.9917 - val_auc: 0.9974 - val_prc: 0.9939
# Epoch 7/30
# 40/40 [==============================] - 48s 1s/step - loss: 0.0144 - tp: 838.0000 - fp: 31.0000 - tn: 1660.0000 - fn: 6.0000 - accuracy: 0.9854 - precision: 0.9643 - recall: 0.9929 - auc: 0.9995 - prc: 0.9990 - val_loss: 0.0658 - val_tp: 602.0000 - val_fp: 35.0000 - val_tn: 1241.0000 - val_fn: 4.0000 - val_accuracy: 0.9793 - val_precision: 0.9451 - val_recall: 0.9934 - val_auc: 0.9968 - val_prc: 0.9909
#
#
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 7s 214ms/step - loss: 0.0695 - tp: 585.0000 - fp: 29.0000 - tn: 1230.0000 - fn: 5.0000 - accuracy: 0.9816 - precision: 0.9528 - recall: 0.9915 - auc: 0.9963 - prc: 0.9887

# %% [markdown]
# ## With Pose Estimation

# %%
train_generator = train_generator_with_preprocessing_2
val_generator = val_generator_with_preprocessing_2
test_generator = test_generator_with_preprocessing_2
preprocess_fn = resnet50_preprocess
neurons_final = 1024
base_model = create_base_ResNet()
fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))-1
model_name= 'RESNet-50_approach2'#################################
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_40 = 40
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################
base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Done
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_9   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_9 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_9   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_18 (Dropout)        (None, 2048)              0
#
#  dense_18 (Dense)            (None, 1024)              2098176
#
#  dropout_19 (Dropout)        (None, 1024)              0
#
#  dense_19 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 25,686,913
# Trainable params: 2,099,201
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Model Summary:  None

# %%
#Load weights
# model.load_weights('/kaggle/input/vgg19-before-tuning/BeforeFineTuning/VGG19__with_keypoints__before_tuning__10epcohs__64batch.h5')

#Train dense layers
base_model.trainable = False
#Train dense layers:
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS)

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
################################################################################################################
model_name= 'RESNet-50_approach2'#################################
fine_tuning = 'before_tuning'
keypoints_added = 'with_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# Training Started
#
# Epoch 1/10
# 40/40 [==============================] - 119s 3s/step - loss: 2.8273 - tp: 1145.0000 - fp: 855.0000 - tn: 2095.0000 - fn: 289.0000 - accuracy: 0.7391 - precision: 0.5725 - recall: 0.7985 - auc: 0.8176 - prc: 0.7502 - val_loss: 0.8106 - val_tp: 606.0000 - val_fp: 1276.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.3220 - val_precision: 0.3220 - val_recall: 1.0000 - val_auc: 0.9463 - val_prc: 0.9401 - lr: 0.0010
# Epoch 2/10
# 40/40 [==============================] - 113s 3s/step - loss: 0.2488 - tp: 778.0000 - fp: 1110.0000 - tn: 581.0000 - fn: 66.0000 - accuracy: 0.5361 - precision: 0.4121 - recall: 0.9218 - auc: 0.8649 - prc: 0.8376 - val_loss: 0.4997 - val_tp: 546.0000 - val_fp: 101.0000 - val_tn: 1175.0000 - val_fn: 60.0000 - val_accuracy: 0.9145 - val_precision: 0.8439 - val_recall: 0.9010 - val_auc: 0.9654 - val_prc: 0.9561 - lr: 0.0010
# Epoch 3/10
# 40/40 [==============================] - 113s 3s/step - loss: 0.2141 - tp: 744.0000 - fp: 711.0000 - tn: 980.0000 - fn: 100.0000 - accuracy: 0.6801 - precision: 0.5113 - recall: 0.8815 - auc: 0.8837 - prc: 0.8757 - val_loss: 0.4304 - val_tp: 530.0000 - val_fp: 47.0000 - val_tn: 1229.0000 - val_fn: 76.0000 - val_accuracy: 0.9346 - val_precision: 0.9185 - val_recall: 0.8746 - val_auc: 0.9705 - val_prc: 0.9606 - lr: 0.0010
# Epoch 4/10
# 40/40 [==============================] - 113s 3s/step - loss: 0.1891 - tp: 768.0000 - fp: 667.0000 - tn: 1024.0000 - fn: 76.0000 - accuracy: 0.7069 - precision: 0.5352 - recall: 0.9100 - auc: 0.9154 - prc: 0.9084 - val_loss: 0.3879 - val_tp: 521.0000 - val_fp: 24.0000 - val_tn: 1252.0000 - val_fn: 85.0000 - val_accuracy: 0.9421 - val_precision: 0.9560 - val_recall: 0.8597 - val_auc: 0.9734 - val_prc: 0.9641 - lr: 0.0010
# Epoch 5/10
# 40/40 [==============================] - 112s 3s/step - loss: 0.1725 - tp: 757.0000 - fp: 466.0000 - tn: 1225.0000 - fn: 87.0000 - accuracy: 0.7819 - precision: 0.6190 - recall: 0.8969 - auc: 0.9269 - prc: 0.9202 - val_loss: 0.3560 - val_tp: 548.0000 - val_fp: 49.0000 - val_tn: 1227.0000 - val_fn: 58.0000 - val_accuracy: 0.9431 - val_precision: 0.9179 - val_recall: 0.9043 - val_auc: 0.9768 - val_prc: 0.9684 - lr: 0.0010
# Epoch 6/10
# 40/40 [==============================] - 111s 3s/step - loss: 0.1645 - tp: 769.0000 - fp: 456.0000 - tn: 1235.0000 - fn: 75.0000 - accuracy: 0.7905 - precision: 0.6278 - recall: 0.9111 - auc: 0.9352 - prc: 0.9272 - val_loss: 0.3233 - val_tp: 521.0000 - val_fp: 18.0000 - val_tn: 1258.0000 - val_fn: 85.0000 - val_accuracy: 0.9453 - val_precision: 0.9666 - val_recall: 0.8597 - val_auc: 0.9793 - val_prc: 0.9709 - lr: 0.0010
# Epoch 7/10
# 40/40 [==============================] - 110s 3s/step - loss: 0.1549 - tp: 754.0000 - fp: 316.0000 - tn: 1375.0000 - fn: 90.0000 - accuracy: 0.8398 - precision: 0.7047 - recall: 0.8934 - auc: 0.9375 - prc: 0.9292 - val_loss: 0.3762 - val_tp: 577.0000 - val_fp: 179.0000 - val_tn: 1097.0000 - val_fn: 29.0000 - val_accuracy: 0.8895 - val_precision: 0.7632 - val_recall: 0.9521 - val_auc: 0.9792 - val_prc: 0.9712 - lr: 0.0010
# Epoch 8/10
# 40/40 [==============================] - 113s 3s/step - loss: 0.1590 - tp: 761.0000 - fp: 406.0000 - tn: 1285.0000 - fn: 83.0000 - accuracy: 0.8071 - precision: 0.6521 - recall: 0.9017 - auc: 0.9346 - prc: 0.9297 - val_loss: 0.3464 - val_tp: 570.0000 - val_fp: 99.0000 - val_tn: 1177.0000 - val_fn: 36.0000 - val_accuracy: 0.9283 - val_precision: 0.8520 - val_recall: 0.9406 - val_auc: 0.9831 - val_prc: 0.9758 - lr: 0.0010
# Epoch 9/10
# 40/40 [==============================] - 111s 3s/step - loss: 0.1496 - tp: 774.0000 - fp: 352.0000 - tn: 1339.0000 - fn: 70.0000 - accuracy: 0.8335 - precision: 0.6874 - recall: 0.9171 - auc: 0.9478 - prc: 0.9408 - val_loss: 0.2793 - val_tp: 546.0000 - val_fp: 34.0000 - val_tn: 1242.0000 - val_fn: 60.0000 - val_accuracy: 0.9501 - val_precision: 0.9414 - val_recall: 0.9010 - val_auc: 0.9839 - val_prc: 0.9768 - lr: 0.0010
# Epoch 10/10
# 40/40 [==============================] - 109s 3s/step - loss: 0.1493 - tp: 761.0000 - fp: 295.0000 - tn: 1396.0000 - fn: 83.0000 - accuracy: 0.8509 - precision: 0.7206 - recall: 0.9017 - auc: 0.9415 - prc: 0.9367 - val_loss: 0.3381 - val_tp: 579.0000 - val_fp: 126.0000 - val_tn: 1150.0000 - val_fn: 27.0000 - val_accuracy: 0.9187 - val_precision: 0.8213 - val_recall: 0.9554 - val_auc: 0.9842 - val_prc: 0.9771 - lr: 0.0010
# Training Finished
#
#
#
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 37s 1s/step - loss: 0.3406 - tp: 557.0000 - fp: 112.0000 - tn: 1147.0000 - fn: 33.0000 - accuracy: 0.9216 - precision: 0.8326 - recall: 0.9441 - auc: 0.9825 - prc: 0.9744
# /kaggle/working/RESNet-50_approach2_with_keypoints_before_tuning_10epochs.h5

# %%
base_model.trainable = True
# for layer in base_model.layers[:fine_tune_limit]:
#     layer.trainable=False
    
model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# ===================================
# Total params: 25,686,913
# Trainable params: 25,633,793
# Non-trainable params: 53,120
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_9   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_9 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_9   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_18 (Dropout)        (None, 2048)              0
#
#  dense_18 (Dense)            (None, 1024)              2098176
#
#  dropout_19 (Dropout)        (None, 1024)              0
#
#  dense_19 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 25,686,913
# Trainable params: 25,633,793
# Non-trainable params: 53,120
# _________________________________________________________________
# None

# %% [markdown]
# ### Fine Tuning 8 epochs

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_8,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning_8'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'RESNet-50_approach2'#################################
fine_tuning = 'tuning_8epochs'
keypoints_added = 'with_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_8, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_8)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/8
# 40/40 [==============================] - 159s 3s/step - loss: 0.1509 - tp: 1317.0000 - fp: 327.0000 - tn: 2623.0000 - fn: 117.0000 - accuracy: 0.8987 - precision: 0.8011 - recall: 0.9184 - auc: 0.9553 - prc: 0.9501 - val_loss: 0.2561 - val_tp: 526.0000 - val_fp: 2.0000 - val_tn: 1274.0000 - val_fn: 80.0000 - val_accuracy: 0.9564 - val_precision: 0.9962 - val_recall: 0.8680 - val_auc: 0.9900 - val_prc: 0.9839
# Epoch 2/8
# 40/40 [==============================] - 127s 3s/step - loss: 0.1383 - tp: 765.0000 - fp: 144.0000 - tn: 1547.0000 - fn: 79.0000 - accuracy: 0.9120 - precision: 0.8416 - recall: 0.9064 - auc: 0.9512 - prc: 0.9481 - val_loss: 0.2877 - val_tp: 594.0000 - val_fp: 105.0000 - val_tn: 1171.0000 - val_fn: 12.0000 - val_accuracy: 0.9378 - val_precision: 0.8498 - val_recall: 0.9802 - val_auc: 0.9939 - val_prc: 0.9896
# Epoch 3/8
# 40/40 [==============================] - 128s 3s/step - loss: 0.1380 - tp: 768.0000 - fp: 168.0000 - tn: 1523.0000 - fn: 76.0000 - accuracy: 0.9037 - precision: 0.8205 - recall: 0.9100 - auc: 0.9521 - prc: 0.9484 - val_loss: 0.2205 - val_tp: 576.0000 - val_fp: 25.0000 - val_tn: 1251.0000 - val_fn: 30.0000 - val_accuracy: 0.9708 - val_precision: 0.9584 - val_recall: 0.9505 - val_auc: 0.9953 - val_prc: 0.9921
# Epoch 4/8
# 40/40 [==============================] - 128s 3s/step - loss: 0.1061 - tp: 811.0000 - fp: 108.0000 - tn: 1583.0000 - fn: 33.0000 - accuracy: 0.9444 - precision: 0.8825 - recall: 0.9609 - auc: 0.9803 - prc: 0.9761 - val_loss: 0.1293 - val_tp: 540.0000 - val_fp: 0.0000e+00 - val_tn: 1276.0000 - val_fn: 66.0000 - val_accuracy: 0.9649 - val_precision: 1.0000 - val_recall: 0.8911 - val_auc: 0.9948 - val_prc: 0.9914
# Epoch 5/8
# 40/40 [==============================] - 129s 3s/step - loss: 0.1346 - tp: 770.0000 - fp: 132.0000 - tn: 1559.0000 - fn: 74.0000 - accuracy: 0.9187 - precision: 0.8537 - recall: 0.9123 - auc: 0.9541 - prc: 0.9455 - val_loss: 0.1830 - val_tp: 499.0000 - val_fp: 1.0000 - val_tn: 1275.0000 - val_fn: 107.0000 - val_accuracy: 0.9426 - val_precision: 0.9980 - val_recall: 0.8234 - val_auc: 0.9919 - val_prc: 0.9863
# Epoch 6/8
# 40/40 [==============================] - 131s 3s/step - loss: 0.1256 - tp: 774.0000 - fp: 105.0000 - tn: 1586.0000 - fn: 70.0000 - accuracy: 0.9310 - precision: 0.8805 - recall: 0.9171 - auc: 0.9613 - prc: 0.9538 - val_loss: 0.1839 - val_tp: 586.0000 - val_fp: 43.0000 - val_tn: 1233.0000 - val_fn: 20.0000 - val_accuracy: 0.9665 - val_precision: 0.9316 - val_recall: 0.9670 - val_auc: 0.9965 - val_prc: 0.9938
# Epoch 7/8
# 40/40 [==============================] - 132s 3s/step - loss: 0.1032 - tp: 805.0000 - fp: 85.0000 - tn: 1606.0000 - fn: 39.0000 - accuracy: 0.9511 - precision: 0.9045 - recall: 0.9538 - auc: 0.9784 - prc: 0.9747 - val_loss: 0.1602 - val_tp: 594.0000 - val_fp: 63.0000 - val_tn: 1213.0000 - val_fn: 12.0000 - val_accuracy: 0.9601 - val_precision: 0.9041 - val_recall: 0.9802 - val_auc: 0.9968 - val_prc: 0.9945
# Epoch 8/8
# 40/40 [==============================] - 131s 3s/step - loss: 0.0969 - tp: 816.0000 - fp: 83.0000 - tn: 1608.0000 - fn: 28.0000 - accuracy: 0.9562 - precision: 0.9077 - recall: 0.9668 - auc: 0.9837 - prc: 0.9777 - val_loss: 0.1501 - val_tp: 592.0000 - val_fp: 58.0000 - val_tn: 1218.0000 - val_fn: 14.0000 - val_accuracy: 0.9617 - val_precision: 0.9108 - val_recall: 0.9769 - val_auc: 0.9971 - val_prc: 0.9950
#
#
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 39s 1s/step - loss: 0.1547 - tp: 575.0000 - fp: 50.0000 - tn: 1209.0000 - fn: 15.0000 - accuracy: 0.9648 - precision: 0.9200 - recall: 0.9746 - auc: 0.9961 - prc: 0.9908

# %% [markdown]
# ### Fine Tuning 40

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune2 = model.fit(train_generator,
                              epochs=epochs_30,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning_32'
###########################################################################################################

################################################################################################################
model_name= 'RESNet-50_approach2'#################################
fine_tuning = 'tuning_40epochs'
keypoints_added = 'without_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_30, batch_size, history_after_tune2)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_30)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
print("Training Finished")
# Out:
# Epoch 1/30
# 40/40 [==============================] - 132s 3s/step - loss: 0.0956 - tp: 818.0000 - fp: 85.0000 - tn: 1606.0000 - fn: 26.0000 - accuracy: 0.9562 - precision: 0.9059 - recall: 0.9692 - auc: 0.9858 - prc: 0.9830 - val_loss: 0.1296 - val_tp: 592.0000 - val_fp: 48.0000 - val_tn: 1228.0000 - val_fn: 14.0000 - val_accuracy: 0.9671 - val_precision: 0.9250 - val_recall: 0.9769 - val_auc: 0.9974 - val_prc: 0.9955
# Epoch 2/30
# 40/40 [==============================] - 131s 3s/step - loss: 0.0953 - tp: 819.0000 - fp: 105.0000 - tn: 1586.0000 - fn: 25.0000 - accuracy: 0.9487 - precision: 0.8864 - recall: 0.9704 - auc: 0.9867 - prc: 0.9825 - val_loss: 0.1630 - val_tp: 599.0000 - val_fp: 77.0000 - val_tn: 1199.0000 - val_fn: 7.0000 - val_accuracy: 0.9554 - val_precision: 0.8861 - val_recall: 0.9884 - val_auc: 0.9975 - val_prc: 0.9956
# Epoch 3/30
# 40/40 [==============================] - 130s 3s/step - loss: 0.0913 - tp: 829.0000 - fp: 93.0000 - tn: 1598.0000 - fn: 15.0000 - accuracy: 0.9574 - precision: 0.8991 - recall: 0.9822 - auc: 0.9888 - prc: 0.9851 - val_loss: 0.0963 - val_tp: 593.0000 - val_fp: 41.0000 - val_tn: 1235.0000 - val_fn: 13.0000 - val_accuracy: 0.9713 - val_precision: 0.9353 - val_recall: 0.9785 - val_auc: 0.9977 - val_prc: 0.9960
# Epoch 4/30
# 40/40 [==============================] - 130s 3s/step - loss: 0.0844 - tp: 820.0000 - fp: 91.0000 - tn: 1600.0000 - fn: 24.0000 - accuracy: 0.9546 - precision: 0.9001 - recall: 0.9716 - auc: 0.9871 - prc: 0.9829 - val_loss: 0.0775 - val_tp: 592.0000 - val_fp: 28.0000 - val_tn: 1248.0000 - val_fn: 14.0000 - val_accuracy: 0.9777 - val_precision: 0.9548 - val_recall: 0.9769 - val_auc: 0.9975 - val_prc: 0.9958
# Epoch 5/30
# 40/40 [==============================] - 132s 3s/step - loss: 0.0728 - tp: 820.0000 - fp: 87.0000 - tn: 1604.0000 - fn: 24.0000 - accuracy: 0.9562 - precision: 0.9041 - recall: 0.9716 - auc: 0.9887 - prc: 0.9828 - val_loss: 0.1162 - val_tp: 598.0000 - val_fp: 68.0000 - val_tn: 1208.0000 - val_fn: 8.0000 - val_accuracy: 0.9596 - val_precision: 0.8979 - val_recall: 0.9868 - val_auc: 0.9978 - val_prc: 0.9961
# Epoch 6/30
# 40/40 [==============================] - 130s 3s/step - loss: 0.0655 - tp: 831.0000 - fp: 83.0000 - tn: 1608.0000 - fn: 13.0000 - accuracy: 0.9621 - precision: 0.9092 - recall: 0.9846 - auc: 0.9929 - prc: 0.9889 - val_loss: 0.0759 - val_tp: 594.0000 - val_fp: 42.0000 - val_tn: 1234.0000 - val_fn: 12.0000 - val_accuracy: 0.9713 - val_precision: 0.9340 - val_recall: 0.9802 - val_auc: 0.9971 - val_prc: 0.9958
# Epoch 7/30
# 40/40 [==============================] - 128s 3s/step - loss: 0.0664 - tp: 829.0000 - fp: 86.0000 - tn: 1605.0000 - fn: 15.0000 - accuracy: 0.9602 - precision: 0.9060 - recall: 0.9822 - auc: 0.9925 - prc: 0.9880 - val_loss: 0.0590 - val_tp: 591.0000 - val_fp: 15.0000 - val_tn: 1261.0000 - val_fn: 15.0000 - val_accuracy: 0.9841 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9970 - val_prc: 0.9955
# Epoch 8/30
# 40/40 [==============================] - 128s 3s/step - loss: 0.0567 - tp: 826.0000 - fp: 50.0000 - tn: 1641.0000 - fn: 18.0000 - accuracy: 0.9732 - precision: 0.9429 - recall: 0.9787 - auc: 0.9932 - prc: 0.9898 - val_loss: 0.0727 - val_tp: 598.0000 - val_fp: 43.0000 - val_tn: 1233.0000 - val_fn: 8.0000 - val_accuracy: 0.9729 - val_precision: 0.9329 - val_recall: 0.9868 - val_auc: 0.9971 - val_prc: 0.9946
# Epoch 9/30
# 40/40 [==============================] - 127s 3s/step - loss: 0.0555 - tp: 840.0000 - fp: 56.0000 - tn: 1635.0000 - fn: 4.0000 - accuracy: 0.9763 - precision: 0.9375 - recall: 0.9953 - auc: 0.9967 - prc: 0.9932 - val_loss: 0.0641 - val_tp: 591.0000 - val_fp: 30.0000 - val_tn: 1246.0000 - val_fn: 15.0000 - val_accuracy: 0.9761 - val_precision: 0.9517 - val_recall: 0.9752 - val_auc: 0.9970 - val_prc: 0.9942
# Epoch 10/30
# 40/40 [==============================] - 130s 3s/step - loss: 0.0414 - tp: 831.0000 - fp: 50.0000 - tn: 1641.0000 - fn: 13.0000 - accuracy: 0.9751 - precision: 0.9432 - recall: 0.9846 - auc: 0.9965 - prc: 0.9939 - val_loss: 0.0754 - val_tp: 598.0000 - val_fp: 44.0000 - val_tn: 1232.0000 - val_fn: 8.0000 - val_accuracy: 0.9724 - val_precision: 0.9315 - val_recall: 0.9868 - val_auc: 0.9970 - val_prc: 0.9943
# Epoch 11/30
# 40/40 [==============================] - 129s 3s/step - loss: 0.0472 - tp: 834.0000 - fp: 84.0000 - tn: 1607.0000 - fn: 10.0000 - accuracy: 0.9629 - precision: 0.9085 - recall: 0.9882 - auc: 0.9962 - prc: 0.9932 - val_loss: 0.0569 - val_tp: 586.0000 - val_fp: 14.0000 - val_tn: 1262.0000 - val_fn: 20.0000 - val_accuracy: 0.9819 - val_precision: 0.9767 - val_recall: 0.9670 - val_auc: 0.9969 - val_prc: 0.9952
# Epoch 12/30
# 40/40 [==============================] - 129s 3s/step - loss: 0.0461 - tp: 832.0000 - fp: 64.0000 - tn: 1627.0000 - fn: 12.0000 - accuracy: 0.9700 - precision: 0.9286 - recall: 0.9858 - auc: 0.9953 - prc: 0.9915 - val_loss: 0.0582 - val_tp: 594.0000 - val_fp: 25.0000 - val_tn: 1251.0000 - val_fn: 12.0000 - val_accuracy: 0.9803 - val_precision: 0.9596 - val_recall: 0.9802 - val_auc: 0.9974 - val_prc: 0.9949
# Epoch 13/30
# 40/40 [==============================] - 129s 3s/step - loss: 0.0375 - tp: 837.0000 - fp: 42.0000 - tn: 1649.0000 - fn: 7.0000 - accuracy: 0.9807 - precision: 0.9522 - recall: 0.9917 - auc: 0.9968 - prc: 0.9938 - val_loss: 0.0706 - val_tp: 601.0000 - val_fp: 41.0000 - val_tn: 1235.0000 - val_fn: 5.0000 - val_accuracy: 0.9756 - val_precision: 0.9361 - val_recall: 0.9917 - val_auc: 0.9976 - val_prc: 0.9953
# Epoch 14/30
# 40/40 [==============================] - 128s 3s/step - loss: 0.0344 - tp: 840.0000 - fp: 39.0000 - tn: 1652.0000 - fn: 4.0000 - accuracy: 0.9830 - precision: 0.9556 - recall: 0.9953 - auc: 0.9986 - prc: 0.9976 - val_loss: 0.0564 - val_tp: 592.0000 - val_fp: 25.0000 - val_tn: 1251.0000 - val_fn: 14.0000 - val_accuracy: 0.9793 - val_precision: 0.9595 - val_recall: 0.9769 - val_auc: 0.9976 - val_prc: 0.9961
# Epoch 15/30
# 40/40 [==============================] - 128s 3s/step - loss: 0.0330 - tp: 836.0000 - fp: 41.0000 - tn: 1650.0000 - fn: 8.0000 - accuracy: 0.9807 - precision: 0.9532 - recall: 0.9905 - auc: 0.9979 - prc: 0.9956 - val_loss: 0.0640 - val_tp: 596.0000 - val_fp: 27.0000 - val_tn: 1249.0000 - val_fn: 10.0000 - val_accuracy: 0.9803 - val_precision: 0.9567 - val_recall: 0.9835 - val_auc: 0.9971 - val_prc: 0.9933
# Epoch 17/30
# 40/40 [==============================] - 128s 3s/step - loss: 0.0277 - tp: 839.0000 - fp: 40.0000 - tn: 1651.0000 - fn: 5.0000 - accuracy: 0.9822 - precision: 0.9545 - recall: 0.9941 - auc: 0.9984 - prc: 0.9965 - val_loss: 0.0728 - val_tp: 598.0000 - val_fp: 30.0000 - val_tn: 1246.0000 - val_fn: 8.0000 - val_accuracy: 0.9798 - val_precision: 0.9522 - val_recall: 0.9868 - val_auc: 0.9956 - val_prc: 0.9867
# Epoch 18/30
# 40/40 [==============================] - 128s 3s/step - loss: 0.0333 - tp: 839.0000 - fp: 41.0000 - tn: 1650.0000 - fn: 5.0000 - accuracy: 0.9819 - precision: 0.9534 - recall: 0.9941 - auc: 0.9972 - prc: 0.9935 - val_loss: 0.1030 - val_tp: 602.0000 - val_fp: 54.0000 - val_tn: 1222.0000 - val_fn: 4.0000 - val_accuracy: 0.9692 - val_precision: 0.9177 - val_recall: 0.9934 - val_auc: 0.9960 - val_prc: 0.9896
# Epoch 19/30
# 40/40 [==============================] - 129s 3s/step - loss: 0.0276 - tp: 837.0000 - fp: 38.0000 - tn: 1653.0000 - fn: 7.0000 - accuracy: 0.9822 - precision: 0.9566 - recall: 0.9917 - auc: 0.9985 - prc: 0.9974 - val_loss: 0.0714 - val_tp: 600.0000 - val_fp: 34.0000 - val_tn: 1242.0000 - val_fn: 6.0000 - val_accuracy: 0.9787 - val_precision: 0.9464 - val_recall: 0.9901 - val_auc: 0.9971 - val_prc: 0.9944
# Epoch 20/30
# 40/40 [==============================] - 128s 3s/step - loss: 0.0288 - tp: 833.0000 - fp: 44.0000 - tn: 1647.0000 - fn: 11.0000 - accuracy: 0.9783 - precision: 0.9498 - recall: 0.9870 - auc: 0.9980 - prc: 0.9958 - val_loss: 0.0619 - val_tp: 595.0000 - val_fp: 22.0000 - val_tn: 1254.0000 - val_fn: 11.0000 - val_accuracy: 0.9825 - val_precision: 0.9643 - val_recall: 0.9818 - val_auc: 0.9974 - val_prc: 0.9950
# Epoch 21/30
# 40/40 [==============================] - 127s 3s/step - loss: 0.0325 - tp: 836.0000 - fp: 43.0000 - tn: 1648.0000 - fn: 8.0000 - accuracy: 0.9799 - precision: 0.9511 - recall: 0.9905 - auc: 0.9974 - prc: 0.9942 - val_loss: 0.0633 - val_tp: 588.0000 - val_fp: 16.0000 - val_tn: 1260.0000 - val_fn: 18.0000 - val_accuracy: 0.9819 - val_precision: 0.9735 - val_recall: 0.9703 - val_auc: 0.9968 - val_prc: 0.9937
# Training Finished

# %%
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
print("Done")
# Out:
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 37s 1s/step - loss: 0.0571 - tp: 577.0000 - fp: 13.0000 - tn: 1246.0000 - fn: 13.0000 - accuracy: 0.9859 - precision: 0.9780 - recall: 0.9780 - auc: 0.9976 - prc: 0.9961
# Done
