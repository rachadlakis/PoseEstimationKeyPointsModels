# %%
import tensorflow as tf
import tensorflow_hub as hub

import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import zipfile
import sys
import random
import os
from PIL import Image
import pickle#to save the weights of the model
import time
import shutil #to create a zip file

from tensorflow.keras.applications import VGG19, ResNet50, MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import Model, Input 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.image import resize_with_crop_or_pad
from tensorflow import cast, expand_dims, int32, convert_to_tensor, float32
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.preprocessing.image import load_img
# from tensorflow.keras.applications.vgg19 import preprocess_input as vgg19_preprocess #preprocess the images before passing to the model to be as eeach model expects
# from tensorflow.keras.applications.resnet50 import preprocess_input as resnet50_preprocess
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mobilenet_preprocess #rescale images from [0,255] to [-1,1]
from tensorflow.keras import metrics 
from tensorflow.io import read_file
from tensorflow.compat.v1.image import decode_jpeg
from numpy import squeeze
from tensorflow.keras.models import load_model
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
#### Determine fixed variables for model

(img_width, img_height) = (224,224) 
batch_size = 64 # small batch size because the datasset in small
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Load the model from TF hub
pose_model = hub.load('https://tfhub.dev/google/movenet/singlepose/thunder/4') #Thunder is the more accurate version but also larger and slower than Lightning
movenet = pose_model.signatures['serving_default']

# %%
def print_parameters_count(model_):
    import tensorflow.keras.backend as K
    trainable_count = np.sum([K.count_params(w) for w in model_.trainable_weights])
    non_trainable_count = np.sum([K.count_params(w) for w in model_.non_trainable_weights])

    print('Total params: {:,}'.format(trainable_count + non_trainable_count))
    print('Trainable params: {:,}'.format(trainable_count))
    print('Non-trainable params: {:,}'.format(non_trainable_count))

def draw_keypoints(image, keypoints, confidence_threshold):
    # Get the height, width, and channels of the input image
    height, width, channels = image.shape
    # Scale the keypoints to match the size of the input image
    _shaped_keypoints = np.squeeze(np.multiply(keypoints, [height,width,1]))
    
    for kp in _shaped_keypoints:
        ky, kx, kp_conf = kp
        if kp_conf > confidence_threshold:
            cv2.circle(image, (int(kx), int(ky)), 4, (0,255,0), -1)


EDGES = {
    (0, 1): 'm',    (0, 2): 'c',    (1, 3): 'm',    (2, 4): 'c',
    (0, 5): 'm',    (0, 6): 'c',    (5, 7): 'm',    (7, 9): 'm',
    (6, 8): 'c',    (8, 10): 'c',    (5, 6): 'y',    (5, 11): 'm',
    (6, 12): 'c',    (11, 12): 'y',    (11, 13): 'm',    (13, 15): 'm',
    (12, 14): 'c',    (14, 16): 'c'}

def draw_connections(image, keypoints, edges, confidence_threshold):
    # Get the height, width, and channels of the input image
    height,  width, c = image.shape
    # Scale the keypoints to match the size of the input image
    _shaped_keypoints = np.squeeze(np.multiply(keypoints, [height, width,1]))
    
    for edge, color in edges.items():
        p1, p2 = edge
        y1, x1, c1 = _shaped_keypoints[p1]
        y2, x2, c2 = _shaped_keypoints[p2]
        
        if (c1 > confidence_threshold) & (c2 > confidence_threshold):      
            cv2.line(image, (int(x1), int(y1)), (int(x2), int(y2)), (0,0,255), 2)


def print_performance_report(model, test_generator):
    """takes as input a model and DirectoryIterator
    and prints the classification report and the Confusion matrix"""
    y_pred = model.predict(test_generator)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = test_generator.classes
    class_labels=list(test_generator.class_indices.keys())

    print("Classification Report:\n", classification_report(y_true, y_pred_classes, target_names=class_labels))
    print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred_classes))

def get_size(model_path):
        # Get the size of the saved model file in MB
    file_size = os.path.getsize(model_path) / (1024 * 1024)
    return file_size
def delete_files_inside(folder):
    for file in os.listdir(folder):
        os.remove(os.path.join(folder,file)) 

    #Confusion_matrix
def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions>0.5 )
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('Adults Detected (True Negatives): ', cm[0][0])
    print('Child Incorrectly Detected (False Positives): ', cm[0][1])
    print('Child Missed (False Negatives): ', cm[1][0])
    print('Child Detected (True Positives): ', cm[1][1])
    
    
def zip_delete(model_name, path):
    """makes a ziped folder of all the results
    and deleted all the initial folder to make it easier to load the data in /kaggle/working"""
    shutil.make_archive(model_name, 'zip', path)
    delete_files_inside(path)
    os.rmdir(path)
    
def delete_folder_contents(folder_path):
    for root, dirs, files in os.walk(folder_path, topdown=False):
        for file in files:
            os.remove(os.path.join(root, file))
        for dir in dirs:
            os.rmdir(os.path.join(root, dir))
    os.rmdir(folder_path)
    

def plot_save_results(model_, model_name, fine_tuning,with_keypoints, num_epcohs, batch_size, history, save=True, loaded=False):
    #create folder for this model

    dir_name = model_name
    model_detailed_name = f"{model_name}__{with_keypoints}__{fine_tuning}__{num_epcohs}epcohs__{batch_size}batch"
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    mpl.rcParams['figure.figsize'] = (12, 10)
    
    if loaded:
        epochs = range(1, len(history['loss'])+1)
        history_dict = history
    else:
        epochs = range(1, len(history.history['loss'])+1)
        history_dict = history.history
    metrics = [ 'loss','accuracy',  'precision', 'recall','prc', 'auc', 'tp', 'fp', 'tn', 'fn',]
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(len(metrics)//2,2,n +1)
        plt.plot(epochs, history_dict[metric], color=colors[0], label='Train')
        plt.plot(epochs, history_dict['val_'+metric],
                 color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.8,1.1])
        elif metric=='tp' or metric=='fp' or metric=='tn' or metric=='fn':
            plt.ylim([1,np.max(history_dict[metric]) *  1.1 ])
        else:
            plt.ylim([0,1.1])
        
        plt.legend()
    if save:    
        plt.savefig(f"{dir_name}/{model_detailed_name}_{metric}.png")
        # Save the entire model to a file
        model_.save(f"{dir_name}/{model_detailed_name}.h5")

        # Save history to a file
        with open(f"{dir_name}/history_{model_detailed_name}.pickle", "wb") as f:
            pickle.dump(history.history, f)

# %%
# def create_base_VGG19():
#     return VGG19(weights='imagenet',input_shape=(224, 224, 3),include_top=False)
# def create_base_ResNet():
#     return  ResNet50(weights='imagenet', input_shape=(224, 224, 3),include_top=False)
def create_base_MobileNetV2():
    return  MobileNetV2(weights='imagenet', input_shape=(224, 224,3),  include_top=False)

# %%
# Define a preprocessing function to be applied to each image
def preprocess_image_add_pose_keypoints(image_, pose_model=movenet, image_output_shape=(224,224), confidence_threshold=0.15, circle_thickness=3, line_thickness=2 ):
    #check if image is corrupted
    """The function reads a PIL image, converts to numpy array, resize to be able to be processed by the pose model,
    then the pose estimation keypoints are added, then reshaped as the NN model expects.
    source of image transformations: https://tfhub.dev/google/movenet/singlepose/lightning/4"""
#     image_ = cast(resize_with_crop_or_pad(expand_dims(image_, axis=0), 256, 256), dtype=int32)
    image_ = tf.convert_to_tensor(image_, dtype=tf.float32)

    image_ = tf.expand_dims(image_, axis=0)
    # Resize and pad the image to keep the aspect ratio and fit the expected size.
    image_ = tf.cast(tf.image.resize_with_crop_or_pad(image_, 256, 256), dtype=tf.int32)
    if image_.shape[1] != 256 or image_.shape[2] != 256:
        return None
    outputs = pose_model(image_)
    # Reshape the image from (1, 256, 256, 3) to (256, 256, 3) and return an nd-array
    image_ = np.squeeze(image_)
    # Output is a [1, 1, 17, 3] tensor. to numpy array then take the points and reshape
    keypoints_with_scores = outputs['output_0'].numpy()[0,0,:,:51].reshape((17,3))
    #transform to numpy array to add the points and lines since tensorflow does not do that easily
    (height,width) = (image_.shape[0],image_.shape[1])
    #multiply x by height, y by weight (and score by 1)to get the real position on the image
    shaped_keypoints =  np.multiply(keypoints_with_scores, [height,width,1])     
    #########################################################################################################3
    for kp in shaped_keypoints:
        ky, kx, kp_conf = kp
        #print(kp)
        if kp_conf > confidence_threshold:
            cv2.circle(image_, (int(kx), int(ky)), 2, (0,0,0), 3)
    #draw_keypoints(image_array, outputs, confidence_threshold=0.3)
    for edge, color in EDGES.items():
        p1, p2 = edge
        y1, x1, c1 = shaped_keypoints[p1]
        y2, x2, c2 = shaped_keypoints[p2]
        if (c1 > confidence_threshold) & (c2 > confidence_threshold):      
            cv2.line(image_, (int(x1), int(y1)), (int(x2), int(y2)), (0,0,0), 2)
 
    #Resize iamge to fit the model of training
    #should change the output shape of the ouput to be fit to the pretrained mode
    image_ = image_.astype(np.float32)#image does not change
    #When the image is of type float, plt expects it to be in rannge[0,1]
    #ImageDataGenerator class expects a NumPy array as input,
    image_  = cv2.resize(image_,dsize=(image_output_shape[0], image_output_shape[1]))
#     tensor = tf.convert_to_tensor(x_np)

    return image_

# %%
path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/test/Adult/ch1_NVR_ch1_main_20220820210000_20220820220000.mp4_000698bf-a7f8-4572-be6d-6e39b5ee8195.jpg'
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread(path)

# Display the original image
plt.imshow(img)
plt.show()

# Apply the preprocess function
processed_img = preprocess_image_add_pose_keypoints(img)

# Display the processed image
plt.imshow(processed_img/255)
plt.show()

# %%
train_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/train'
validation_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/val'
test_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/test'

############################################################################################################################################
# Create a data generator to load and augment the training data
#Removed rescale from Image data generators, since Using pre
train_datagen_without_preprocessing = ImageDataGenerator(  
    #rescale=1.0/255,  #If using the pre processing fn of the pre trainde models, no need to rescale, and should add featurewise_center=False if so.
    featurewise_center=False, # if using the pre processing of the pre trained models, no need to make featurewise center, and if not false, should fit it before use
    rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest'
)

train_generator_without_preprocessing = train_datagen_without_preprocessing.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False)
# Create a data generator to load the validation data
val_datagen_without_preprocessing = ImageDataGenerator( featurewise_center=False)

val_generator_without_preprocessing = val_datagen_without_preprocessing.flow_from_directory(
    validation_path,
    target_size= (img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
shuffle=False)

#######################################################################################################################################
# Create a data generator to accept the trainign data with the preprocessing function
train_datagen_with_preprocessing = ImageDataGenerator(
    featurewise_center=False,
     rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest',  # fill any missing pixels with the nearest value
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet,
                                                                         image_output_shape=(img_width, img_height),
                                                                         confidence_threshold= 0.05)
)

train_generator_with_preprocessing = train_datagen_with_preprocessing.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)


# Create a data generator to load the validation data with the preprocessing function
val_datagen_with_preprocessing = ImageDataGenerator( 
    featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold=0.05)
)

val_generator_with_preprocessing = val_datagen_with_preprocessing.flow_from_directory(
    validation_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

#######################################################################################################################################
test_datagen_without_preprocessing = ImageDataGenerator( featurewise_center=False,)

#Load the training data
test_generator_without_preprocessing = test_datagen_without_preprocessing.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
###################################
# Create a data generator to accept the trainign data with the preprocessing function
test_datagen_with_preprocessing = ImageDataGenerator( featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold= 0.05)
)

# Load the training data
test_generator_with_preprocessing = test_datagen_with_preprocessing.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 5642 images belonging to 2 classes.
# Found 720 images belonging to 2 classes.
# Found 5642 images belonging to 2 classes.
# Found 720 images belonging to 2 classes.
# Found 674 images belonging to 2 classes.
# Found 674 images belonging to 2 classes.

# %% [markdown]
# # First Approach

# %% [markdown]
# ## Without Pose Estimation key points

# %% [markdown]
# ### Train before Tune

# %%
train_generator = train_generator_without_preprocessing
val_generator = val_generator_without_preprocessing
test_generator = test_generator_without_preprocessing
preprocess_fn = mobilenet_preprocess

neurons_final = 64
base_model = create_base_MobileNetV2()
fine_tune_limit = len(base_model.layers) - int(0.1*len(base_model.layers))
model_name= 'MobileNetV2_light64'
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_30 = 30
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################

base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Done
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 64)                81984
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,340,033
# Trainable params: 82,049
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Model Summary:  None

# %%
counter = Counter(train_generator.classes)
print(str(counter.items())+"\n") # dict_items([(0, 1648), (1, 3614)])
Adult = 3997
Child = 1645
total = Adult + Child
weight_for_Adult =   (total / Adult) 
weight_for_Child =   (total /Child)
weight_for_Adult /= (weight_for_Adult +  weight_for_Child)
weight_for_Child /= (weight_for_Adult +  weight_for_Child)

class_weight = {0: weight_for_Adult, 1: weight_for_Child}
print('Class Weights: ', class_weight)

METRICS = [
      metrics.TruePositives(name='tp'),
      metrics.FalsePositives(name='fp'),
      metrics.TrueNegatives(name='tn'),
      metrics.FalseNegatives(name='fn'), 
      metrics.BinaryAccuracy(name='accuracy'),
      metrics.Precision(name='precision'),
      metrics.Recall(name='recall'),
      metrics.AUC(name='auc'),
      metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]
# Out:
# dict_items([(0, 3997), (1, 1645)])
#
# Class Weights:  {0: 0.2915632754342432, 1: 0.9216512191765469}

# %%
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS)

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################
# Out:
# Training Started
#
# Epoch 1/10
# 88/88 [==============================] - 106s 1s/step - loss: 0.4256 - tp: 1286.0000 - fp: 1272.0000 - tn: 2661.0000 - fn: 359.0000 - accuracy: 0.7076 - precision: 0.5027 - recall: 0.7818 - auc: 0.7775 - prc: 0.6901 - val_loss: 0.2569 - val_tp: 145.0000 - val_fp: 8.0000 - val_tn: 509.0000 - val_fn: 42.0000 - val_accuracy: 0.9290 - val_precision: 0.9477 - val_recall: 0.7754 - val_auc: 0.9543 - val_prc: 0.9347 - lr: 0.0010
# Epoch 2/10
# 88/88 [==============================] - 73s 828ms/step - loss: 0.1580 - tp: 1459.0000 - fp: 582.0000 - tn: 3351.0000 - fn: 186.0000 - accuracy: 0.8623 - precision: 0.7148 - recall: 0.8869 - auc: 0.9333 - prc: 0.8823 - val_loss: 0.1998 - val_tp: 169.0000 - val_fp: 25.0000 - val_tn: 492.0000 - val_fn: 18.0000 - val_accuracy: 0.9389 - val_precision: 0.8711 - val_recall: 0.9037 - val_auc: 0.9707 - val_prc: 0.9518 - lr: 0.0010
# Epoch 3/10
# 88/88 [==============================] - 73s 833ms/step - loss: 0.1160 - tp: 1470.0000 - fp: 307.0000 - tn: 3626.0000 - fn: 175.0000 - accuracy: 0.9136 - precision: 0.8272 - recall: 0.8936 - auc: 0.9625 - prc: 0.9382 - val_loss: 0.1930 - val_tp: 172.0000 - val_fp: 28.0000 - val_tn: 489.0000 - val_fn: 15.0000 - val_accuracy: 0.9389 - val_precision: 0.8600 - val_recall: 0.9198 - val_auc: 0.9810 - val_prc: 0.9634 - lr: 0.0010
# Epoch 4/10
# 88/88 [==============================] - 73s 826ms/step - loss: 0.0961 - tp: 1443.0000 - fp: 310.0000 - tn: 3687.0000 - fn: 138.0000 - accuracy: 0.9197 - precision: 0.8232 - recall: 0.9127 - auc: 0.9748 - prc: 0.9538 - val_loss: 0.1560 - val_tp: 172.0000 - val_fp: 20.0000 - val_tn: 497.0000 - val_fn: 15.0000 - val_accuracy: 0.9503 - val_precision: 0.8958 - val_recall: 0.9198 - val_auc: 0.9846 - val_prc: 0.9690 - lr: 0.0010
# Epoch 5/10
# 88/88 [==============================] - 73s 833ms/step - loss: 0.0911 - tp: 1495.0000 - fp: 272.0000 - tn: 3661.0000 - fn: 150.0000 - accuracy: 0.9243 - precision: 0.8461 - recall: 0.9088 - auc: 0.9784 - prc: 0.9590 - val_loss: 0.1768 - val_tp: 177.0000 - val_fp: 39.0000 - val_tn: 478.0000 - val_fn: 10.0000 - val_accuracy: 0.9304 - val_precision: 0.8194 - val_recall: 0.9465 - val_auc: 0.9879 - val_prc: 0.9736 - lr: 0.0010
# Epoch 6/10
# 88/88 [==============================] - 83s 949ms/step - loss: 0.0805 - tp: 1469.0000 - fp: 286.0000 - tn: 3711.0000 - fn: 112.0000 - accuracy: 0.9286 - precision: 0.8370 - recall: 0.9292 - auc: 0.9821 - prc: 0.9658 - val_loss: 0.1950 - val_tp: 181.0000 - val_fp: 46.0000 - val_tn: 471.0000 - val_fn: 6.0000 - val_accuracy: 0.9261 - val_precision: 0.7974 - val_recall: 0.9679 - val_auc: 0.9894 - val_prc: 0.9759 - lr: 0.0010
# Epoch 7/10
# 88/88 [==============================] - 73s 828ms/step - loss: 0.0774 - tp: 1521.0000 - fp: 229.0000 - tn: 3704.0000 - fn: 124.0000 - accuracy: 0.9367 - precision: 0.8691 - recall: 0.9246 - auc: 0.9839 - prc: 0.9683 - val_loss: 0.1949 - val_tp: 182.0000 - val_fp: 50.0000 - val_tn: 467.0000 - val_fn: 5.0000 - val_accuracy: 0.9219 - val_precision: 0.7845 - val_recall: 0.9733 - val_auc: 0.9903 - val_prc: 0.9776 - lr: 0.0010
# Epoch 8/10
# 88/88 [==============================] - 72s 819ms/step - loss: 0.0734 - tp: 1487.0000 - fp: 292.0000 - tn: 3705.0000 - fn: 94.0000 - accuracy: 0.9308 - precision: 0.8359 - recall: 0.9405 - auc: 0.9855 - prc: 0.9691 - val_loss: 0.1303 - val_tp: 180.0000 - val_fp: 23.0000 - val_tn: 494.0000 - val_fn: 7.0000 - val_accuracy: 0.9574 - val_precision: 0.8867 - val_recall: 0.9626 - val_auc: 0.9920 - val_prc: 0.9810 - lr: 0.0010
# Epoch 9/10
# 88/88 [==============================] - 73s 831ms/step - loss: 0.0628 - tp: 1560.0000 - fp: 216.0000 - tn: 3717.0000 - fn: 85.0000 - accuracy: 0.9460 - precision: 0.8784 - recall: 0.9483 - auc: 0.9895 - prc: 0.9774 - val_loss: 0.0996 - val_tp: 165.0000 - val_fp: 5.0000 - val_tn: 512.0000 - val_fn: 22.0000 - val_accuracy: 0.9616 - val_precision: 0.9706 - val_recall: 0.8824 - val_auc: 0.9920 - val_prc: 0.9813 - lr: 0.0010
# Epoch 10/10
# 88/88 [==============================] - 73s 832ms/step - loss: 0.0710 - tp: 1548.0000 - fp: 242.0000 - tn: 3691.0000 - fn: 97.0000 - accuracy: 0.9392 - precision: 0.8648 - recall: 0.9410 - auc: 0.9866 - prc: 0.9718 - val_loss: 0.1838 - val_tp: 185.0000 - val_fp: 61.0000 - val_tn: 456.0000 - val_fn: 2.0000 - val_accuracy: 0.9105 - val_precision: 0.7520 - val_recall: 0.9893 - val_auc: 0.9925 - val_prc: 0.9816 - lr: 0.0010
# Training Finished

# %%
# delete_folder_contents('/kaggle/working/')

# %%
################################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# /kaggle/working/MobileNetV2_light64_without_keypoints_before_tuning_10epochs.h5

# %%
# model.load_weights('/kaggle/working/RESNet-50_without_keypoints_before_tuning_10epochs.h5')
# model.compile(optimizer=Adam(learning_rate=lr_2), loss= 'binary_crossentropy', metrics=METRICS)

# %%
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)
# Out:
# Evaluation of test Data Generator:
#
#
# 11/11 [==============================] - 6s 563ms/step - loss: 0.1446 - tp: 191.0000 - fp: 44.0000 - tn: 438.0000 - fn: 1.0000 - accuracy: 0.9332 - precision: 0.8128 - recall: 0.9948 - auc: 0.9959 - prc: 0.9905
# [0.14460685849189758,
#  191.0,
#  44.0,
#  438.0,
#  1.0,
#  0.9332343935966492,
#  0.8127659559249878,
#  0.9947916865348816,
#  0.995850682258606,
#  0.9905213713645935]

# %% [markdown]
# ### Fine Tuning

# %%
print_parameters_count(base_model)
# Out:
# Total params: 2,257,984.0
# Trainable params: 0.0
# Non-trainable params: 2,257,984

# %%
base_model.trainable = True
for layer in base_model.layers[:fine_tune_limit]:
    layer.trainable=False
print_parameters_count(base_model)

model.compile(optimizer=Adam(learning_rate=lr_2), loss= 'binary_crossentropy', metrics=METRICS)
print('#######################################################################\n')
print(model.summary())
# Out:
# Total params: 2,257,984
# Trainable params: 1,040,000
# Non-trainable params: 1,217,984
# #######################################################################
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 64)                81984
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,340,033
# Trainable params: 1,122,049
# Non-trainable params: 1,217,984
# _________________________________________________________________
# None

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_fine_tuning,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)

################################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_fine_tuning, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_fine_tuning)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/20
# 89/89 [==============================] - 83s 840ms/step - loss: 0.0606 - tp: 1756.0000 - fp: 300.0000 - tn: 4179.0000 - fn: 81.0000 - accuracy: 0.9397 - precision: 0.8541 - recall: 0.9559 - auc: 0.9906 - prc: 0.9797 - val_loss: 0.1115 - val_tp: 194.0000 - val_fp: 19.0000 - val_tn: 498.0000 - val_fn: 9.0000 - val_accuracy: 0.9611 - val_precision: 0.9108 - val_recall: 0.9557 - val_auc: 0.9932 - val_prc: 0.9842
# Epoch 2/20
# 89/89 [==============================] - 74s 832ms/step - loss: 0.0546 - tp: 1567.0000 - fp: 228.0000 - tn: 3769.0000 - fn: 78.0000 - accuracy: 0.9458 - precision: 0.8730 - recall: 0.9526 - auc: 0.9919 - prc: 0.9832 - val_loss: 0.1730 - val_tp: 200.0000 - val_fp: 40.0000 - val_tn: 477.0000 - val_fn: 3.0000 - val_accuracy: 0.9403 - val_precision: 0.8333 - val_recall: 0.9852 - val_auc: 0.9915 - val_prc: 0.9738
# Epoch 3/20
# 89/89 [==============================] - 75s 846ms/step - loss: 0.0509 - tp: 1568.0000 - fp: 198.0000 - tn: 3799.0000 - fn: 77.0000 - accuracy: 0.9513 - precision: 0.8879 - recall: 0.9532 - auc: 0.9929 - prc: 0.9841 - val_loss: 0.1088 - val_tp: 198.0000 - val_fp: 23.0000 - val_tn: 494.0000 - val_fn: 5.0000 - val_accuracy: 0.9611 - val_precision: 0.8959 - val_recall: 0.9754 - val_auc: 0.9939 - val_prc: 0.9820
# Epoch 4/20
# 89/89 [==============================] - 75s 838ms/step - loss: 0.0499 - tp: 1582.0000 - fp: 200.0000 - tn: 3797.0000 - fn: 63.0000 - accuracy: 0.9534 - precision: 0.8878 - recall: 0.9617 - auc: 0.9931 - prc: 0.9839 - val_loss: 0.1363 - val_tp: 200.0000 - val_fp: 29.0000 - val_tn: 488.0000 - val_fn: 3.0000 - val_accuracy: 0.9556 - val_precision: 0.8734 - val_recall: 0.9852 - val_auc: 0.9927 - val_prc: 0.9764
# Epoch 5/20
# 89/89 [==============================] - 74s 835ms/step - loss: 0.0481 - tp: 1583.0000 - fp: 180.0000 - tn: 3817.0000 - fn: 62.0000 - accuracy: 0.9571 - precision: 0.8979 - recall: 0.9623 - auc: 0.9935 - prc: 0.9860 - val_loss: 0.1133 - val_tp: 198.0000 - val_fp: 23.0000 - val_tn: 494.0000 - val_fn: 5.0000 - val_accuracy: 0.9611 - val_precision: 0.8959 - val_recall: 0.9754 - val_auc: 0.9941 - val_prc: 0.9825
# Epoch 6/20
# 89/89 [==============================] - 74s 829ms/step - loss: 0.0533 - tp: 1577.0000 - fp: 194.0000 - tn: 3803.0000 - fn: 68.0000 - accuracy: 0.9536 - precision: 0.8905 - recall: 0.9587 - auc: 0.9918 - prc: 0.9805 - val_loss: 0.1211 - val_tp: 198.0000 - val_fp: 26.0000 - val_tn: 491.0000 - val_fn: 5.0000 - val_accuracy: 0.9569 - val_precision: 0.8839 - val_recall: 0.9754 - val_auc: 0.9932 - val_prc: 0.9775
# Epoch 7/20
# 89/89 [==============================] - 74s 831ms/step - loss: 0.0459 - tp: 1583.0000 - fp: 169.0000 - tn: 3828.0000 - fn: 62.0000 - accuracy: 0.9591 - precision: 0.9035 - recall: 0.9623 - auc: 0.9938 - prc: 0.9858 - val_loss: 0.0923 - val_tp: 195.0000 - val_fp: 14.0000 - val_tn: 503.0000 - val_fn: 8.0000 - val_accuracy: 0.9694 - val_precision: 0.9330 - val_recall: 0.9606 - val_auc: 0.9946 - val_prc: 0.9836
# Epoch 8/20
# 89/89 [==============================] - 75s 843ms/step - loss: 0.0421 - tp: 1594.0000 - fp: 165.0000 - tn: 3832.0000 - fn: 51.0000 - accuracy: 0.9617 - precision: 0.9062 - recall: 0.9690 - auc: 0.9949 - prc: 0.9889 - val_loss: 0.0930 - val_tp: 196.0000 - val_fp: 15.0000 - val_tn: 502.0000 - val_fn: 7.0000 - val_accuracy: 0.9694 - val_precision: 0.9289 - val_recall: 0.9655 - val_auc: 0.9949 - val_prc: 0.9843
# Epoch 9/20
# 89/89 [==============================] - 76s 852ms/step - loss: 0.0480 - tp: 1587.0000 - fp: 191.0000 - tn: 3806.0000 - fn: 58.0000 - accuracy: 0.9559 - precision: 0.8926 - recall: 0.9647 - auc: 0.9937 - prc: 0.9857 - val_loss: 0.0880 - val_tp: 194.0000 - val_fp: 13.0000 - val_tn: 504.0000 - val_fn: 9.0000 - val_accuracy: 0.9694 - val_precision: 0.9372 - val_recall: 0.9557 - val_auc: 0.9951 - val_prc: 0.9846
# Epoch 10/20
# 89/89 [==============================] - 75s 838ms/step - loss: 0.0368 - tp: 1599.0000 - fp: 107.0000 - tn: 3890.0000 - fn: 46.0000 - accuracy: 0.9729 - precision: 0.9373 - recall: 0.9720 - auc: 0.9964 - prc: 0.9913 - val_loss: 0.1877 - val_tp: 201.0000 - val_fp: 40.0000 - val_tn: 477.0000 - val_fn: 2.0000 - val_accuracy: 0.9417 - val_precision: 0.8340 - val_recall: 0.9901 - val_auc: 0.9899 - val_prc: 0.9594
# Epoch 11/20
# 89/89 [==============================] - 79s 892ms/step - loss: 0.0450 - tp: 1584.0000 - fp: 172.0000 - tn: 3825.0000 - fn: 61.0000 - accuracy: 0.9587 - precision: 0.9021 - recall: 0.9629 - auc: 0.9940 - prc: 0.9833 - val_loss: 0.0843 - val_tp: 195.0000 - val_fp: 12.0000 - val_tn: 505.0000 - val_fn: 8.0000 - val_accuracy: 0.9722 - val_precision: 0.9420 - val_recall: 0.9606 - val_auc: 0.9955 - val_prc: 0.9856
# Epoch 12/20
# 89/89 [==============================] - 80s 898ms/step - loss: 0.0345 - tp: 1600.0000 - fp: 114.0000 - tn: 3883.0000 - fn: 45.0000 - accuracy: 0.9718 - precision: 0.9335 - recall: 0.9726 - auc: 0.9969 - prc: 0.9926 - val_loss: 0.1342 - val_tp: 200.0000 - val_fp: 24.0000 - val_tn: 493.0000 - val_fn: 3.0000 - val_accuracy: 0.9625 - val_precision: 0.8929 - val_recall: 0.9852 - val_auc: 0.9933 - val_prc: 0.9750
# Epoch 13/20
# 89/89 [==============================] - 81s 906ms/step - loss: 0.0366 - tp: 1602.0000 - fp: 146.0000 - tn: 3851.0000 - fn: 43.0000 - accuracy: 0.9665 - precision: 0.9165 - recall: 0.9739 - auc: 0.9963 - prc: 0.9915 - val_loss: 0.1195 - val_tp: 200.0000 - val_fp: 23.0000 - val_tn: 494.0000 - val_fn: 3.0000 - val_accuracy: 0.9639 - val_precision: 0.8969 - val_recall: 0.9852 - val_auc: 0.9945 - val_prc: 0.9806
# Epoch 14/20
# 89/89 [==============================] - 81s 910ms/step - loss: 0.0328 - tp: 1600.0000 - fp: 105.0000 - tn: 3892.0000 - fn: 45.0000 - accuracy: 0.9734 - precision: 0.9384 - recall: 0.9726 - auc: 0.9970 - prc: 0.9922 - val_loss: 0.0805 - val_tp: 198.0000 - val_fp: 13.0000 - val_tn: 504.0000 - val_fn: 5.0000 - val_accuracy: 0.9750 - val_precision: 0.9384 - val_recall: 0.9754 - val_auc: 0.9951 - val_prc: 0.9816
# Epoch 15/20
# 89/89 [==============================] - 80s 898ms/step - loss: 0.0304 - tp: 1606.0000 - fp: 109.0000 - tn: 3888.0000 - fn: 39.0000 - accuracy: 0.9738 - precision: 0.9364 - recall: 0.9763 - auc: 0.9975 - prc: 0.9940 - val_loss: 0.1201 - val_tp: 200.0000 - val_fp: 20.0000 - val_tn: 497.0000 - val_fn: 3.0000 - val_accuracy: 0.9681 - val_precision: 0.9091 - val_recall: 0.9852 - val_auc: 0.9940 - val_prc: 0.9767
# Epoch 16/20
# 89/89 [==============================] - 77s 866ms/step - loss: 0.0289 - tp: 1618.0000 - fp: 113.0000 - tn: 3884.0000 - fn: 27.0000 - accuracy: 0.9752 - precision: 0.9347 - recall: 0.9836 - auc: 0.9974 - prc: 0.9926 - val_loss: 0.0892 - val_tp: 179.0000 - val_fp: 4.0000 - val_tn: 513.0000 - val_fn: 24.0000 - val_accuracy: 0.9611 - val_precision: 0.9781 - val_recall: 0.8818 - val_auc: 0.9966 - val_prc: 0.9911
# Epoch 17/20
# 89/89 [==============================] - 76s 852ms/step - loss: 0.0329 - tp: 1600.0000 - fp: 110.0000 - tn: 3887.0000 - fn: 45.0000 - accuracy: 0.9725 - precision: 0.9357 - recall: 0.9726 - auc: 0.9970 - prc: 0.9931 - val_loss: 0.0994 - val_tp: 199.0000 - val_fp: 15.0000 - val_tn: 502.0000 - val_fn: 4.0000 - val_accuracy: 0.9736 - val_precision: 0.9299 - val_recall: 0.9803 - val_auc: 0.9949 - val_prc: 0.9815
# Epoch 18/20
# 89/89 [==============================] - 75s 839ms/step - loss: 0.0283 - tp: 1613.0000 - fp: 102.0000 - tn: 3895.0000 - fn: 32.0000 - accuracy: 0.9762 - precision: 0.9405 - recall: 0.9805 - auc: 0.9978 - prc: 0.9945 - val_loss: 0.0897 - val_tp: 199.0000 - val_fp: 13.0000 - val_tn: 504.0000 - val_fn: 4.0000 - val_accuracy: 0.9764 - val_precision: 0.9387 - val_recall: 0.9803 - val_auc: 0.9951 - val_prc: 0.9819
# Epoch 19/20
# 89/89 [==============================] - 76s 857ms/step - loss: 0.0324 - tp: 1602.0000 - fp: 115.0000 - tn: 3882.0000 - fn: 43.0000 - accuracy: 0.9720 - precision: 0.9330 - recall: 0.9739 - auc: 0.9967 - prc: 0.9903 - val_loss: 0.1131 - val_tp: 200.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 3.0000 - val_accuracy: 0.9708 - val_precision: 0.9174 - val_recall: 0.9852 - val_auc: 0.9950 - val_prc: 0.9819
# Epoch 20/20
# 89/89 [==============================] - 74s 827ms/step - loss: 0.0322 - tp: 1604.0000 - fp: 118.0000 - tn: 3879.0000 - fn: 41.0000 - accuracy: 0.9718 - precision: 0.9315 - recall: 0.9751 - auc: 0.9969 - prc: 0.9914 - val_loss: 0.0985 - val_tp: 199.0000 - val_fp: 17.0000 - val_tn: 500.0000 - val_fn: 4.0000 - val_accuracy: 0.9708 - val_precision: 0.9213 - val_recall: 0.9803 - val_auc: 0.9951 - val_prc: 0.9820
#
#
# Evaluation of test Data Generator:
#
#
# 11/11 [==============================] - 3s 231ms/step - loss: 0.0501 - tp: 191.0000 - fp: 9.0000 - tn: 473.0000 - fn: 1.0000 - accuracy: 0.9852 - precision: 0.9550 - recall: 0.9948 - auc: 0.9987 - prc: 0.9970

# %% [markdown]
# ## With Pose Estimation key points

# %% [markdown]
# ### Train before Tune

# %%
train_generator = train_generator_with_preprocessing
val_generator = val_generator_with_preprocessing
test_generator = test_generator_with_preprocessing
preprocess_fn = mobilenet_preprocess
neurons_final = 64
base_model = create_base_MobileNetV2()
fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))
model_name= 'MobileNetV2_light64'
fine_tuning = 'before_tuning'
keypoints_added = 'with_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_30 = 30
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")

#####################################################################3
base_model.trainable = False

inputs = Input(shape=(224,224,3))
# x = PreprocessAddKPts()(inputs)
x = preprocess_fn(inputs)
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print( model.summary())
# Out:
# Done
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 64)                81984
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,340,033
# Trainable params: 82,049
# Non-trainable params: 2,257,984
# _________________________________________________________________
# None

# %%
call_backs = [ EarlyStopping(monitor='val_loss', patience=6),
               ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5) ]

model.compile(optimizer=Adam(learning_rate=lr_1),loss= 'binary_crossentropy',metrics=METRICS)

# steps_per_epoch = train_generator.n // batch_size  
# validation_steps = val_generator.n // batch_size
print("Training Started\n\n")   
train_generator.reset()
val_generator.reset()
history = model.fit(train_generator,
                    epochs= epochs_1,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n")

##################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Training Started
#
#
# Epoch 1/10
# 89/89 [==============================] - 175s 2s/step - loss: 0.5350 - tp: 1454.0000 - fp: 1975.0000 - tn: 2504.0000 - fn: 383.0000 - accuracy: 0.6267 - precision: 0.4240 - recall: 0.7915 - auc: 0.7728 - prc: 0.6962 - val_loss: 0.4032 - val_tp: 179.0000 - val_fp: 83.0000 - val_tn: 434.0000 - val_fn: 24.0000 - val_accuracy: 0.8514 - val_precision: 0.6832 - val_recall: 0.8818 - val_auc: 0.9537 - val_prc: 0.9296 - lr: 0.0010
# Epoch 2/10
# 89/89 [==============================] - 168s 2s/step - loss: 0.1747 - tp: 1378.0000 - fp: 648.0000 - tn: 3349.0000 - fn: 267.0000 - accuracy: 0.8378 - precision: 0.6802 - recall: 0.8377 - auc: 0.9095 - prc: 0.8753 - val_loss: 0.4673 - val_tp: 194.0000 - val_fp: 132.0000 - val_tn: 385.0000 - val_fn: 9.0000 - val_accuracy: 0.8042 - val_precision: 0.5951 - val_recall: 0.9557 - val_auc: 0.9687 - val_prc: 0.9492 - lr: 0.0010
# Epoch 3/10
# 89/89 [==============================] - 168s 2s/step - loss: 0.1445 - tp: 1426.0000 - fp: 486.0000 - tn: 3511.0000 - fn: 219.0000 - accuracy: 0.8750 - precision: 0.7458 - recall: 0.8669 - auc: 0.9387 - prc: 0.9156 - val_loss: 0.2437 - val_tp: 182.0000 - val_fp: 41.0000 - val_tn: 476.0000 - val_fn: 21.0000 - val_accuracy: 0.9139 - val_precision: 0.8161 - val_recall: 0.8966 - val_auc: 0.9756 - val_prc: 0.9581 - lr: 0.0010
# Epoch 4/10
# 89/89 [==============================] - 170s 2s/step - loss: 0.1340 - tp: 1441.0000 - fp: 487.0000 - tn: 3510.0000 - fn: 204.0000 - accuracy: 0.8775 - precision: 0.7474 - recall: 0.8760 - auc: 0.9479 - prc: 0.9230 - val_loss: 0.2415 - val_tp: 187.0000 - val_fp: 50.0000 - val_tn: 467.0000 - val_fn: 16.0000 - val_accuracy: 0.9083 - val_precision: 0.7890 - val_recall: 0.9212 - val_auc: 0.9802 - val_prc: 0.9649 - lr: 0.0010
# Epoch 5/10
# 89/89 [==============================] - 170s 2s/step - loss: 0.1188 - tp: 1451.0000 - fp: 320.0000 - tn: 3677.0000 - fn: 194.0000 - accuracy: 0.9089 - precision: 0.8193 - recall: 0.8821 - auc: 0.9592 - prc: 0.9370 - val_loss: 0.3186 - val_tp: 196.0000 - val_fp: 95.0000 - val_tn: 422.0000 - val_fn: 7.0000 - val_accuracy: 0.8583 - val_precision: 0.6735 - val_recall: 0.9655 - val_auc: 0.9820 - val_prc: 0.9679 - lr: 0.0010
# Epoch 6/10
# 89/89 [==============================] - 170s 2s/step - loss: 0.1209 - tp: 1462.0000 - fp: 368.0000 - tn: 3629.0000 - fn: 183.0000 - accuracy: 0.9023 - precision: 0.7989 - recall: 0.8888 - auc: 0.9581 - prc: 0.9316 - val_loss: 0.1835 - val_tp: 184.0000 - val_fp: 29.0000 - val_tn: 488.0000 - val_fn: 19.0000 - val_accuracy: 0.9333 - val_precision: 0.8638 - val_recall: 0.9064 - val_auc: 0.9847 - val_prc: 0.9718 - lr: 0.0010
# Epoch 7/10
# 89/89 [==============================] - 178s 2s/step - loss: 0.1131 - tp: 1473.0000 - fp: 392.0000 - tn: 3605.0000 - fn: 172.0000 - accuracy: 0.9000 - precision: 0.7898 - recall: 0.8954 - auc: 0.9648 - prc: 0.9428 - val_loss: 0.1979 - val_tp: 188.0000 - val_fp: 25.0000 - val_tn: 492.0000 - val_fn: 15.0000 - val_accuracy: 0.9444 - val_precision: 0.8826 - val_recall: 0.9261 - val_auc: 0.9872 - val_prc: 0.9753 - lr: 0.0010
# Epoch 8/10
# 89/89 [==============================] - 172s 2s/step - loss: 0.1023 - tp: 1466.0000 - fp: 278.0000 - tn: 3719.0000 - fn: 179.0000 - accuracy: 0.9190 - precision: 0.8406 - recall: 0.8912 - auc: 0.9716 - prc: 0.9504 - val_loss: 0.1484 - val_tp: 185.0000 - val_fp: 16.0000 - val_tn: 501.0000 - val_fn: 18.0000 - val_accuracy: 0.9528 - val_precision: 0.9204 - val_recall: 0.9113 - val_auc: 0.9875 - val_prc: 0.9765 - lr: 0.0010
# Epoch 9/10
# 89/89 [==============================] - 171s 2s/step - loss: 0.1003 - tp: 1502.0000 - fp: 311.0000 - tn: 3686.0000 - fn: 143.0000 - accuracy: 0.9195 - precision: 0.8285 - recall: 0.9131 - auc: 0.9722 - prc: 0.9503 - val_loss: 0.1337 - val_tp: 170.0000 - val_fp: 3.0000 - val_tn: 514.0000 - val_fn: 33.0000 - val_accuracy: 0.9500 - val_precision: 0.9827 - val_recall: 0.8374 - val_auc: 0.9875 - val_prc: 0.9762 - lr: 0.0010
# Epoch 10/10
# 89/89 [==============================] - 171s 2s/step - loss: 0.0931 - tp: 1501.0000 - fp: 299.0000 - tn: 3698.0000 - fn: 144.0000 - accuracy: 0.9215 - precision: 0.8339 - recall: 0.9125 - auc: 0.9760 - prc: 0.9596 - val_loss: 0.1309 - val_tp: 184.0000 - val_fp: 11.0000 - val_tn: 506.0000 - val_fn: 19.0000 - val_accuracy: 0.9583 - val_precision: 0.9436 - val_recall: 0.9064 - val_auc: 0.9892 - val_prc: 0.9791 - lr: 0.0010
# Training Finished

# %%
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)
# Out:
# Evaluation of test Data Generator:
#
#
# 11/11 [==============================] - 12s 1s/step - loss: 0.1096 - tp: 183.0000 - fp: 11.0000 - tn: 471.0000 - fn: 9.0000 - accuracy: 0.9703 - precision: 0.9433 - recall: 0.9531 - auc: 0.9951 - prc: 0.9890
# [0.10961635410785675,
#  183.0,
#  11.0,
#  471.0,
#  9.0,
#  0.9703264236450195,
#  0.9432989954948425,
#  0.953125,
#  0.9951374530792236,
#  0.9889519214630127]

# %%
# saved_model_before_withKPts_path = '/kaggle/working/{}.h5'.format(name)
# print(saved_model_before_withKPts_path)

# %% [markdown]
# ### Fine Tuning

# %%
# model.load_weights('/kaggle/working/RESNet-50_with_keypoints_before_tuning_10epochs.h5')
# model.compile(optimizer=Adam(learning_rate=lr_1),loss= 'binary_crossentropy',metrics=METRICS)
# model.evaluate(test_generator)

# %%
fine_tuning = 'after_tuning'
base_model.trainable = True
for layer in base_model.layers[:fine_tune_limit]:
    layer.trainable=False


model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('+===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# +===================================
# Total params: 2,340,033
# Trainable params: 1,122,049
# Non-trainable params: 1,217,984
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 64)                81984
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,340,033
# Trainable params: 1,122,049
# Non-trainable params: 1,217,984
# _________________________________________________________________
# None

# %%
#######################################################################################################################33
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
history_after_tune = model.fit(train_generator,
                              epochs=epochs_fine_tuning,
                               #steps_per_epoch=steps_per_epoch,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                               #validation_steps=validation_steps,
                              class_weight=class_weight)

#############################################################################################################33
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)

##########################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_fine_tuning, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_fine_tuning)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0992 - tp: 1651.0000 - fp: 256.0000 - tn: 4223.0000 - fn: 186.0000 - accuracy: 0.9300 - precision: 0.8658 - recall: 0.8987 - auc: 0.9752 - prc: 0.9577 - val_loss: 0.1500 - val_tp: 191.0000 - val_fp: 26.0000 - val_tn: 491.0000 - val_fn: 12.0000 - val_accuracy: 0.9472 - val_precision: 0.8802 - val_recall: 0.9409 - val_auc: 0.9896 - val_prc: 0.9791
# Epoch 2/20
# 89/89 [==============================] - 169s 2s/step - loss: 0.0903 - tp: 1493.0000 - fp: 202.0000 - tn: 3795.0000 - fn: 152.0000 - accuracy: 0.9373 - precision: 0.8808 - recall: 0.9076 - auc: 0.9773 - prc: 0.9605 - val_loss: 0.1262 - val_tp: 187.0000 - val_fp: 12.0000 - val_tn: 505.0000 - val_fn: 16.0000 - val_accuracy: 0.9611 - val_precision: 0.9397 - val_recall: 0.9212 - val_auc: 0.9910 - val_prc: 0.9819
# Epoch 3/20
# 89/89 [==============================] - 170s 2s/step - loss: 0.0849 - tp: 1513.0000 - fp: 242.0000 - tn: 3755.0000 - fn: 132.0000 - accuracy: 0.9337 - precision: 0.8621 - recall: 0.9198 - auc: 0.9804 - prc: 0.9640 - val_loss: 0.1388 - val_tp: 195.0000 - val_fp: 26.0000 - val_tn: 491.0000 - val_fn: 8.0000 - val_accuracy: 0.9528 - val_precision: 0.8824 - val_recall: 0.9606 - val_auc: 0.9906 - val_prc: 0.9808
# Epoch 4/20
# 89/89 [==============================] - 167s 2s/step - loss: 0.0815 - tp: 1503.0000 - fp: 220.0000 - tn: 3777.0000 - fn: 142.0000 - accuracy: 0.9358 - precision: 0.8723 - recall: 0.9137 - auc: 0.9819 - prc: 0.9660 - val_loss: 0.1344 - val_tp: 194.0000 - val_fp: 21.0000 - val_tn: 496.0000 - val_fn: 9.0000 - val_accuracy: 0.9583 - val_precision: 0.9023 - val_recall: 0.9557 - val_auc: 0.9921 - val_prc: 0.9831
# Epoch 5/20
# 89/89 [==============================] - 166s 2s/step - loss: 0.0792 - tp: 1530.0000 - fp: 231.0000 - tn: 3766.0000 - fn: 115.0000 - accuracy: 0.9387 - precision: 0.8688 - recall: 0.9301 - auc: 0.9826 - prc: 0.9693 - val_loss: 0.1517 - val_tp: 197.0000 - val_fp: 32.0000 - val_tn: 485.0000 - val_fn: 6.0000 - val_accuracy: 0.9472 - val_precision: 0.8603 - val_recall: 0.9704 - val_auc: 0.9922 - val_prc: 0.9829
# Epoch 6/20
# 89/89 [==============================] - 166s 2s/step - loss: 0.0732 - tp: 1526.0000 - fp: 205.0000 - tn: 3792.0000 - fn: 119.0000 - accuracy: 0.9426 - precision: 0.8816 - recall: 0.9277 - auc: 0.9854 - prc: 0.9733 - val_loss: 0.1139 - val_tp: 193.0000 - val_fp: 17.0000 - val_tn: 500.0000 - val_fn: 10.0000 - val_accuracy: 0.9625 - val_precision: 0.9190 - val_recall: 0.9507 - val_auc: 0.9927 - val_prc: 0.9844
# Epoch 7/20
# 89/89 [==============================] - 165s 2s/step - loss: 0.0767 - tp: 1514.0000 - fp: 178.0000 - tn: 3819.0000 - fn: 131.0000 - accuracy: 0.9452 - precision: 0.8948 - recall: 0.9204 - auc: 0.9830 - prc: 0.9698 - val_loss: 0.1004 - val_tp: 184.0000 - val_fp: 7.0000 - val_tn: 510.0000 - val_fn: 19.0000 - val_accuracy: 0.9639 - val_precision: 0.9634 - val_recall: 0.9064 - val_auc: 0.9934 - val_prc: 0.9861
# Epoch 8/20
# 89/89 [==============================] - 166s 2s/step - loss: 0.0802 - tp: 1519.0000 - fp: 217.0000 - tn: 3780.0000 - fn: 126.0000 - accuracy: 0.9392 - precision: 0.8750 - recall: 0.9234 - auc: 0.9824 - prc: 0.9652 - val_loss: 0.1211 - val_tp: 194.0000 - val_fp: 19.0000 - val_tn: 498.0000 - val_fn: 9.0000 - val_accuracy: 0.9611 - val_precision: 0.9108 - val_recall: 0.9557 - val_auc: 0.9933 - val_prc: 0.9852
# Epoch 9/20
# 89/89 [==============================] - 166s 2s/step - loss: 0.0671 - tp: 1534.0000 - fp: 176.0000 - tn: 3821.0000 - fn: 111.0000 - accuracy: 0.9491 - precision: 0.8971 - recall: 0.9325 - auc: 0.9880 - prc: 0.9766 - val_loss: 0.1228 - val_tp: 197.0000 - val_fp: 22.0000 - val_tn: 495.0000 - val_fn: 6.0000 - val_accuracy: 0.9611 - val_precision: 0.8995 - val_recall: 0.9704 - val_auc: 0.9929 - val_prc: 0.9806
# Epoch 10/20
# 89/89 [==============================] - 165s 2s/step - loss: 0.0670 - tp: 1539.0000 - fp: 181.0000 - tn: 3816.0000 - fn: 106.0000 - accuracy: 0.9491 - precision: 0.8948 - recall: 0.9356 - auc: 0.9877 - prc: 0.9764 - val_loss: 0.1313 - val_tp: 198.0000 - val_fp: 25.0000 - val_tn: 492.0000 - val_fn: 5.0000 - val_accuracy: 0.9583 - val_precision: 0.8879 - val_recall: 0.9754 - val_auc: 0.9923 - val_prc: 0.9759
# Epoch 11/20
# 89/89 [==============================] - 164s 2s/step - loss: 0.0700 - tp: 1546.0000 - fp: 189.0000 - tn: 3808.0000 - fn: 99.0000 - accuracy: 0.9490 - precision: 0.8911 - recall: 0.9398 - auc: 0.9862 - prc: 0.9742 - val_loss: 0.0954 - val_tp: 191.0000 - val_fp: 9.0000 - val_tn: 508.0000 - val_fn: 12.0000 - val_accuracy: 0.9708 - val_precision: 0.9550 - val_recall: 0.9409 - val_auc: 0.9946 - val_prc: 0.9880
# Epoch 12/20
# 89/89 [==============================] - 167s 2s/step - loss: 0.0661 - tp: 1552.0000 - fp: 205.0000 - tn: 3792.0000 - fn: 93.0000 - accuracy: 0.9472 - precision: 0.8833 - recall: 0.9435 - auc: 0.9880 - prc: 0.9769 - val_loss: 0.1126 - val_tp: 195.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 8.0000 - val_accuracy: 0.9639 - val_precision: 0.9155 - val_recall: 0.9606 - val_auc: 0.9950 - val_prc: 0.9883
# Epoch 13/20
# 89/89 [==============================] - 164s 2s/step - loss: 0.0681 - tp: 1543.0000 - fp: 180.0000 - tn: 3817.0000 - fn: 102.0000 - accuracy: 0.9500 - precision: 0.8955 - recall: 0.9380 - auc: 0.9876 - prc: 0.9771 - val_loss: 0.1368 - val_tp: 199.0000 - val_fp: 26.0000 - val_tn: 491.0000 - val_fn: 4.0000 - val_accuracy: 0.9583 - val_precision: 0.8844 - val_recall: 0.9803 - val_auc: 0.9938 - val_prc: 0.9825
# Epoch 14/20
# 89/89 [==============================] - 163s 2s/step - loss: 0.0626 - tp: 1544.0000 - fp: 167.0000 - tn: 3830.0000 - fn: 101.0000 - accuracy: 0.9525 - precision: 0.9024 - recall: 0.9386 - auc: 0.9895 - prc: 0.9804 - val_loss: 0.1118 - val_tp: 197.0000 - val_fp: 20.0000 - val_tn: 497.0000 - val_fn: 6.0000 - val_accuracy: 0.9639 - val_precision: 0.9078 - val_recall: 0.9704 - val_auc: 0.9943 - val_prc: 0.9836
# Epoch 15/20
# 89/89 [==============================] - 164s 2s/step - loss: 0.0595 - tp: 1556.0000 - fp: 173.0000 - tn: 3824.0000 - fn: 89.0000 - accuracy: 0.9536 - precision: 0.8999 - recall: 0.9459 - auc: 0.9906 - prc: 0.9803 - val_loss: 0.1082 - val_tp: 197.0000 - val_fp: 19.0000 - val_tn: 498.0000 - val_fn: 6.0000 - val_accuracy: 0.9653 - val_precision: 0.9120 - val_recall: 0.9704 - val_auc: 0.9937 - val_prc: 0.9790
# Epoch 16/20
# 89/89 [==============================] - 165s 2s/step - loss: 0.0638 - tp: 1538.0000 - fp: 173.0000 - tn: 3824.0000 - fn: 107.0000 - accuracy: 0.9504 - precision: 0.8989 - recall: 0.9350 - auc: 0.9890 - prc: 0.9781 - val_loss: 0.0862 - val_tp: 187.0000 - val_fp: 6.0000 - val_tn: 511.0000 - val_fn: 16.0000 - val_accuracy: 0.9694 - val_precision: 0.9689 - val_recall: 0.9212 - val_auc: 0.9958 - val_prc: 0.9900
# Epoch 17/20
# 89/89 [==============================] - 165s 2s/step - loss: 0.0596 - tp: 1562.0000 - fp: 156.0000 - tn: 3841.0000 - fn: 83.0000 - accuracy: 0.9576 - precision: 0.9092 - recall: 0.9495 - auc: 0.9901 - prc: 0.9803 - val_loss: 0.0913 - val_tp: 192.0000 - val_fp: 11.0000 - val_tn: 506.0000 - val_fn: 11.0000 - val_accuracy: 0.9694 - val_precision: 0.9458 - val_recall: 0.9458 - val_auc: 0.9961 - val_prc: 0.9904
# Epoch 18/20
# 89/89 [==============================] - 165s 2s/step - loss: 0.0623 - tp: 1547.0000 - fp: 176.0000 - tn: 3821.0000 - fn: 98.0000 - accuracy: 0.9514 - precision: 0.8979 - recall: 0.9404 - auc: 0.9891 - prc: 0.9792 - val_loss: 0.1256 - val_tp: 198.0000 - val_fp: 28.0000 - val_tn: 489.0000 - val_fn: 5.0000 - val_accuracy: 0.9542 - val_precision: 0.8761 - val_recall: 0.9754 - val_auc: 0.9939 - val_prc: 0.9790
# Epoch 19/20
# 89/89 [==============================] - 168s 2s/step - loss: 0.0550 - tp: 1571.0000 - fp: 180.0000 - tn: 3817.0000 - fn: 74.0000 - accuracy: 0.9550 - precision: 0.8972 - recall: 0.9550 - auc: 0.9919 - prc: 0.9816 - val_loss: 0.0916 - val_tp: 195.0000 - val_fp: 12.0000 - val_tn: 505.0000 - val_fn: 8.0000 - val_accuracy: 0.9722 - val_precision: 0.9420 - val_recall: 0.9606 - val_auc: 0.9959 - val_prc: 0.9866
# Epoch 20/20
# 89/89 [==============================] - 164s 2s/step - loss: 0.0584 - tp: 1540.0000 - fp: 135.0000 - tn: 3862.0000 - fn: 105.0000 - accuracy: 0.9575 - precision: 0.9194 - recall: 0.9362 - auc: 0.9907 - prc: 0.9814 - val_loss: 0.1293 - val_tp: 199.0000 - val_fp: 27.0000 - val_tn: 490.0000 - val_fn: 4.0000 - val_accuracy: 0.9569 - val_precision: 0.8805 - val_recall: 0.9803 - val_auc: 0.9940 - val_prc: 0.9794
#
#
# Evaluation of test Data Generator:
#
#
# 11/11 [==============================] - 13s 1s/step - loss: 0.1009 - tp: 190.0000 - fp: 21.0000 - tn: 461.0000 - fn: 2.0000 - accuracy: 0.9659 - precision: 0.9005 - recall: 0.9896 - auc: 0.9975 - prc: 0.9943

# %% [markdown]
# # Second Approach: Unfreeze all layers

# %%
#define generators from second data set
#reapeat trainning of dense layers before unfreezing the model
train_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/train'
validation_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/val'
test_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/test'

############################################################################################################################################
# Create a data generator to load and augment the training data
train_datagen_without_preprocessing_2 = ImageDataGenerator(  
    #rescale=1.0/255,  #If using the pre processing fn of the pre trainde models, no need to rescale, and should add featurewise_center=False if so.
    featurewise_center=False, # if using the pre processing of the pre trained models, no need to make featurewise center, and if not false, should fit it before use
    rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest' )

train_generator_without_preprocessing_2 = train_datagen_without_preprocessing_2.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
# Create a data generator to load the validation data
val_datagen_without_preprocessing_2 = ImageDataGenerator( featurewise_center=False)

val_generator_without_preprocessing_2 = val_datagen_without_preprocessing_2.flow_from_directory(
    validation_path,
    target_size= (img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
shuffle=False )

#######################################################################################################################################
# Create a data generator to accept the trainign data with the preprocessing function
train_datagen_with_preprocessing_2 = ImageDataGenerator(
    featurewise_center=False,
     rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest',  # fill any missing pixels with the nearest value
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet,
                                                                         image_output_shape=(img_width, img_height),
                                                                         confidence_threshold= 0.05) )

train_generator_with_preprocessing_2 = train_datagen_with_preprocessing_2.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )

# Create a data generator to load the validation data with the preprocessing function
val_datagen_with_preprocessing_2 = ImageDataGenerator( 
    featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold=0.05) )

val_generator_with_preprocessing_2 = val_datagen_with_preprocessing_2.flow_from_directory(
    validation_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )

#######################################################################################################################################
test_datagen_without_preprocessing_2 = ImageDataGenerator( featurewise_center=False,)

#Load the training data
test_generator_without_preprocessing_2 = test_datagen_without_preprocessing_2.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
###################################
# Create a data generator to accept the trainign data with the preprocessing function
test_datagen_with_preprocessing_2 = ImageDataGenerator( featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold= 0.05) )

# Load the training data
test_generator_with_preprocessing_2 = test_datagen_with_preprocessing_2.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
# Out:
# Found 2535 images belonging to 2 classes.
# Found 1882 images belonging to 2 classes.
# Found 2535 images belonging to 2 classes.
# Found 1882 images belonging to 2 classes.
# Found 1849 images belonging to 2 classes.
# Found 1849 images belonging to 2 classes.

# %% [markdown]
# ## Wihtout Pose Estimation

# %%
train_generator = train_generator_without_preprocessing_2
val_generator = val_generator_without_preprocessing_2
test_generator = test_generator_without_preprocessing_2
#############################################################
preprocess_fn = mobilenet_preprocess############################
neurons_final = 64########################################
base_model = create_base_MobileNetV2()###########################
# fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))-1
model_name= 'MobileNetV2_light64_approach2'#################################
fine_tuning = 'before_tuning'################################
keypoints_added = 'without_keypoints'
###############################################################
epochs_1 = 10
epochs_fine_tuning = 20
epochs_8 = 8
epochs_40 = 40
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################
base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)###########################################
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Done
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_2 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_2   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 64)                81984
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,340,033
# Trainable params: 82,049
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Model Summary:  None

# %%
counter = Counter(train_generator.classes)
print(str(counter.items())+"\n") # dict_items([(0, 1648), (1, 3614)])
Adult = 3997
Child = 1645
total = Adult + Child
weight_for_Adult =   (total / Adult) 
weight_for_Child =   (total /Child)
weight_for_Adult /= (weight_for_Adult +  weight_for_Child)
weight_for_Child /= (weight_for_Adult +  weight_for_Child)

class_weight = {0: weight_for_Adult, 1: weight_for_Child}
print('Class Weights: ', class_weight)

METRICS = [
      metrics.TruePositives(name='tp'),
      metrics.FalsePositives(name='fp'),
      metrics.TrueNegatives(name='tn'),
      metrics.FalseNegatives(name='fn'), 
      metrics.BinaryAccuracy(name='accuracy'),
      metrics.Precision(name='precision'),
      metrics.Recall(name='recall'),
      metrics.AUC(name='auc'),
      metrics.AUC(name='prc', curve='PR'), ]  # precision-recall curve
# Out:
# dict_items([(0, 1691), (1, 844)])
#
# Class Weights:  {0: 0.2915632754342432, 1: 0.9216512191765469}

# %%
base_model.trainable = False
#Train dense layers:
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS )

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################

################################################################################################################
model_name= 'MobileNetV2_light64_approach2'#################################
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# Training Started
#
# Epoch 1/10
# 40/40 [==============================] - 61s 1s/step - loss: 0.3810 - tp: 619.0000 - fp: 693.0000 - tn: 998.0000 - fn: 225.0000 - accuracy: 0.6379 - precision: 0.4718 - recall: 0.7334 - auc: 0.7149 - prc: 0.5927 - val_loss: 0.5274 - val_tp: 604.0000 - val_fp: 452.0000 - val_tn: 824.0000 - val_fn: 2.0000 - val_accuracy: 0.7588 - val_precision: 0.5720 - val_recall: 0.9967 - val_auc: 0.9683 - val_prc: 0.9438 - lr: 0.0010
# Epoch 2/10
# 40/40 [==============================] - 37s 933ms/step - loss: 0.1693 - tp: 738.0000 - fp: 330.0000 - tn: 1361.0000 - fn: 106.0000 - accuracy: 0.8280 - precision: 0.6910 - recall: 0.8744 - auc: 0.9256 - prc: 0.8839 - val_loss: 0.6368 - val_tp: 603.0000 - val_fp: 520.0000 - val_tn: 756.0000 - val_fn: 3.0000 - val_accuracy: 0.7221 - val_precision: 0.5370 - val_recall: 0.9950 - val_auc: 0.9743 - val_prc: 0.9557 - lr: 0.0010
# Epoch 3/10
# 40/40 [==============================] - 36s 903ms/step - loss: 0.1490 - tp: 768.0000 - fp: 301.0000 - tn: 1390.0000 - fn: 76.0000 - accuracy: 0.8513 - precision: 0.7184 - recall: 0.9100 - auc: 0.9443 - prc: 0.9140 - val_loss: 0.2085 - val_tp: 562.0000 - val_fp: 116.0000 - val_tn: 1160.0000 - val_fn: 44.0000 - val_accuracy: 0.9150 - val_precision: 0.8289 - val_recall: 0.9274 - val_auc: 0.9818 - val_prc: 0.9688 - lr: 0.0010
# Epoch 4/10
# 40/40 [==============================] - 37s 934ms/step - loss: 0.1181 - tp: 775.0000 - fp: 226.0000 - tn: 1465.0000 - fn: 69.0000 - accuracy: 0.8836 - precision: 0.7742 - recall: 0.9182 - auc: 0.9645 - prc: 0.9471 - val_loss: 0.1903 - val_tp: 573.0000 - val_fp: 112.0000 - val_tn: 1164.0000 - val_fn: 33.0000 - val_accuracy: 0.9230 - val_precision: 0.8365 - val_recall: 0.9455 - val_auc: 0.9858 - val_prc: 0.9757 - lr: 0.0010
# Epoch 5/10
# 40/40 [==============================] - 37s 937ms/step - loss: 0.1065 - tp: 778.0000 - fp: 182.0000 - tn: 1509.0000 - fn: 66.0000 - accuracy: 0.9022 - precision: 0.8104 - recall: 0.9218 - auc: 0.9712 - prc: 0.9571 - val_loss: 0.2261 - val_tp: 589.0000 - val_fp: 184.0000 - val_tn: 1092.0000 - val_fn: 17.0000 - val_accuracy: 0.8932 - val_precision: 0.7620 - val_recall: 0.9719 - val_auc: 0.9872 - val_prc: 0.9781 - lr: 0.0010
# Epoch 6/10
# 40/40 [==============================] - 37s 917ms/step - loss: 0.0931 - tp: 789.0000 - fp: 194.0000 - tn: 1497.0000 - fn: 55.0000 - accuracy: 0.9018 - precision: 0.8026 - recall: 0.9348 - auc: 0.9782 - prc: 0.9645 - val_loss: 0.1726 - val_tp: 586.0000 - val_fp: 126.0000 - val_tn: 1150.0000 - val_fn: 20.0000 - val_accuracy: 0.9224 - val_precision: 0.8230 - val_recall: 0.9670 - val_auc: 0.9897 - val_prc: 0.9823 - lr: 0.0010
# Epoch 7/10
# 40/40 [==============================] - 38s 942ms/step - loss: 0.0878 - tp: 780.0000 - fp: 131.0000 - tn: 1560.0000 - fn: 64.0000 - accuracy: 0.9231 - precision: 0.8562 - recall: 0.9242 - auc: 0.9811 - prc: 0.9693 - val_loss: 0.1823 - val_tp: 597.0000 - val_fp: 141.0000 - val_tn: 1135.0000 - val_fn: 9.0000 - val_accuracy: 0.9203 - val_precision: 0.8089 - val_recall: 0.9851 - val_auc: 0.9917 - val_prc: 0.9853 - lr: 0.0010
# Epoch 8/10
# 40/40 [==============================] - 36s 891ms/step - loss: 0.0970 - tp: 797.0000 - fp: 218.0000 - tn: 1473.0000 - fn: 47.0000 - accuracy: 0.8955 - precision: 0.7852 - recall: 0.9443 - auc: 0.9766 - prc: 0.9587 - val_loss: 0.1194 - val_tp: 570.0000 - val_fp: 58.0000 - val_tn: 1218.0000 - val_fn: 36.0000 - val_accuracy: 0.9501 - val_precision: 0.9076 - val_recall: 0.9406 - val_auc: 0.9914 - val_prc: 0.9853 - lr: 0.0010
# Epoch 9/10
# 40/40 [==============================] - 36s 912ms/step - loss: 0.0804 - tp: 799.0000 - fp: 146.0000 - tn: 1545.0000 - fn: 45.0000 - accuracy: 0.9247 - precision: 0.8455 - recall: 0.9467 - auc: 0.9834 - prc: 0.9750 - val_loss: 0.1098 - val_tp: 572.0000 - val_fp: 58.0000 - val_tn: 1218.0000 - val_fn: 34.0000 - val_accuracy: 0.9511 - val_precision: 0.9079 - val_recall: 0.9439 - val_auc: 0.9922 - val_prc: 0.9864 - lr: 0.0010
# Epoch 10/10
# 40/40 [==============================] - 37s 923ms/step - loss: 0.0796 - tp: 792.0000 - fp: 156.0000 - tn: 1535.0000 - fn: 52.0000 - accuracy: 0.9179 - precision: 0.8354 - recall: 0.9384 - auc: 0.9837 - prc: 0.9702 - val_loss: 0.1414 - val_tp: 599.0000 - val_fp: 104.0000 - val_tn: 1172.0000 - val_fn: 7.0000 - val_accuracy: 0.9410 - val_precision: 0.8521 - val_recall: 0.9884 - val_auc: 0.9934 - val_prc: 0.9880 - lr: 0.0010
# Training Finished
#
# /kaggle/working/MobileNetV2_light64_approach2_without_keypoints_before_tuning_10epochs.h5

# %%
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
# Out:
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 13s 438ms/step - loss: 0.1466 - tp: 575.0000 - fp: 107.0000 - tn: 1152.0000 - fn: 15.0000 - accuracy: 0.9340 - precision: 0.8431 - recall: 0.9746 - auc: 0.9920 - prc: 0.9856
# [0.14656302332878113,
#  575.0,
#  107.0,
#  1152.0,
#  15.0,
#  0.9340183734893799,
#  0.8431084752082825,
#  0.9745762944221497,
#  0.9919770956039429,
#  0.9855655431747437]

# %%
base_model.trainable = True
# for layer in base_model.layers[:fine_tune_limit]:
#     layer.trainable=False
    
model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# ===================================
# Total params: 2,340,033
# Trainable params: 2,305,921
# Non-trainable params: 34,112
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_2 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_2   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 64)                81984
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,340,033
# Trainable params: 2,305,921
# Non-trainable params: 34,112
# _________________________________________________________________
# None

# %% [markdown]
# ### Fine Tuning 8 epcohs

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_8,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning_8'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'MobileNetV2_light64_approach2'#################################
fine_tuning = 'tuning_8epochs'
keypoints_added = 'without_keypoints'

plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_8, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_8)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/8
# 40/40 [==============================] - 66s 976ms/step - loss: 0.0828 - tp: 1367.0000 - fp: 244.0000 - tn: 2706.0000 - fn: 67.0000 - accuracy: 0.9291 - precision: 0.8485 - recall: 0.9533 - auc: 0.9868 - prc: 0.9785 - val_loss: 0.1181 - val_tp: 592.0000 - val_fp: 83.0000 - val_tn: 1193.0000 - val_fn: 14.0000 - val_accuracy: 0.9485 - val_precision: 0.8770 - val_recall: 0.9769 - val_auc: 0.9947 - val_prc: 0.9904
# Epoch 2/8
# 40/40 [==============================] - 40s 998ms/step - loss: 0.0624 - tp: 823.0000 - fp: 154.0000 - tn: 1537.0000 - fn: 21.0000 - accuracy: 0.9310 - precision: 0.8424 - recall: 0.9751 - auc: 0.9906 - prc: 0.9813 - val_loss: 0.0915 - val_tp: 595.0000 - val_fp: 62.0000 - val_tn: 1214.0000 - val_fn: 11.0000 - val_accuracy: 0.9612 - val_precision: 0.9056 - val_recall: 0.9818 - val_auc: 0.9954 - val_prc: 0.9923
# Epoch 3/8
# 40/40 [==============================] - 40s 999ms/step - loss: 0.0521 - tp: 818.0000 - fp: 86.0000 - tn: 1605.0000 - fn: 26.0000 - accuracy: 0.9558 - precision: 0.9049 - recall: 0.9692 - auc: 0.9924 - prc: 0.9848 - val_loss: 0.0760 - val_tp: 565.0000 - val_fp: 13.0000 - val_tn: 1263.0000 - val_fn: 41.0000 - val_accuracy: 0.9713 - val_precision: 0.9775 - val_recall: 0.9323 - val_auc: 0.9957 - val_prc: 0.9928
# Epoch 4/8
# 40/40 [==============================] - 40s 989ms/step - loss: 0.0506 - tp: 812.0000 - fp: 86.0000 - tn: 1605.0000 - fn: 32.0000 - accuracy: 0.9535 - precision: 0.9042 - recall: 0.9621 - auc: 0.9937 - prc: 0.9883 - val_loss: 0.1369 - val_tp: 602.0000 - val_fp: 119.0000 - val_tn: 1157.0000 - val_fn: 4.0000 - val_accuracy: 0.9346 - val_precision: 0.8350 - val_recall: 0.9934 - val_auc: 0.9963 - val_prc: 0.9942
# Epoch 5/8
# 40/40 [==============================] - 39s 982ms/step - loss: 0.0536 - tp: 826.0000 - fp: 130.0000 - tn: 1561.0000 - fn: 18.0000 - accuracy: 0.9416 - precision: 0.8640 - recall: 0.9787 - auc: 0.9926 - prc: 0.9845 - val_loss: 0.0702 - val_tp: 594.0000 - val_fp: 35.0000 - val_tn: 1241.0000 - val_fn: 12.0000 - val_accuracy: 0.9750 - val_precision: 0.9444 - val_recall: 0.9802 - val_auc: 0.9970 - val_prc: 0.9953
# Epoch 6/8
# 40/40 [==============================] - 40s 993ms/step - loss: 0.0454 - tp: 824.0000 - fp: 84.0000 - tn: 1607.0000 - fn: 20.0000 - accuracy: 0.9590 - precision: 0.9075 - recall: 0.9763 - auc: 0.9949 - prc: 0.9908 - val_loss: 0.0902 - val_tp: 602.0000 - val_fp: 74.0000 - val_tn: 1202.0000 - val_fn: 4.0000 - val_accuracy: 0.9586 - val_precision: 0.8905 - val_recall: 0.9934 - val_auc: 0.9971 - val_prc: 0.9958
# Epoch 7/8
# 40/40 [==============================] - 40s 1s/step - loss: 0.0461 - tp: 832.0000 - fp: 117.0000 - tn: 1574.0000 - fn: 12.0000 - accuracy: 0.9491 - precision: 0.8767 - recall: 0.9858 - auc: 0.9947 - prc: 0.9898 - val_loss: 0.0601 - val_tp: 596.0000 - val_fp: 30.0000 - val_tn: 1246.0000 - val_fn: 10.0000 - val_accuracy: 0.9787 - val_precision: 0.9521 - val_recall: 0.9835 - val_auc: 0.9975 - val_prc: 0.9963
# Epoch 8/8
# 40/40 [==============================] - 39s 973ms/step - loss: 0.0336 - tp: 826.0000 - fp: 70.0000 - tn: 1621.0000 - fn: 18.0000 - accuracy: 0.9653 - precision: 0.9219 - recall: 0.9787 - auc: 0.9972 - prc: 0.9947 - val_loss: 0.0787 - val_tp: 603.0000 - val_fp: 58.0000 - val_tn: 1218.0000 - val_fn: 3.0000 - val_accuracy: 0.9676 - val_precision: 0.9123 - val_recall: 0.9950 - val_auc: 0.9975 - val_prc: 0.9964
#
#
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 5s 182ms/step - loss: 0.0890 - tp: 583.0000 - fp: 59.0000 - tn: 1200.0000 - fn: 7.0000 - accuracy: 0.9643 - precision: 0.9081 - recall: 0.9881 - auc: 0.9965 - prc: 0.9942

# %% [markdown]
# ### Fine Tuning 40

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune2 = model.fit(train_generator,
                              epochs=epochs_40,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'MobileNetV2_light64_approach2'#################################
fine_tuning = 'tuning_40epochs'
keypoints_added = 'without_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_40, batch_size, history_after_tune2)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_40)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/40
# 40/40 [==============================] - 45s 1s/step - loss: 0.0426 - tp: 829.0000 - fp: 87.0000 - tn: 1604.0000 - fn: 15.0000 - accuracy: 0.9598 - precision: 0.9050 - recall: 0.9822 - auc: 0.9948 - prc: 0.9904 - val_loss: 0.0630 - val_tp: 600.0000 - val_fp: 37.0000 - val_tn: 1239.0000 - val_fn: 6.0000 - val_accuracy: 0.9772 - val_precision: 0.9419 - val_recall: 0.9901 - val_auc: 0.9977 - val_prc: 0.9967
# Epoch 2/40
# 40/40 [==============================] - 40s 988ms/step - loss: 0.0349 - tp: 832.0000 - fp: 66.0000 - tn: 1625.0000 - fn: 12.0000 - accuracy: 0.9692 - precision: 0.9265 - recall: 0.9858 - auc: 0.9969 - prc: 0.9942 - val_loss: 0.0523 - val_tp: 589.0000 - val_fp: 15.0000 - val_tn: 1261.0000 - val_fn: 17.0000 - val_accuracy: 0.9830 - val_precision: 0.9752 - val_recall: 0.9719 - val_auc: 0.9977 - val_prc: 0.9966
# Epoch 3/40
# 40/40 [==============================] - 39s 983ms/step - loss: 0.0256 - tp: 833.0000 - fp: 44.0000 - tn: 1647.0000 - fn: 11.0000 - accuracy: 0.9783 - precision: 0.9498 - recall: 0.9870 - auc: 0.9985 - prc: 0.9971 - val_loss: 0.0479 - val_tp: 587.0000 - val_fp: 14.0000 - val_tn: 1262.0000 - val_fn: 19.0000 - val_accuracy: 0.9825 - val_precision: 0.9767 - val_recall: 0.9686 - val_auc: 0.9979 - val_prc: 0.9969
# Epoch 4/40
# 40/40 [==============================] - 39s 971ms/step - loss: 0.0338 - tp: 827.0000 - fp: 65.0000 - tn: 1626.0000 - fn: 17.0000 - accuracy: 0.9677 - precision: 0.9271 - recall: 0.9799 - auc: 0.9969 - prc: 0.9940 - val_loss: 0.0654 - val_tp: 600.0000 - val_fp: 43.0000 - val_tn: 1233.0000 - val_fn: 6.0000 - val_accuracy: 0.9740 - val_precision: 0.9331 - val_recall: 0.9901 - val_auc: 0.9978 - val_prc: 0.9969
# Epoch 5/40
# 40/40 [==============================] - 39s 971ms/step - loss: 0.0301 - tp: 833.0000 - fp: 62.0000 - tn: 1629.0000 - fn: 11.0000 - accuracy: 0.9712 - precision: 0.9307 - recall: 0.9870 - auc: 0.9975 - prc: 0.9946 - val_loss: 0.0636 - val_tp: 600.0000 - val_fp: 48.0000 - val_tn: 1228.0000 - val_fn: 6.0000 - val_accuracy: 0.9713 - val_precision: 0.9259 - val_recall: 0.9901 - val_auc: 0.9980 - val_prc: 0.9972
# Epoch 6/40
# 40/40 [==============================] - 40s 990ms/step - loss: 0.0246 - tp: 838.0000 - fp: 47.0000 - tn: 1644.0000 - fn: 6.0000 - accuracy: 0.9791 - precision: 0.9469 - recall: 0.9929 - auc: 0.9983 - prc: 0.9960 - val_loss: 0.0481 - val_tp: 599.0000 - val_fp: 21.0000 - val_tn: 1255.0000 - val_fn: 7.0000 - val_accuracy: 0.9851 - val_precision: 0.9661 - val_recall: 0.9884 - val_auc: 0.9981 - val_prc: 0.9973
# Epoch 7/40
# 40/40 [==============================] - 39s 969ms/step - loss: 0.0379 - tp: 829.0000 - fp: 83.0000 - tn: 1608.0000 - fn: 15.0000 - accuracy: 0.9613 - precision: 0.9090 - recall: 0.9822 - auc: 0.9955 - prc: 0.9907 - val_loss: 0.0857 - val_tp: 604.0000 - val_fp: 68.0000 - val_tn: 1208.0000 - val_fn: 2.0000 - val_accuracy: 0.9628 - val_precision: 0.8988 - val_recall: 0.9967 - val_auc: 0.9980 - val_prc: 0.9973
# Epoch 8/40
# 40/40 [==============================] - 39s 973ms/step - loss: 0.0274 - tp: 830.0000 - fp: 54.0000 - tn: 1637.0000 - fn: 14.0000 - accuracy: 0.9732 - precision: 0.9389 - recall: 0.9834 - auc: 0.9982 - prc: 0.9966 - val_loss: 0.0467 - val_tp: 599.0000 - val_fp: 21.0000 - val_tn: 1255.0000 - val_fn: 7.0000 - val_accuracy: 0.9851 - val_precision: 0.9661 - val_recall: 0.9884 - val_auc: 0.9981 - val_prc: 0.9973
# Epoch 9/40
# 40/40 [==============================] - 39s 969ms/step - loss: 0.0222 - tp: 837.0000 - fp: 44.0000 - tn: 1647.0000 - fn: 7.0000 - accuracy: 0.9799 - precision: 0.9501 - recall: 0.9917 - auc: 0.9981 - prc: 0.9948 - val_loss: 0.0413 - val_tp: 595.0000 - val_fp: 15.0000 - val_tn: 1261.0000 - val_fn: 11.0000 - val_accuracy: 0.9862 - val_precision: 0.9754 - val_recall: 0.9818 - val_auc: 0.9982 - val_prc: 0.9975
# Epoch 10/40
# 40/40 [==============================] - 38s 955ms/step - loss: 0.0300 - tp: 829.0000 - fp: 65.0000 - tn: 1626.0000 - fn: 15.0000 - accuracy: 0.9684 - precision: 0.9273 - recall: 0.9822 - auc: 0.9970 - prc: 0.9922 - val_loss: 0.0526 - val_tp: 575.0000 - val_fp: 6.0000 - val_tn: 1270.0000 - val_fn: 31.0000 - val_accuracy: 0.9803 - val_precision: 0.9897 - val_recall: 0.9488 - val_auc: 0.9971 - val_prc: 0.9963
# Epoch 11/40
# 40/40 [==============================] - 39s 974ms/step - loss: 0.0327 - tp: 830.0000 - fp: 72.0000 - tn: 1619.0000 - fn: 14.0000 - accuracy: 0.9661 - precision: 0.9202 - recall: 0.9834 - auc: 0.9968 - prc: 0.9939 - val_loss: 0.0462 - val_tp: 601.0000 - val_fp: 27.0000 - val_tn: 1249.0000 - val_fn: 5.0000 - val_accuracy: 0.9830 - val_precision: 0.9570 - val_recall: 0.9917 - val_auc: 0.9983 - val_prc: 0.9978
# Epoch 12/40
# 40/40 [==============================] - 44s 1s/step - loss: 0.0178 - tp: 839.0000 - fp: 42.0000 - tn: 1649.0000 - fn: 5.0000 - accuracy: 0.9815 - precision: 0.9523 - recall: 0.9941 - auc: 0.9992 - prc: 0.9984 - val_loss: 0.0406 - val_tp: 600.0000 - val_fp: 17.0000 - val_tn: 1259.0000 - val_fn: 6.0000 - val_accuracy: 0.9878 - val_precision: 0.9724 - val_recall: 0.9901 - val_auc: 0.9976 - val_prc: 0.9973
# Epoch 13/40
# 40/40 [==============================] - 39s 971ms/step - loss: 0.0174 - tp: 839.0000 - fp: 37.0000 - tn: 1654.0000 - fn: 5.0000 - accuracy: 0.9834 - precision: 0.9578 - recall: 0.9941 - auc: 0.9992 - prc: 0.9984 - val_loss: 0.0405 - val_tp: 599.0000 - val_fp: 18.0000 - val_tn: 1258.0000 - val_fn: 7.0000 - val_accuracy: 0.9867 - val_precision: 0.9708 - val_recall: 0.9884 - val_auc: 0.9984 - val_prc: 0.9980
# Epoch 14/40
# 40/40 [==============================] - 40s 999ms/step - loss: 0.0214 - tp: 839.0000 - fp: 50.0000 - tn: 1641.0000 - fn: 5.0000 - accuracy: 0.9783 - precision: 0.9438 - recall: 0.9941 - auc: 0.9985 - prc: 0.9964 - val_loss: 0.0542 - val_tp: 566.0000 - val_fp: 1.0000 - val_tn: 1275.0000 - val_fn: 40.0000 - val_accuracy: 0.9782 - val_precision: 0.9982 - val_recall: 0.9340 - val_auc: 0.9976 - val_prc: 0.9972
# Epoch 15/40
# 40/40 [==============================] - 39s 977ms/step - loss: 0.0202 - tp: 838.0000 - fp: 35.0000 - tn: 1656.0000 - fn: 6.0000 - accuracy: 0.9838 - precision: 0.9599 - recall: 0.9929 - auc: 0.9989 - prc: 0.9978 - val_loss: 0.0376 - val_tp: 595.0000 - val_fp: 6.0000 - val_tn: 1270.0000 - val_fn: 11.0000 - val_accuracy: 0.9910 - val_precision: 0.9900 - val_recall: 0.9818 - val_auc: 0.9977 - val_prc: 0.9974
# Epoch 16/40
# 40/40 [==============================] - 39s 985ms/step - loss: 0.0223 - tp: 835.0000 - fp: 39.0000 - tn: 1652.0000 - fn: 9.0000 - accuracy: 0.9811 - precision: 0.9554 - recall: 0.9893 - auc: 0.9984 - prc: 0.9962 - val_loss: 0.0526 - val_tp: 603.0000 - val_fp: 38.0000 - val_tn: 1238.0000 - val_fn: 3.0000 - val_accuracy: 0.9782 - val_precision: 0.9407 - val_recall: 0.9950 - val_auc: 0.9985 - val_prc: 0.9981
# Epoch 17/40
# 40/40 [==============================] - 39s 971ms/step - loss: 0.0178 - tp: 836.0000 - fp: 38.0000 - tn: 1653.0000 - fn: 8.0000 - accuracy: 0.9819 - precision: 0.9565 - recall: 0.9905 - auc: 0.9993 - prc: 0.9986 - val_loss: 0.0436 - val_tp: 603.0000 - val_fp: 30.0000 - val_tn: 1246.0000 - val_fn: 3.0000 - val_accuracy: 0.9825 - val_precision: 0.9526 - val_recall: 0.9950 - val_auc: 0.9986 - val_prc: 0.9983
# Epoch 18/40
# 40/40 [==============================] - 40s 993ms/step - loss: 0.0160 - tp: 841.0000 - fp: 34.0000 - tn: 1657.0000 - fn: 3.0000 - accuracy: 0.9854 - precision: 0.9611 - recall: 0.9964 - auc: 0.9993 - prc: 0.9987 - val_loss: 0.0356 - val_tp: 599.0000 - val_fp: 11.0000 - val_tn: 1265.0000 - val_fn: 7.0000 - val_accuracy: 0.9904 - val_precision: 0.9820 - val_recall: 0.9884 - val_auc: 0.9978 - val_prc: 0.9977
# Epoch 19/40
# 40/40 [==============================] - 40s 990ms/step - loss: 0.0160 - tp: 836.0000 - fp: 28.0000 - tn: 1663.0000 - fn: 8.0000 - accuracy: 0.9858 - precision: 0.9676 - recall: 0.9905 - auc: 0.9988 - prc: 0.9963 - val_loss: 0.0608 - val_tp: 603.0000 - val_fp: 40.0000 - val_tn: 1236.0000 - val_fn: 3.0000 - val_accuracy: 0.9772 - val_precision: 0.9378 - val_recall: 0.9950 - val_auc: 0.9985 - val_prc: 0.9981
# Epoch 20/40
# 40/40 [==============================] - 39s 962ms/step - loss: 0.0163 - tp: 842.0000 - fp: 38.0000 - tn: 1653.0000 - fn: 2.0000 - accuracy: 0.9842 - precision: 0.9568 - recall: 0.9976 - auc: 0.9988 - prc: 0.9964 - val_loss: 0.0340 - val_tp: 596.0000 - val_fp: 6.0000 - val_tn: 1270.0000 - val_fn: 10.0000 - val_accuracy: 0.9915 - val_precision: 0.9900 - val_recall: 0.9835 - val_auc: 0.9979 - val_prc: 0.9977
# Epoch 21/40
# 40/40 [==============================] - 40s 1000ms/step - loss: 0.0143 - tp: 840.0000 - fp: 23.0000 - tn: 1668.0000 - fn: 4.0000 - accuracy: 0.9893 - precision: 0.9733 - recall: 0.9953 - auc: 0.9992 - prc: 0.9978 - val_loss: 0.0390 - val_tp: 603.0000 - val_fp: 23.0000 - val_tn: 1253.0000 - val_fn: 3.0000 - val_accuracy: 0.9862 - val_precision: 0.9633 - val_recall: 0.9950 - val_auc: 0.9979 - val_prc: 0.9978
# Epoch 22/40
# 40/40 [==============================] - 40s 985ms/step - loss: 0.0181 - tp: 839.0000 - fp: 28.0000 - tn: 1663.0000 - fn: 5.0000 - accuracy: 0.9870 - precision: 0.9677 - recall: 0.9941 - auc: 0.9991 - prc: 0.9983 - val_loss: 0.0435 - val_tp: 603.0000 - val_fp: 30.0000 - val_tn: 1246.0000 - val_fn: 3.0000 - val_accuracy: 0.9825 - val_precision: 0.9526 - val_recall: 0.9950 - val_auc: 0.9986 - val_prc: 0.9982
# Epoch 23/40
# 40/40 [==============================] - 39s 971ms/step - loss: 0.0121 - tp: 839.0000 - fp: 21.0000 - tn: 1670.0000 - fn: 5.0000 - accuracy: 0.9897 - precision: 0.9756 - recall: 0.9941 - auc: 0.9996 - prc: 0.9993 - val_loss: 0.0488 - val_tp: 603.0000 - val_fp: 32.0000 - val_tn: 1244.0000 - val_fn: 3.0000 - val_accuracy: 0.9814 - val_precision: 0.9496 - val_recall: 0.9950 - val_auc: 0.9987 - val_prc: 0.9985
# Epoch 24/40
# 40/40 [==============================] - 39s 974ms/step - loss: 0.0146 - tp: 839.0000 - fp: 34.0000 - tn: 1657.0000 - fn: 5.0000 - accuracy: 0.9846 - precision: 0.9611 - recall: 0.9941 - auc: 0.9994 - prc: 0.9988 - val_loss: 0.0301 - val_tp: 600.0000 - val_fp: 7.0000 - val_tn: 1269.0000 - val_fn: 6.0000 - val_accuracy: 0.9931 - val_precision: 0.9885 - val_recall: 0.9901 - val_auc: 0.9980 - val_prc: 0.9979
# Epoch 25/40
# 40/40 [==============================] - 39s 970ms/step - loss: 0.0121 - tp: 840.0000 - fp: 16.0000 - tn: 1675.0000 - fn: 4.0000 - accuracy: 0.9921 - precision: 0.9813 - recall: 0.9953 - auc: 0.9993 - prc: 0.9979 - val_loss: 0.0331 - val_tp: 600.0000 - val_fp: 13.0000 - val_tn: 1263.0000 - val_fn: 6.0000 - val_accuracy: 0.9899 - val_precision: 0.9788 - val_recall: 0.9901 - val_auc: 0.9979 - val_prc: 0.9978
# Epoch 26/40
# 40/40 [==============================] - 40s 985ms/step - loss: 0.0159 - tp: 836.0000 - fp: 25.0000 - tn: 1666.0000 - fn: 8.0000 - accuracy: 0.9870 - precision: 0.9710 - recall: 0.9905 - auc: 0.9988 - prc: 0.9964 - val_loss: 0.0310 - val_tp: 598.0000 - val_fp: 7.0000 - val_tn: 1269.0000 - val_fn: 8.0000 - val_accuracy: 0.9920 - val_precision: 0.9884 - val_recall: 0.9868 - val_auc: 0.9980 - val_prc: 0.9979
# Epoch 27/40
# 40/40 [==============================] - 40s 987ms/step - loss: 0.0139 - tp: 839.0000 - fp: 26.0000 - tn: 1665.0000 - fn: 5.0000 - accuracy: 0.9878 - precision: 0.9699 - recall: 0.9941 - auc: 0.9994 - prc: 0.9988 - val_loss: 0.0374 - val_tp: 591.0000 - val_fp: 2.0000 - val_tn: 1274.0000 - val_fn: 15.0000 - val_accuracy: 0.9910 - val_precision: 0.9966 - val_recall: 0.9752 - val_auc: 0.9972 - val_prc: 0.9972
# Epoch 28/40
# 40/40 [==============================] - 39s 968ms/step - loss: 0.0097 - tp: 840.0000 - fp: 17.0000 - tn: 1674.0000 - fn: 4.0000 - accuracy: 0.9917 - precision: 0.9802 - recall: 0.9953 - auc: 0.9995 - prc: 0.9983 - val_loss: 0.0322 - val_tp: 593.0000 - val_fp: 4.0000 - val_tn: 1272.0000 - val_fn: 13.0000 - val_accuracy: 0.9910 - val_precision: 0.9933 - val_recall: 0.9785 - val_auc: 0.9973 - val_prc: 0.9973
# Epoch 29/40
# 40/40 [==============================] - 40s 995ms/step - loss: 0.0164 - tp: 835.0000 - fp: 26.0000 - tn: 1665.0000 - fn: 9.0000 - accuracy: 0.9862 - precision: 0.9698 - recall: 0.9893 - auc: 0.9987 - prc: 0.9962 - val_loss: 0.0319 - val_tp: 602.0000 - val_fp: 12.0000 - val_tn: 1264.0000 - val_fn: 4.0000 - val_accuracy: 0.9915 - val_precision: 0.9805 - val_recall: 0.9934 - val_auc: 0.9987 - val_prc: 0.9985
# Epoch 30/40
# 40/40 [==============================] - 39s 976ms/step - loss: 0.0139 - tp: 839.0000 - fp: 28.0000 - tn: 1663.0000 - fn: 5.0000 - accuracy: 0.9870 - precision: 0.9677 - recall: 0.9941 - auc: 0.9992 - prc: 0.9977 - val_loss: 0.0482 - val_tp: 603.0000 - val_fp: 26.0000 - val_tn: 1250.0000 - val_fn: 3.0000 - val_accuracy: 0.9846 - val_precision: 0.9587 - val_recall: 0.9950 - val_auc: 0.9983 - val_prc: 0.9968
#
#
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 6s 219ms/step - loss: 0.0651 - tp: 587.0000 - fp: 28.0000 - tn: 1231.0000 - fn: 3.0000 - accuracy: 0.9832 - precision: 0.9545 - recall: 0.9949 - auc: 0.9970 - prc: 0.9912

# %% [markdown]
# ## With Pose Estimation

# %%
train_generator = train_generator_with_preprocessing_2
val_generator = val_generator_with_preprocessing_2
test_generator = test_generator_with_preprocessing_2
preprocess_fn = mobilenet_preprocess
neurons_final = 64
base_model = create_base_MobileNetV2()
fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))-1
model_name= 'RESNet-50_approach2'#################################
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_40 = 40
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################
base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Done
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_3 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_3 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_3   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dropout_6 (Dropout)         (None, 1280)              0
#
#  dense_6 (Dense)             (None, 64)                81984
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,340,033
# Trainable params: 82,049
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Model Summary:  None

# %%
#Load weights
# model.load_weights('/kaggle/input/vgg19-before-tuning/BeforeFineTuning/VGG19__with_keypoints__before_tuning__10epcohs__64batch.h5')

#Train dense layers
base_model.trainable = False
#Train dense layers:
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS)

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
################################################################################################################
model_name= 'MobileNetV2_light64_approach2'#################################
fine_tuning = 'before_tuning'
keypoints_added = 'with_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# Training Started
#
# Epoch 1/10
# 40/40 [==============================] - 110s 3s/step - loss: 0.4759 - tp: 1212.0000 - fp: 1033.0000 - tn: 1917.0000 - fn: 222.0000 - accuracy: 0.7137 - precision: 0.5399 - recall: 0.8452 - auc: 0.8471 - prc: 0.7462 - val_loss: 0.4457 - val_tp: 465.0000 - val_fp: 81.0000 - val_tn: 1195.0000 - val_fn: 141.0000 - val_accuracy: 0.8820 - val_precision: 0.8516 - val_recall: 0.7673 - val_auc: 0.9325 - val_prc: 0.9090 - lr: 0.0010
# Epoch 2/10
# 40/40 [==============================] - 102s 3s/step - loss: 0.2213 - tp: 696.0000 - fp: 526.0000 - tn: 1165.0000 - fn: 148.0000 - accuracy: 0.7341 - precision: 0.5696 - recall: 0.8246 - auc: 0.8655 - prc: 0.8259 - val_loss: 0.3423 - val_tp: 551.0000 - val_fp: 177.0000 - val_tn: 1099.0000 - val_fn: 55.0000 - val_accuracy: 0.8767 - val_precision: 0.7569 - val_recall: 0.9092 - val_auc: 0.9637 - val_prc: 0.9464 - lr: 0.0010
# Epoch 3/10
# 40/40 [==============================] - 102s 3s/step - loss: 0.2018 - tp: 734.0000 - fp: 417.0000 - tn: 1274.0000 - fn: 110.0000 - accuracy: 0.7921 - precision: 0.6377 - recall: 0.8697 - auc: 0.8954 - prc: 0.8514 - val_loss: 0.5167 - val_tp: 597.0000 - val_fp: 479.0000 - val_tn: 797.0000 - val_fn: 9.0000 - val_accuracy: 0.7407 - val_precision: 0.5548 - val_recall: 0.9851 - val_auc: 0.9728 - val_prc: 0.9589 - lr: 0.0010
# Epoch 4/10
# 40/40 [==============================] - 101s 3s/step - loss: 0.1731 - tp: 713.0000 - fp: 244.0000 - tn: 1447.0000 - fn: 131.0000 - accuracy: 0.8521 - precision: 0.7450 - recall: 0.8448 - auc: 0.9219 - prc: 0.8990 - val_loss: 0.3192 - val_tp: 571.0000 - val_fp: 202.0000 - val_tn: 1074.0000 - val_fn: 35.0000 - val_accuracy: 0.8741 - val_precision: 0.7387 - val_recall: 0.9422 - val_auc: 0.9772 - val_prc: 0.9653 - lr: 0.0010
# Epoch 5/10
# 40/40 [==============================] - 101s 3s/step - loss: 0.1588 - tp: 752.0000 - fp: 355.0000 - tn: 1336.0000 - fn: 92.0000 - accuracy: 0.8237 - precision: 0.6793 - recall: 0.8910 - auc: 0.9332 - prc: 0.9179 - val_loss: 0.2165 - val_tp: 533.0000 - val_fp: 34.0000 - val_tn: 1242.0000 - val_fn: 73.0000 - val_accuracy: 0.9431 - val_precision: 0.9400 - val_recall: 0.8795 - val_auc: 0.9786 - val_prc: 0.9667 - lr: 0.0010
# Epoch 6/10
# 40/40 [==============================] - 102s 3s/step - loss: 0.1439 - tp: 747.0000 - fp: 261.0000 - tn: 1430.0000 - fn: 97.0000 - accuracy: 0.8588 - precision: 0.7411 - recall: 0.8851 - auc: 0.9454 - prc: 0.9316 - val_loss: 0.3155 - val_tp: 586.0000 - val_fp: 232.0000 - val_tn: 1044.0000 - val_fn: 20.0000 - val_accuracy: 0.8661 - val_precision: 0.7164 - val_recall: 0.9670 - val_auc: 0.9825 - val_prc: 0.9722 - lr: 0.0010
# Epoch 7/10
# 40/40 [==============================] - 103s 3s/step - loss: 0.1389 - tp: 746.0000 - fp: 236.0000 - tn: 1455.0000 - fn: 98.0000 - accuracy: 0.8682 - precision: 0.7597 - recall: 0.8839 - auc: 0.9491 - prc: 0.9305 - val_loss: 0.2420 - val_tp: 575.0000 - val_fp: 160.0000 - val_tn: 1116.0000 - val_fn: 31.0000 - val_accuracy: 0.8985 - val_precision: 0.7823 - val_recall: 0.9488 - val_auc: 0.9836 - val_prc: 0.9742 - lr: 0.0010
# Epoch 8/10
# 40/40 [==============================] - 101s 3s/step - loss: 0.1304 - tp: 759.0000 - fp: 263.0000 - tn: 1428.0000 - fn: 85.0000 - accuracy: 0.8627 - precision: 0.7427 - recall: 0.8993 - auc: 0.9556 - prc: 0.9393 - val_loss: 0.2708 - val_tp: 589.0000 - val_fp: 184.0000 - val_tn: 1092.0000 - val_fn: 17.0000 - val_accuracy: 0.8932 - val_precision: 0.7620 - val_recall: 0.9719 - val_auc: 0.9859 - val_prc: 0.9772 - lr: 0.0010
# Epoch 9/10
# 40/40 [==============================] - 103s 3s/step - loss: 0.1230 - tp: 770.0000 - fp: 240.0000 - tn: 1451.0000 - fn: 74.0000 - accuracy: 0.8761 - precision: 0.7624 - recall: 0.9123 - auc: 0.9620 - prc: 0.9454 - val_loss: 0.1821 - val_tp: 561.0000 - val_fp: 67.0000 - val_tn: 1209.0000 - val_fn: 45.0000 - val_accuracy: 0.9405 - val_precision: 0.8933 - val_recall: 0.9257 - val_auc: 0.9863 - val_prc: 0.9780 - lr: 0.0010
# Epoch 10/10
# 40/40 [==============================] - 102s 3s/step - loss: 0.1247 - tp: 783.0000 - fp: 268.0000 - tn: 1423.0000 - fn: 61.0000 - accuracy: 0.8702 - precision: 0.7450 - recall: 0.9277 - auc: 0.9619 - prc: 0.9420 - val_loss: 0.1701 - val_tp: 558.0000 - val_fp: 61.0000 - val_tn: 1215.0000 - val_fn: 48.0000 - val_accuracy: 0.9421 - val_precision: 0.9015 - val_recall: 0.9208 - val_auc: 0.9857 - val_prc: 0.9770 - lr: 0.0010
# Training Finished
#
#
#
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 34s 1s/step - loss: 0.1780 - tp: 543.0000 - fp: 61.0000 - tn: 1198.0000 - fn: 47.0000 - accuracy: 0.9416 - precision: 0.8990 - recall: 0.9203 - auc: 0.9831 - prc: 0.9732
# /kaggle/working/MobileNetV2_light64_approach2_with_keypoints_before_tuning_10epochs.h5

# %%
base_model.trainable = True
# for layer in base_model.layers[:fine_tune_limit]:
#     layer.trainable=False
    
model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# ===================================
# Total params: 2,340,033
# Trainable params: 2,305,921
# Non-trainable params: 34,112
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_3 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_3 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_3   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dropout_6 (Dropout)         (None, 1280)              0
#
#  dense_6 (Dense)             (None, 64)                81984
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,340,033
# Trainable params: 2,305,921
# Non-trainable params: 34,112
# _________________________________________________________________
# None

# %% [markdown]
# ### Fine Tuning 8 epochs

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_8,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning_8'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'MobileNetV2_light64_approach2'#################################
fine_tuning = 'tuning_8epochs'
keypoints_added = 'with_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_8, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_8)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/8
# 40/40 [==============================] - 133s 3s/step - loss: 0.1380 - tp: 1292.0000 - fp: 250.0000 - tn: 2700.0000 - fn: 142.0000 - accuracy: 0.9106 - precision: 0.8379 - recall: 0.9010 - auc: 0.9650 - prc: 0.9491 - val_loss: 0.3869 - val_tp: 603.0000 - val_fp: 365.0000 - val_tn: 911.0000 - val_fn: 3.0000 - val_accuracy: 0.8045 - val_precision: 0.6229 - val_recall: 0.9950 - val_auc: 0.9876 - val_prc: 0.9796
# Epoch 2/8
# 40/40 [==============================] - 109s 3s/step - loss: 0.1113 - tp: 768.0000 - fp: 205.0000 - tn: 1486.0000 - fn: 76.0000 - accuracy: 0.8892 - precision: 0.7893 - recall: 0.9100 - auc: 0.9686 - prc: 0.9567 - val_loss: 0.1743 - val_tp: 583.0000 - val_fp: 84.0000 - val_tn: 1192.0000 - val_fn: 23.0000 - val_accuracy: 0.9431 - val_precision: 0.8741 - val_recall: 0.9620 - val_auc: 0.9908 - val_prc: 0.9843
# Epoch 3/8
# 40/40 [==============================] - 109s 3s/step - loss: 0.0919 - tp: 796.0000 - fp: 161.0000 - tn: 1530.0000 - fn: 48.0000 - accuracy: 0.9176 - precision: 0.8318 - recall: 0.9431 - auc: 0.9794 - prc: 0.9689 - val_loss: 0.1745 - val_tp: 592.0000 - val_fp: 107.0000 - val_tn: 1169.0000 - val_fn: 14.0000 - val_accuracy: 0.9357 - val_precision: 0.8469 - val_recall: 0.9769 - val_auc: 0.9921 - val_prc: 0.9864
# Epoch 4/8
# 40/40 [==============================] - 110s 3s/step - loss: 0.0843 - tp: 799.0000 - fp: 156.0000 - tn: 1535.0000 - fn: 45.0000 - accuracy: 0.9207 - precision: 0.8366 - recall: 0.9467 - auc: 0.9828 - prc: 0.9742 - val_loss: 0.1299 - val_tp: 588.0000 - val_fp: 67.0000 - val_tn: 1209.0000 - val_fn: 18.0000 - val_accuracy: 0.9548 - val_precision: 0.8977 - val_recall: 0.9703 - val_auc: 0.9924 - val_prc: 0.9869
# Epoch 5/8
# 40/40 [==============================] - 109s 3s/step - loss: 0.0773 - tp: 799.0000 - fp: 140.0000 - tn: 1551.0000 - fn: 45.0000 - accuracy: 0.9270 - precision: 0.8509 - recall: 0.9467 - auc: 0.9853 - prc: 0.9772 - val_loss: 0.1012 - val_tp: 555.0000 - val_fp: 20.0000 - val_tn: 1256.0000 - val_fn: 51.0000 - val_accuracy: 0.9623 - val_precision: 0.9652 - val_recall: 0.9158 - val_auc: 0.9925 - val_prc: 0.9872
# Epoch 6/8
# 40/40 [==============================] - 109s 3s/step - loss: 0.1002 - tp: 782.0000 - fp: 174.0000 - tn: 1517.0000 - fn: 62.0000 - accuracy: 0.9069 - precision: 0.8180 - recall: 0.9265 - auc: 0.9746 - prc: 0.9623 - val_loss: 0.1134 - val_tp: 568.0000 - val_fp: 33.0000 - val_tn: 1243.0000 - val_fn: 38.0000 - val_accuracy: 0.9623 - val_precision: 0.9451 - val_recall: 0.9373 - val_auc: 0.9938 - val_prc: 0.9891
# Epoch 7/8
# 40/40 [==============================] - 108s 3s/step - loss: 0.0743 - tp: 797.0000 - fp: 130.0000 - tn: 1561.0000 - fn: 47.0000 - accuracy: 0.9302 - precision: 0.8598 - recall: 0.9443 - auc: 0.9864 - prc: 0.9775 - val_loss: 0.0964 - val_tp: 559.0000 - val_fp: 28.0000 - val_tn: 1248.0000 - val_fn: 47.0000 - val_accuracy: 0.9601 - val_precision: 0.9523 - val_recall: 0.9224 - val_auc: 0.9942 - val_prc: 0.9897
# Epoch 8/8
# 40/40 [==============================] - 110s 3s/step - loss: 0.0697 - tp: 802.0000 - fp: 91.0000 - tn: 1600.0000 - fn: 42.0000 - accuracy: 0.9475 - precision: 0.8981 - recall: 0.9502 - auc: 0.9877 - prc: 0.9822 - val_loss: 0.1389 - val_tp: 595.0000 - val_fp: 97.0000 - val_tn: 1179.0000 - val_fn: 11.0000 - val_accuracy: 0.9426 - val_precision: 0.8598 - val_recall: 0.9818 - val_auc: 0.9950 - val_prc: 0.9909
#
#
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 33s 1s/step - loss: 0.1343 - tp: 575.0000 - fp: 89.0000 - tn: 1170.0000 - fn: 15.0000 - accuracy: 0.9438 - precision: 0.8660 - recall: 0.9746 - auc: 0.9946 - prc: 0.9905

# %% [markdown]
# ### Fine Tuning 40

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune2 = model.fit(train_generator,
                              epochs=epochs_40,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning_32'
###########################################################################################################

################################################################################################################
model_name= 'MobileNetV2_light64_approach2'#################################
fine_tuning = 'tuning_40epochs'
keypoints_added = 'without_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_40, batch_size, history_after_tune2)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_40)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
print("Training Finished")
# Out:
# Epoch 1/40
# 40/40 [==============================] - 111s 3s/step - loss: 0.0767 - tp: 808.0000 - fp: 143.0000 - tn: 1548.0000 - fn: 36.0000 - accuracy: 0.9294 - precision: 0.8496 - recall: 0.9573 - auc: 0.9856 - prc: 0.9733 - val_loss: 0.1236 - val_tp: 595.0000 - val_fp: 87.0000 - val_tn: 1189.0000 - val_fn: 11.0000 - val_accuracy: 0.9479 - val_precision: 0.8724 - val_recall: 0.9818 - val_auc: 0.9953 - val_prc: 0.9915
# Epoch 2/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0741 - tp: 810.0000 - fp: 142.0000 - tn: 1549.0000 - fn: 34.0000 - accuracy: 0.9306 - precision: 0.8508 - recall: 0.9597 - auc: 0.9861 - prc: 0.9748 - val_loss: 0.1828 - val_tp: 604.0000 - val_fp: 148.0000 - val_tn: 1128.0000 - val_fn: 2.0000 - val_accuracy: 0.9203 - val_precision: 0.8032 - val_recall: 0.9967 - val_auc: 0.9953 - val_prc: 0.9915
# Epoch 3/40
# 40/40 [==============================] - 108s 3s/step - loss: 0.0651 - tp: 803.0000 - fp: 98.0000 - tn: 1593.0000 - fn: 41.0000 - accuracy: 0.9452 - precision: 0.8912 - recall: 0.9514 - auc: 0.9902 - prc: 0.9841 - val_loss: 0.1186 - val_tp: 596.0000 - val_fp: 90.0000 - val_tn: 1186.0000 - val_fn: 10.0000 - val_accuracy: 0.9469 - val_precision: 0.8688 - val_recall: 0.9835 - val_auc: 0.9959 - val_prc: 0.9925
# Epoch 4/40
# 40/40 [==============================] - 110s 3s/step - loss: 0.0579 - tp: 822.0000 - fp: 122.0000 - tn: 1569.0000 - fn: 22.0000 - accuracy: 0.9432 - precision: 0.8708 - recall: 0.9739 - auc: 0.9917 - prc: 0.9825 - val_loss: 0.0948 - val_tp: 594.0000 - val_fp: 60.0000 - val_tn: 1216.0000 - val_fn: 12.0000 - val_accuracy: 0.9617 - val_precision: 0.9083 - val_recall: 0.9802 - val_auc: 0.9964 - val_prc: 0.9933
# Epoch 5/40
# 40/40 [==============================] - 110s 3s/step - loss: 0.0618 - tp: 811.0000 - fp: 95.0000 - tn: 1596.0000 - fn: 33.0000 - accuracy: 0.9495 - precision: 0.8951 - recall: 0.9609 - auc: 0.9907 - prc: 0.9841 - val_loss: 0.1479 - val_tp: 602.0000 - val_fp: 113.0000 - val_tn: 1163.0000 - val_fn: 4.0000 - val_accuracy: 0.9378 - val_precision: 0.8420 - val_recall: 0.9934 - val_auc: 0.9962 - val_prc: 0.9931
# Epoch 6/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0538 - tp: 816.0000 - fp: 83.0000 - tn: 1608.0000 - fn: 28.0000 - accuracy: 0.9562 - precision: 0.9077 - recall: 0.9668 - auc: 0.9929 - prc: 0.9871 - val_loss: 0.2233 - val_tp: 605.0000 - val_fp: 166.0000 - val_tn: 1110.0000 - val_fn: 1.0000 - val_accuracy: 0.9113 - val_precision: 0.7847 - val_recall: 0.9983 - val_auc: 0.9955 - val_prc: 0.9907
# Epoch 7/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0657 - tp: 821.0000 - fp: 144.0000 - tn: 1547.0000 - fn: 23.0000 - accuracy: 0.9341 - precision: 0.8508 - recall: 0.9727 - auc: 0.9898 - prc: 0.9813 - val_loss: 0.0763 - val_tp: 591.0000 - val_fp: 37.0000 - val_tn: 1239.0000 - val_fn: 15.0000 - val_accuracy: 0.9724 - val_precision: 0.9411 - val_recall: 0.9752 - val_auc: 0.9969 - val_prc: 0.9944
# Epoch 8/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0555 - tp: 810.0000 - fp: 98.0000 - tn: 1593.0000 - fn: 34.0000 - accuracy: 0.9479 - precision: 0.8921 - recall: 0.9597 - auc: 0.9919 - prc: 0.9840 - val_loss: 0.1581 - val_tp: 604.0000 - val_fp: 125.0000 - val_tn: 1151.0000 - val_fn: 2.0000 - val_accuracy: 0.9325 - val_precision: 0.8285 - val_recall: 0.9967 - val_auc: 0.9967 - val_prc: 0.9938
# Epoch 9/40
# 40/40 [==============================] - 110s 3s/step - loss: 0.0530 - tp: 814.0000 - fp: 75.0000 - tn: 1616.0000 - fn: 30.0000 - accuracy: 0.9586 - precision: 0.9156 - recall: 0.9645 - auc: 0.9934 - prc: 0.9873 - val_loss: 0.1405 - val_tp: 602.0000 - val_fp: 113.0000 - val_tn: 1163.0000 - val_fn: 4.0000 - val_accuracy: 0.9378 - val_precision: 0.8420 - val_recall: 0.9934 - val_auc: 0.9966 - val_prc: 0.9926
# Epoch 10/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0550 - tp: 817.0000 - fp: 93.0000 - tn: 1598.0000 - fn: 27.0000 - accuracy: 0.9527 - precision: 0.8978 - recall: 0.9680 - auc: 0.9922 - prc: 0.9863 - val_loss: 0.1397 - val_tp: 604.0000 - val_fp: 119.0000 - val_tn: 1157.0000 - val_fn: 2.0000 - val_accuracy: 0.9357 - val_precision: 0.8354 - val_recall: 0.9967 - val_auc: 0.9969 - val_prc: 0.9942
# Epoch 11/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0486 - tp: 820.0000 - fp: 92.0000 - tn: 1599.0000 - fn: 24.0000 - accuracy: 0.9542 - precision: 0.8991 - recall: 0.9716 - auc: 0.9934 - prc: 0.9883 - val_loss: 0.2091 - val_tp: 604.0000 - val_fp: 147.0000 - val_tn: 1129.0000 - val_fn: 2.0000 - val_accuracy: 0.9208 - val_precision: 0.8043 - val_recall: 0.9967 - val_auc: 0.9959 - val_prc: 0.9904
# Epoch 12/40
# 40/40 [==============================] - 110s 3s/step - loss: 0.0486 - tp: 826.0000 - fp: 94.0000 - tn: 1597.0000 - fn: 18.0000 - accuracy: 0.9558 - precision: 0.8978 - recall: 0.9787 - auc: 0.9941 - prc: 0.9879 - val_loss: 0.0731 - val_tp: 595.0000 - val_fp: 48.0000 - val_tn: 1228.0000 - val_fn: 11.0000 - val_accuracy: 0.9687 - val_precision: 0.9253 - val_recall: 0.9818 - val_auc: 0.9975 - val_prc: 0.9954
# Epoch 13/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0528 - tp: 813.0000 - fp: 93.0000 - tn: 1598.0000 - fn: 31.0000 - accuracy: 0.9511 - precision: 0.8974 - recall: 0.9633 - auc: 0.9931 - prc: 0.9883 - val_loss: 0.1089 - val_tp: 602.0000 - val_fp: 94.0000 - val_tn: 1182.0000 - val_fn: 4.0000 - val_accuracy: 0.9479 - val_precision: 0.8649 - val_recall: 0.9934 - val_auc: 0.9973 - val_prc: 0.9951
# Epoch 14/40
# 40/40 [==============================] - 110s 3s/step - loss: 0.0458 - tp: 823.0000 - fp: 74.0000 - tn: 1617.0000 - fn: 21.0000 - accuracy: 0.9625 - precision: 0.9175 - recall: 0.9751 - auc: 0.9945 - prc: 0.9890 - val_loss: 0.0758 - val_tp: 600.0000 - val_fp: 53.0000 - val_tn: 1223.0000 - val_fn: 6.0000 - val_accuracy: 0.9687 - val_precision: 0.9188 - val_recall: 0.9901 - val_auc: 0.9975 - val_prc: 0.9954
# Epoch 15/40
# 40/40 [==============================] - 110s 3s/step - loss: 0.0465 - tp: 829.0000 - fp: 88.0000 - tn: 1603.0000 - fn: 15.0000 - accuracy: 0.9594 - precision: 0.9040 - recall: 0.9822 - auc: 0.9946 - prc: 0.9892 - val_loss: 0.0648 - val_tp: 594.0000 - val_fp: 41.0000 - val_tn: 1235.0000 - val_fn: 12.0000 - val_accuracy: 0.9718 - val_precision: 0.9354 - val_recall: 0.9802 - val_auc: 0.9971 - val_prc: 0.9953
# Epoch 16/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0449 - tp: 824.0000 - fp: 89.0000 - tn: 1602.0000 - fn: 20.0000 - accuracy: 0.9570 - precision: 0.9025 - recall: 0.9763 - auc: 0.9951 - prc: 0.9914 - val_loss: 0.0591 - val_tp: 585.0000 - val_fp: 21.0000 - val_tn: 1255.0000 - val_fn: 21.0000 - val_accuracy: 0.9777 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9971 - val_prc: 0.9953
# Epoch 17/40
# 40/40 [==============================] - 108s 3s/step - loss: 0.0588 - tp: 807.0000 - fp: 90.0000 - tn: 1601.0000 - fn: 37.0000 - accuracy: 0.9499 - precision: 0.8997 - recall: 0.9562 - auc: 0.9905 - prc: 0.9807 - val_loss: 0.0691 - val_tp: 583.0000 - val_fp: 22.0000 - val_tn: 1254.0000 - val_fn: 23.0000 - val_accuracy: 0.9761 - val_precision: 0.9636 - val_recall: 0.9620 - val_auc: 0.9976 - val_prc: 0.9957
# Epoch 18/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0399 - tp: 820.0000 - fp: 61.0000 - tn: 1630.0000 - fn: 24.0000 - accuracy: 0.9665 - precision: 0.9308 - recall: 0.9716 - auc: 0.9963 - prc: 0.9937 - val_loss: 0.1517 - val_tp: 603.0000 - val_fp: 117.0000 - val_tn: 1159.0000 - val_fn: 3.0000 - val_accuracy: 0.9362 - val_precision: 0.8375 - val_recall: 0.9950 - val_auc: 0.9969 - val_prc: 0.9934
# Epoch 19/40
# 40/40 [==============================] - 108s 3s/step - loss: 0.0549 - tp: 819.0000 - fp: 120.0000 - tn: 1571.0000 - fn: 25.0000 - accuracy: 0.9428 - precision: 0.8722 - recall: 0.9704 - auc: 0.9920 - prc: 0.9805 - val_loss: 0.0902 - val_tp: 600.0000 - val_fp: 72.0000 - val_tn: 1204.0000 - val_fn: 6.0000 - val_accuracy: 0.9586 - val_precision: 0.8929 - val_recall: 0.9901 - val_auc: 0.9976 - val_prc: 0.9958
# Epoch 20/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0388 - tp: 825.0000 - fp: 62.0000 - tn: 1629.0000 - fn: 19.0000 - accuracy: 0.9680 - precision: 0.9301 - recall: 0.9775 - auc: 0.9963 - prc: 0.9924 - val_loss: 0.0660 - val_tp: 596.0000 - val_fp: 43.0000 - val_tn: 1233.0000 - val_fn: 10.0000 - val_accuracy: 0.9718 - val_precision: 0.9327 - val_recall: 0.9835 - val_auc: 0.9973 - val_prc: 0.9959
# Epoch 21/40
# 40/40 [==============================] - 109s 3s/step - loss: 0.0345 - tp: 825.0000 - fp: 48.0000 - tn: 1643.0000 - fn: 19.0000 - accuracy: 0.9736 - precision: 0.9450 - recall: 0.9775 - auc: 0.9966 - prc: 0.9949 - val_loss: 0.1914 - val_tp: 604.0000 - val_fp: 135.0000 - val_tn: 1141.0000 - val_fn: 2.0000 - val_accuracy: 0.9272 - val_precision: 0.8173 - val_recall: 0.9967 - val_auc: 0.9951 - val_prc: 0.9852
# Epoch 22/40
# 40/40 [==============================] - 108s 3s/step - loss: 0.0459 - tp: 822.0000 - fp: 78.0000 - tn: 1613.0000 - fn: 22.0000 - accuracy: 0.9606 - precision: 0.9133 - recall: 0.9739 - auc: 0.9942 - prc: 0.9864 - val_loss: 0.1225 - val_tp: 603.0000 - val_fp: 98.0000 - val_tn: 1178.0000 - val_fn: 3.0000 - val_accuracy: 0.9463 - val_precision: 0.8602 - val_recall: 0.9950 - val_auc: 0.9976 - val_prc: 0.9957
# Training Finished

# %%
print("\n\nEvaluation of test Data Generator:\n\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
print("Done")
# Out:
# Evaluation of test Data Generator:
#
#
# 29/29 [==============================] - 34s 1s/step - loss: 0.1263 - tp: 586.0000 - fp: 99.0000 - tn: 1160.0000 - fn: 4.0000 - accuracy: 0.9443 - precision: 0.8555 - recall: 0.9932 - auc: 0.9962 - prc: 0.9900
# Done
