# %%
import tensorflow as tf
import tensorflow_hub as hub

import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import zipfile
import sys
import random
import os
from PIL import Image
import pickle#to save the weights of the model
import time
import shutil #to create a zip file

from tensorflow.keras.applications import VGG19, ResNet50, MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import Model, Input 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.image import resize_with_crop_or_pad
from tensorflow import cast, expand_dims, int32, convert_to_tensor, float32
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg19 import preprocess_input as vgg19_preprocess #preprocess the images before passing to the model to be as eeach model expects
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet50_preprocess
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mobilenet_preprocess #rescale images from [0,255] to [-1,1]
from tensorflow.keras import metrics 
from tensorflow.io import read_file
from tensorflow.compat.v1.image import decode_jpeg
from numpy import squeeze
from tensorflow.keras.models import load_model
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
#### Determine fixed variables for model

(img_width, img_height) = (224,224) 
batch_size = 64 # small batch size because the datasset in small

# %%
#Load the model from TF hub
pose_model = hub.load('https://tfhub.dev/google/movenet/singlepose/thunder/4') #Thunder is the more accurate version but also larger and slower than Lightning
movenet = pose_model.signatures['serving_default']

# %%
def print_parameters_count(model_):
    import tensorflow.keras.backend as K
    trainable_count = np.sum([K.count_params(w) for w in model_.trainable_weights])
    non_trainable_count = np.sum([K.count_params(w) for w in model_.non_trainable_weights])

    print('Total params: {:,}'.format(trainable_count + non_trainable_count))
    print('Trainable params: {:,}'.format(trainable_count))
    print('Non-trainable params: {:,}'.format(non_trainable_count))

def draw_keypoints(image, keypoints, confidence_threshold):
    # Get the height, width, and channels of the input image
    height, width, channels = image.shape
    # Scale the keypoints to match the size of the input image
    _shaped_keypoints = np.squeeze(np.multiply(keypoints, [height,width,1]))
    
    for kp in _shaped_keypoints:
        ky, kx, kp_conf = kp
        if kp_conf > confidence_threshold:
            cv2.circle(image, (int(kx), int(ky)), 4, (0,255,0), -1)


EDGES = {
    (0, 1): 'm',    (0, 2): 'c',    (1, 3): 'm',    (2, 4): 'c',
    (0, 5): 'm',    (0, 6): 'c',    (5, 7): 'm',    (7, 9): 'm',
    (6, 8): 'c',    (8, 10): 'c',    (5, 6): 'y',    (5, 11): 'm',
    (6, 12): 'c',    (11, 12): 'y',    (11, 13): 'm',    (13, 15): 'm',
    (12, 14): 'c',    (14, 16): 'c'}

def draw_connections(image, keypoints, edges, confidence_threshold):
    # Get the height, width, and channels of the input image
    height,  width, c = image.shape
    # Scale the keypoints to match the size of the input image
    _shaped_keypoints = np.squeeze(np.multiply(keypoints, [height, width,1]))
    
    for edge, color in edges.items():
        p1, p2 = edge
        y1, x1, c1 = _shaped_keypoints[p1]
        y2, x2, c2 = _shaped_keypoints[p2]
        
        if (c1 > confidence_threshold) & (c2 > confidence_threshold):      
            cv2.line(image, (int(x1), int(y1)), (int(x2), int(y2)), (0,0,255), 2)


def print_performance_report(model, test_generator):
    """takes as input a model and DirectoryIterator
    and prints the classification report and the Confusion matrix"""
    y_pred = model.predict(test_generator)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = test_generator.classes
    class_labels=list(test_generator.class_indices.keys())

    print("Classification Report:\n", classification_report(y_true, y_pred_classes, target_names=class_labels))
    print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred_classes))

def get_size(model_path):
        # Get the size of the saved model file in MB
    file_size = os.path.getsize(model_path) / (1024 * 1024)
    return file_size
def delete_files_inside(folder):
    for file in os.listdir(folder):
        os.remove(os.path.join(folder,file)) 

    #Confusion_matrix
def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions>0.5 )
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('Adults Detected (True Negatives): ', cm[0][0])
    print('Child Incorrectly Detected (False Positives): ', cm[0][1])
    print('Child Missed (False Negatives): ', cm[1][0])
    print('Child Detected (True Positives): ', cm[1][1])
    
    
def zip_delete(model_name, path):
    """makes a ziped folder of all the results
    and deleted all the initial folder to make it easier to load the data in /kaggle/working"""
    shutil.make_archive(model_name, 'zip', path)
    delete_files_inside(path)
    os.rmdir(path)
    
def delete_folder_contents(folder_path):
    for root, dirs, files in os.walk(folder_path, topdown=False):
        for file in files:
            os.remove(os.path.join(root, file))
        for dir in dirs:
            os.rmdir(os.path.join(root, dir))
    os.rmdir(folder_path)
    

def plot_save_results(model_, model_name, fine_tuning,with_keypoints, num_epcohs, batch_size, history, save=True, loaded=False):
    #create folder for this model

    dir_name = model_name
    model_detailed_name = f"{model_name}__{with_keypoints}__{fine_tuning}__{num_epcohs}epcohs__{batch_size}batch"
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    mpl.rcParams['figure.figsize'] = (12, 10)
    
    if loaded:
        epochs = range(1, len(history['loss'])+1)
        history_dict = history
    else:
        epochs = range(1, len(history.history['loss'])+1)
        history_dict = history.history
    metrics = [ 'loss','accuracy',  'precision', 'recall','prc', 'auc', 'tp', 'fp', 'tn', 'fn',]
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(len(metrics)//2,2,n +1)
        plt.plot(epochs, history_dict[metric], color=colors[0], label='Train')
        plt.plot(epochs, history_dict['val_'+metric],
                 color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.8,1.1])
        elif metric=='tp' or metric=='fp' or metric=='tn' or metric=='fn':
            plt.ylim([1,np.max(history_dict[metric]) *  1.1 ])
        else:
            plt.ylim([0,1.1])
        
        plt.legend()
    if save:    
        plt.savefig(f"{dir_name}/{model_detailed_name}_{metric}.png")
        # Save the entire model to a file
        model_.save(f"{dir_name}/{model_detailed_name}.h5")

        # Save history to a file
        with open(f"{dir_name}/history_{model_detailed_name}.pickle", "wb") as f:
            pickle.dump(history.history, f)

# %%
def create_base_VGG19():
    return VGG19(weights='imagenet',input_shape=(224, 224, 3),include_top=False)
def create_base_ResNet():
    return  ResNet50(weights='imagenet', input_shape=(224, 224, 3),include_top=False)
def create_base_MobileNetV2():
    return  MobileNetV2(weights='imagenet', input_shape=(224, 224,3),  include_top=False)

# %%
# Define a preprocessing function to be applied to each image
def preprocess_image_add_pose_keypoints(image_, pose_model=movenet, image_output_shape=(224,224), confidence_threshold=0.15, circle_thickness=3, line_thickness=2 ):
    #check if image is corrupted
    """The function reads a PIL image, converts to numpy array, resize to be able to be processed by the pose model,
    then the pose estimation keypoints are added, then reshaped as the NN model expects.
    source of image transformations: https://tfhub.dev/google/movenet/singlepose/lightning/4"""
#     image_ = cast(resize_with_crop_or_pad(expand_dims(image_, axis=0), 256, 256), dtype=int32)
    image_ = tf.convert_to_tensor(image_, dtype=tf.float32)

    image_ = tf.expand_dims(image_, axis=0)
    # Resize and pad the image to keep the aspect ratio and fit the expected size.
    image_ = tf.cast(tf.image.resize_with_pad(image_, 256, 256), dtype=tf.int32)
    if image_.shape[1] != 256 or image_.shape[2] != 256:
        return None
    outputs = pose_model(image_)
    # Reshape the image from (1, 256, 256, 3) to (256, 256, 3) and return an nd-array
    image_ = np.squeeze(image_)
    # Output is a [1, 1, 17, 3] tensor. to numpy array then take the points and reshape
    keypoints_with_scores = outputs['output_0'].numpy()[0,0,:,:51].reshape((17,3))
    #transform to numpy array to add the points and lines since tensorflow does not do that easily
    (height,width) = (image_.shape[0],image_.shape[1])
    #multiply x by height, y by weight (and score by 1)to get the real position on the image
    shaped_keypoints =  np.multiply(keypoints_with_scores, [height,width,1])     
    #########################################################################################################3
    for kp in shaped_keypoints:
        ky, kx, kp_conf = kp
        #print(kp)
        if kp_conf > confidence_threshold:
            cv2.circle(image_, (int(kx), int(ky)), 2, (0,0,0), 3)
    #draw_keypoints(image_array, outputs, confidence_threshold=0.3)
    for edge, color in EDGES.items():
        p1, p2 = edge
        y1, x1, c1 = shaped_keypoints[p1]
        y2, x2, c2 = shaped_keypoints[p2]
        if (c1 > confidence_threshold) & (c2 > confidence_threshold):      
            cv2.line(image_, (int(x1), int(y1)), (int(x2), int(y2)), (0,0,0), 2)
 
    #Resize iamge to fit the model of training
    #should change the output shape of the ouput to be fit to the pretrained mode
    image_ = image_.astype(np.float32)#image does not change
    #When the image is of type float, plt expects it to be in rannge[0,1]
    #ImageDataGenerator class expects a NumPy array as input,
    image_  = cv2.resize(image_,dsize=(image_output_shape[0], image_output_shape[1]))
#     tensor = tf.convert_to_tensor(x_np)

    return image_

# %%
path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/test/Adult/ch1_NVR_ch1_main_20220820210000_20220820220000.mp4_000698bf-a7f8-4572-be6d-6e39b5ee8195.jpg'
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread(path)

# Display the original image
plt.imshow(img)
plt.show()

# Apply the preprocess function
processed_img = preprocess_image_add_pose_keypoints(img)

# Display the processed image
plt.imshow(processed_img/255)
plt.show()

# %%
train_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/train'
validation_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/val'
test_path = '/kaggle/input/adult-child-v2-train-val-test/Adult_Child_v2 train_val_test/test'

############################################################################################################################################
# Create a data generator to load and augment the training data
#Removed rescale from Image data generators, since Using pre
train_datagen_without_preprocessing = ImageDataGenerator(  
    #rescale=1.0/255,  #If using the pre processing fn of the pre trainde models, no need to rescale, and should add featurewise_center=False if so.
    featurewise_center=False, # if using the pre processing of the pre trained models, no need to make featurewise center, and if not false, should fit it before use
    rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest'
)

train_generator_without_preprocessing = train_datagen_without_preprocessing.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False)
# Create a data generator to load the validation data
val_datagen_without_preprocessing = ImageDataGenerator( featurewise_center=False)

val_generator_without_preprocessing = val_datagen_without_preprocessing.flow_from_directory(
    validation_path,
    target_size= (img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
shuffle=False)

#######################################################################################################################################
# Create a data generator to accept the trainign data with the preprocessing function
train_datagen_with_preprocessing = ImageDataGenerator(
    featurewise_center=False,
     rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest',  # fill any missing pixels with the nearest value
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet,
                                                                         image_output_shape=(img_width, img_height),
                                                                         confidence_threshold= 0.05)
)

train_generator_with_preprocessing = train_datagen_with_preprocessing.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)


# Create a data generator to load the validation data with the preprocessing function
val_datagen_with_preprocessing = ImageDataGenerator( 
    featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold=0.05)
)

val_generator_with_preprocessing = val_datagen_with_preprocessing.flow_from_directory(
    validation_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

#######################################################################################################################################
test_datagen_without_preprocessing = ImageDataGenerator( featurewise_center=False,)

#Load the training data
test_generator_without_preprocessing = test_datagen_without_preprocessing.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
###################################
# Create a data generator to accept the trainign data with the preprocessing function
test_datagen_with_preprocessing = ImageDataGenerator( featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold= 0.05)
)

# Load the training data
test_generator_with_preprocessing = test_datagen_with_preprocessing.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

# %% [markdown]
# # First Approach

# %% [markdown]
# ## Without Pose Estimation key points

# %% [markdown]
# ### Train before Tune

# %%
train_generator = train_generator_without_preprocessing
val_generator = val_generator_without_preprocessing
test_generator = test_generator_without_preprocessing
preprocess_fn = vgg19_preprocess
neurons_final = 1024
base_model = create_base_VGG19()
fine_tune_limit = len(base_model.layers) - int(0.1*len(base_model.layers))-1
model_name= 'VGG19'
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_30 = 30
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################

base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Done
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_2   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 1024)              525312
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 20,550,721
# Trainable params: 526,337
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Model Summary:  None

# %%
counter = Counter(train_generator.classes)
print(str(counter.items())+"\n") # dict_items([(0, 1648), (1, 3614)])
Adult = 3997
Child = 1645
total = Adult + Child
weight_for_Adult =   (total / Adult) 
weight_for_Child =   (total /Child)
weight_for_Adult /= (weight_for_Adult +  weight_for_Child)
weight_for_Child /= (weight_for_Adult +  weight_for_Child)

class_weight = {0: weight_for_Adult, 1: weight_for_Child}
print('Class Weights: ', class_weight)

METRICS = [
      metrics.TruePositives(name='tp'),
      metrics.FalsePositives(name='fp'),
      metrics.TrueNegatives(name='tn'),
      metrics.FalseNegatives(name='fn'), 
      metrics.BinaryAccuracy(name='accuracy'),
      metrics.Precision(name='precision'),
      metrics.Recall(name='recall'),
      metrics.AUC(name='auc'),
      metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %%
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS)

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################
# Out:
# Training Started
#
# Epoch 1/10
# 88/88 [==============================] - 101s 1s/step - loss: 0.6575 - tp: 1355.0000 - fp: 843.0000 - tn: 3090.0000 - fn: 290.0000 - accuracy: 0.7969 - precision: 0.6165 - recall: 0.8237 - auc: 0.8543 - prc: 0.6758 - val_loss: 0.1437 - val_tp: 170.0000 - val_fp: 21.0000 - val_tn: 496.0000 - val_fn: 17.0000 - val_accuracy: 0.9460 - val_precision: 0.8901 - val_recall: 0.9091 - val_auc: 0.9823 - val_prc: 0.9662 - lr: 0.0010
# Epoch 2/10
# 88/88 [==============================] - 74s 838ms/step - loss: 0.0969 - tp: 1513.0000 - fp: 368.0000 - tn: 3565.0000 - fn: 132.0000 - accuracy: 0.9104 - precision: 0.8044 - recall: 0.9198 - auc: 0.9760 - prc: 0.9536 - val_loss: 0.1947 - val_tp: 183.0000 - val_fp: 51.0000 - val_tn: 466.0000 - val_fn: 4.0000 - val_accuracy: 0.9219 - val_precision: 0.7821 - val_recall: 0.9786 - val_auc: 0.9910 - val_prc: 0.9753 - lr: 0.0010
# Epoch 3/10
# 88/88 [==============================] - 77s 873ms/step - loss: 0.0827 - tp: 1537.0000 - fp: 325.0000 - tn: 3608.0000 - fn: 108.0000 - accuracy: 0.9224 - precision: 0.8255 - recall: 0.9343 - auc: 0.9814 - prc: 0.9633 - val_loss: 0.1894 - val_tp: 187.0000 - val_fp: 58.0000 - val_tn: 459.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9176 - val_precision: 0.7633 - val_recall: 1.0000 - val_auc: 0.9940 - val_prc: 0.9847 - lr: 0.0010
# Epoch 4/10
# 88/88 [==============================] - 76s 861ms/step - loss: 0.0699 - tp: 1531.0000 - fp: 237.0000 - tn: 3696.0000 - fn: 114.0000 - accuracy: 0.9371 - precision: 0.8660 - recall: 0.9307 - auc: 0.9868 - prc: 0.9748 - val_loss: 0.1381 - val_tp: 186.0000 - val_fp: 37.0000 - val_tn: 480.0000 - val_fn: 1.0000 - val_accuracy: 0.9460 - val_precision: 0.8341 - val_recall: 0.9947 - val_auc: 0.9957 - val_prc: 0.9886 - lr: 0.0010
# Epoch 5/10
# 88/88 [==============================] - 73s 827ms/step - loss: 0.0635 - tp: 1564.0000 - fp: 256.0000 - tn: 3677.0000 - fn: 81.0000 - accuracy: 0.9396 - precision: 0.8593 - recall: 0.9508 - auc: 0.9889 - prc: 0.9787 - val_loss: 0.1206 - val_tp: 186.0000 - val_fp: 29.0000 - val_tn: 488.0000 - val_fn: 1.0000 - val_accuracy: 0.9574 - val_precision: 0.8651 - val_recall: 0.9947 - val_auc: 0.9962 - val_prc: 0.9898 - lr: 0.0010
# Epoch 6/10
# 88/88 [==============================] - 77s 870ms/step - loss: 0.0600 - tp: 1557.0000 - fp: 221.0000 - tn: 3712.0000 - fn: 88.0000 - accuracy: 0.9446 - precision: 0.8757 - recall: 0.9465 - auc: 0.9901 - prc: 0.9795 - val_loss: 0.1314 - val_tp: 187.0000 - val_fp: 36.0000 - val_tn: 481.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9489 - val_precision: 0.8386 - val_recall: 1.0000 - val_auc: 0.9967 - val_prc: 0.9912 - lr: 0.0010
# Epoch 7/10
# 88/88 [==============================] - 74s 839ms/step - loss: 0.0632 - tp: 1574.0000 - fp: 250.0000 - tn: 3683.0000 - fn: 71.0000 - accuracy: 0.9425 - precision: 0.8629 - recall: 0.9568 - auc: 0.9888 - prc: 0.9749 - val_loss: 0.0770 - val_tp: 174.0000 - val_fp: 13.0000 - val_tn: 504.0000 - val_fn: 13.0000 - val_accuracy: 0.9631 - val_precision: 0.9305 - val_recall: 0.9305 - val_auc: 0.9959 - val_prc: 0.9892 - lr: 0.0010
# Epoch 8/10
# 88/88 [==============================] - 74s 835ms/step - loss: 0.0726 - tp: 1545.0000 - fp: 285.0000 - tn: 3648.0000 - fn: 100.0000 - accuracy: 0.9310 - precision: 0.8443 - recall: 0.9392 - auc: 0.9857 - prc: 0.9720 - val_loss: 0.0681 - val_tp: 174.0000 - val_fp: 11.0000 - val_tn: 506.0000 - val_fn: 13.0000 - val_accuracy: 0.9659 - val_precision: 0.9405 - val_recall: 0.9305 - val_auc: 0.9968 - val_prc: 0.9913 - lr: 0.0010
# Epoch 9/10
# 88/88 [==============================] - 77s 871ms/step - loss: 0.0468 - tp: 1522.0000 - fp: 187.0000 - tn: 3810.0000 - fn: 59.0000 - accuracy: 0.9559 - precision: 0.8906 - recall: 0.9627 - auc: 0.9939 - prc: 0.9870 - val_loss: 0.0739 - val_tp: 182.0000 - val_fp: 15.0000 - val_tn: 502.0000 - val_fn: 5.0000 - val_accuracy: 0.9716 - val_precision: 0.9239 - val_recall: 0.9733 - val_auc: 0.9968 - val_prc: 0.9912 - lr: 0.0010
# Epoch 10/10
# 88/88 [==============================] - 75s 847ms/step - loss: 0.0474 - tp: 1511.0000 - fp: 182.0000 - tn: 3815.0000 - fn: 70.0000 - accuracy: 0.9548 - precision: 0.8925 - recall: 0.9557 - auc: 0.9939 - prc: 0.9863 - val_loss: 0.2362 - val_tp: 187.0000 - val_fp: 60.0000 - val_tn: 457.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9148 - val_precision: 0.7571 - val_recall: 1.0000 - val_auc: 0.9955 - val_prc: 0.9818 - lr: 0.0010
# Training Finished

# %%
# delete_folder_contents('/kaggle/working/')

# %%
################################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# /kaggle/working/VGG19_without_keypoints_before_tuning_10epochs.h5

# %%
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)

# %% [markdown]
# ### Fine Tuning

# %%
print_parameters_count(base_model)
# Out:
# Total params: 20,024,384
# Trainable params: 4,719,616
# Non-trainable params: 15,304,768

# %%
base_model.trainable = True
for layer in base_model.layers[:fine_tune_limit]:
    layer.trainable=False
print_parameters_count(base_model)

model.compile(optimizer=Adam(learning_rate=lr_2), loss= 'binary_crossentropy', metrics=METRICS)
print('#######################################################################\n')
print(model.summary())
# Out:
# Total params: 20,024,384
# Trainable params: 4,719,616
# Non-trainable params: 15,304,768
# #######################################################################
#
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_2   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 1024)              525312
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 20,550,721
# Trainable params: 5,245,953
# Non-trainable params: 15,304,768
# _________________________________________________________________
# None

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_fine_tuning,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)

################################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_fine_tuning, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_fine_tuning)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/20
# 89/89 [==============================] - 82s 877ms/step - loss: 0.0420 - tp: 1778.0000 - fp: 230.0000 - tn: 4284.0000 - fn: 54.0000 - accuracy: 0.9552 - precision: 0.8855 - recall: 0.9705 - auc: 0.9942 - prc: 0.9861 - val_loss: 0.1199 - val_tp: 203.0000 - val_fp: 33.0000 - val_tn: 484.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9542 - val_precision: 0.8602 - val_recall: 1.0000 - val_auc: 0.9961 - val_prc: 0.9872
# Epoch 2/20
# 89/89 [==============================] - 74s 833ms/step - loss: 0.0314 - tp: 1615.0000 - fp: 148.0000 - tn: 3849.0000 - fn: 30.0000 - accuracy: 0.9685 - precision: 0.9161 - recall: 0.9818 - auc: 0.9971 - prc: 0.9925 - val_loss: 0.0650 - val_tp: 189.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 14.0000 - val_accuracy: 0.9667 - val_precision: 0.9497 - val_recall: 0.9310 - val_auc: 0.9969 - val_prc: 0.9920
# Epoch 3/20
# 89/89 [==============================] - 74s 828ms/step - loss: 0.0336 - tp: 1603.0000 - fp: 138.0000 - tn: 3859.0000 - fn: 42.0000 - accuracy: 0.9681 - precision: 0.9207 - recall: 0.9745 - auc: 0.9969 - prc: 0.9931 - val_loss: 0.0863 - val_tp: 202.0000 - val_fp: 23.0000 - val_tn: 494.0000 - val_fn: 1.0000 - val_accuracy: 0.9667 - val_precision: 0.8978 - val_recall: 0.9951 - val_auc: 0.9964 - val_prc: 0.9879
# Epoch 4/20
# 89/89 [==============================] - 74s 827ms/step - loss: 0.0324 - tp: 1612.0000 - fp: 147.0000 - tn: 3850.0000 - fn: 33.0000 - accuracy: 0.9681 - precision: 0.9164 - recall: 0.9799 - auc: 0.9965 - prc: 0.9927 - val_loss: 0.0789 - val_tp: 202.0000 - val_fp: 22.0000 - val_tn: 495.0000 - val_fn: 1.0000 - val_accuracy: 0.9681 - val_precision: 0.9018 - val_recall: 0.9951 - val_auc: 0.9968 - val_prc: 0.9889
# Epoch 5/20
# 89/89 [==============================] - 74s 827ms/step - loss: 0.0268 - tp: 1623.0000 - fp: 117.0000 - tn: 3880.0000 - fn: 22.0000 - accuracy: 0.9754 - precision: 0.9328 - recall: 0.9866 - auc: 0.9979 - prc: 0.9948 - val_loss: 0.0548 - val_tp: 199.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 4.0000 - val_accuracy: 0.9806 - val_precision: 0.9522 - val_recall: 0.9803 - val_auc: 0.9979 - val_prc: 0.9946
# Epoch 6/20
# 89/89 [==============================] - 73s 820ms/step - loss: 0.0249 - tp: 1619.0000 - fp: 110.0000 - tn: 3887.0000 - fn: 26.0000 - accuracy: 0.9759 - precision: 0.9364 - recall: 0.9842 - auc: 0.9980 - prc: 0.9946 - val_loss: 0.0983 - val_tp: 203.0000 - val_fp: 26.0000 - val_tn: 491.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9639 - val_precision: 0.8865 - val_recall: 1.0000 - val_auc: 0.9962 - val_prc: 0.9847
# Epoch 7/20
# 89/89 [==============================] - 73s 821ms/step - loss: 0.0251 - tp: 1619.0000 - fp: 115.0000 - tn: 3882.0000 - fn: 26.0000 - accuracy: 0.9750 - precision: 0.9337 - recall: 0.9842 - auc: 0.9981 - prc: 0.9953 - val_loss: 0.0814 - val_tp: 202.0000 - val_fp: 22.0000 - val_tn: 495.0000 - val_fn: 1.0000 - val_accuracy: 0.9681 - val_precision: 0.9018 - val_recall: 0.9951 - val_auc: 0.9963 - val_prc: 0.9849
# Epoch 8/20
# 89/89 [==============================] - 76s 849ms/step - loss: 0.0245 - tp: 1619.0000 - fp: 103.0000 - tn: 3894.0000 - fn: 26.0000 - accuracy: 0.9771 - precision: 0.9402 - recall: 0.9842 - auc: 0.9982 - prc: 0.9952 - val_loss: 0.0741 - val_tp: 202.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 1.0000 - val_accuracy: 0.9736 - val_precision: 0.9182 - val_recall: 0.9951 - val_auc: 0.9973 - val_prc: 0.9902
# Epoch 9/20
# 89/89 [==============================] - 75s 847ms/step - loss: 0.0214 - tp: 1624.0000 - fp: 91.0000 - tn: 3906.0000 - fn: 21.0000 - accuracy: 0.9801 - precision: 0.9469 - recall: 0.9872 - auc: 0.9986 - prc: 0.9962 - val_loss: 0.0473 - val_tp: 199.0000 - val_fp: 8.0000 - val_tn: 509.0000 - val_fn: 4.0000 - val_accuracy: 0.9833 - val_precision: 0.9614 - val_recall: 0.9803 - val_auc: 0.9983 - val_prc: 0.9957
# Epoch 10/20
# 89/89 [==============================] - 74s 826ms/step - loss: 0.0176 - tp: 1628.0000 - fp: 74.0000 - tn: 3923.0000 - fn: 17.0000 - accuracy: 0.9839 - precision: 0.9565 - recall: 0.9897 - auc: 0.9991 - prc: 0.9977 - val_loss: 0.0793 - val_tp: 202.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 1.0000 - val_accuracy: 0.9736 - val_precision: 0.9182 - val_recall: 0.9951 - val_auc: 0.9966 - val_prc: 0.9858
# Epoch 11/20
# 89/89 [==============================] - 74s 834ms/step - loss: 0.0209 - tp: 1630.0000 - fp: 84.0000 - tn: 3913.0000 - fn: 15.0000 - accuracy: 0.9825 - precision: 0.9510 - recall: 0.9909 - auc: 0.9984 - prc: 0.9950 - val_loss: 0.0612 - val_tp: 201.0000 - val_fp: 12.0000 - val_tn: 505.0000 - val_fn: 2.0000 - val_accuracy: 0.9806 - val_precision: 0.9437 - val_recall: 0.9901 - val_auc: 0.9976 - val_prc: 0.9910
# Epoch 12/20
# 89/89 [==============================] - 73s 819ms/step - loss: 0.0189 - tp: 1627.0000 - fp: 84.0000 - tn: 3913.0000 - fn: 18.0000 - accuracy: 0.9819 - precision: 0.9509 - recall: 0.9891 - auc: 0.9987 - prc: 0.9961 - val_loss: 0.0506 - val_tp: 201.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 2.0000 - val_accuracy: 0.9833 - val_precision: 0.9526 - val_recall: 0.9901 - val_auc: 0.9976 - val_prc: 0.9909
# Epoch 13/20
# 89/89 [==============================] - 73s 819ms/step - loss: 0.0192 - tp: 1629.0000 - fp: 85.0000 - tn: 3912.0000 - fn: 16.0000 - accuracy: 0.9821 - precision: 0.9504 - recall: 0.9903 - auc: 0.9987 - prc: 0.9962 - val_loss: 0.0512 - val_tp: 199.0000 - val_fp: 8.0000 - val_tn: 509.0000 - val_fn: 4.0000 - val_accuracy: 0.9833 - val_precision: 0.9614 - val_recall: 0.9803 - val_auc: 0.9976 - val_prc: 0.9908
# Epoch 14/20
# 89/89 [==============================] - 73s 819ms/step - loss: 0.0186 - tp: 1622.0000 - fp: 69.0000 - tn: 3928.0000 - fn: 23.0000 - accuracy: 0.9837 - precision: 0.9592 - recall: 0.9860 - auc: 0.9989 - prc: 0.9970 - val_loss: 0.0734 - val_tp: 202.0000 - val_fp: 13.0000 - val_tn: 504.0000 - val_fn: 1.0000 - val_accuracy: 0.9806 - val_precision: 0.9395 - val_recall: 0.9951 - val_auc: 0.9961 - val_prc: 0.9817
# Epoch 15/20
# 89/89 [==============================] - 73s 816ms/step - loss: 0.0177 - tp: 1634.0000 - fp: 80.0000 - tn: 3917.0000 - fn: 11.0000 - accuracy: 0.9839 - precision: 0.9533 - recall: 0.9933 - auc: 0.9988 - prc: 0.9964 - val_loss: 0.0534 - val_tp: 200.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 3.0000 - val_accuracy: 0.9819 - val_precision: 0.9524 - val_recall: 0.9852 - val_auc: 0.9976 - val_prc: 0.9908
# Evaluation of test Data Generator
# 11/11 [==============================] - 8s 802ms/step - loss: 0.0278 - tp: 190.0000 - fp: 4.0000 - tn: 478.0000 - fn: 2.0000 - accuracy: 0.9911 - precision: 0.9794 - recall: 0.9896 - auc: 0.9994 - prc: 0.9984

# %% [markdown]
# ## With Pose Estimation key points

# %% [markdown]
# ### Train before Tune

# %%
train_generator = train_generator_with_preprocessing
val_generator = val_generator_with_preprocessing
test_generator = test_generator_with_preprocessing
preprocess_fn = vgg19_preprocess
neurons_final = 1024
base_model = create_base_VGG19()
fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))-1
model_name= 'VGG19'
fine_tuning = 'before_tuning'
keypoints_added = 'with_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_30 = 30
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")

#####################################################################3
base_model.trainable = False

inputs = Input(shape=(224,224,3))
# x = PreprocessAddKPts()(inputs)
x = preprocess_fn(inputs)
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print( model.summary())
# Out:
# Done
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_11  (None, 224, 224, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_11 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d_11  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  dropout_22 (Dropout)        (None, 512)               0
#
#  dense_22 (Dense)            (None, 1024)              525312
#
#  dropout_23 (Dropout)        (None, 1024)              0
#
#  dense_23 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 20,550,721
# Trainable params: 526,337
# Non-trainable params: 20,024,384
# _________________________________________________________________
# None

# %%
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1),loss= 'binary_crossentropy',metrics=METRICS)

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n\n")   
train_generator.reset()
val_generator.reset()
history = model.fit(train_generator,
                    epochs= epochs_1,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n")

##################################################################################

plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Training Started
#
#
# Epoch 1/10
# 88/88 [==============================] - 173s 2s/step - loss: 0.4780 - tp: 1371.0000 - fp: 901.0000 - tn: 3096.0000 - fn: 274.0000 - accuracy: 0.7917 - precision: 0.6034 - recall: 0.8334 - auc: 0.8675 - prc: 0.7198 - val_loss: 0.4604 - val_tp: 120.0000 - val_fp: 1.0000 - val_tn: 516.0000 - val_fn: 67.0000 - val_accuracy: 0.9034 - val_precision: 0.9917 - val_recall: 0.6417 - val_auc: 0.9285 - val_prc: 0.9185 - lr: 0.0010
# Epoch 2/10
# 88/88 [==============================] - 164s 2s/step - loss: 0.1609 - tp: 1491.0000 - fp: 583.0000 - tn: 3350.0000 - fn: 154.0000 - accuracy: 0.8679 - precision: 0.7189 - recall: 0.9064 - auc: 0.9531 - prc: 0.9064 - val_loss: 0.1626 - val_tp: 178.0000 - val_fp: 31.0000 - val_tn: 486.0000 - val_fn: 9.0000 - val_accuracy: 0.9432 - val_precision: 0.8517 - val_recall: 0.9519 - val_auc: 0.9880 - val_prc: 0.9755 - lr: 0.0010
# Epoch 3/10
# 88/88 [==============================] - 167s 2s/step - loss: 0.1191 - tp: 1440.0000 - fp: 409.0000 - tn: 3559.0000 - fn: 170.0000 - accuracy: 0.8962 - precision: 0.7788 - recall: 0.8944 - auc: 0.9650 - prc: 0.9318 - val_loss: 0.1600 - val_tp: 178.0000 - val_fp: 35.0000 - val_tn: 482.0000 - val_fn: 9.0000 - val_accuracy: 0.9375 - val_precision: 0.8357 - val_recall: 0.9519 - val_auc: 0.9893 - val_prc: 0.9766 - lr: 0.0010
# Epoch 4/10
# 88/88 [==============================] - 155s 2s/step - loss: 0.1173 - tp: 1518.0000 - fp: 521.0000 - tn: 3412.0000 - fn: 127.0000 - accuracy: 0.8838 - precision: 0.7445 - recall: 0.9228 - auc: 0.9662 - prc: 0.9346 - val_loss: 0.3291 - val_tp: 113.0000 - val_fp: 0.0000e+00 - val_tn: 517.0000 - val_fn: 74.0000 - val_accuracy: 0.8949 - val_precision: 1.0000 - val_recall: 0.6043 - val_auc: 0.9795 - val_prc: 0.9683 - lr: 0.0010
# Epoch 5/10
# 88/88 [==============================] - 168s 2s/step - loss: 0.1567 - tp: 1376.0000 - fp: 430.0000 - tn: 3567.0000 - fn: 205.0000 - accuracy: 0.8862 - precision: 0.7619 - recall: 0.8703 - auc: 0.9456 - prc: 0.9068 - val_loss: 0.2115 - val_tp: 183.0000 - val_fp: 50.0000 - val_tn: 467.0000 - val_fn: 4.0000 - val_accuracy: 0.9233 - val_precision: 0.7854 - val_recall: 0.9786 - val_auc: 0.9916 - val_prc: 0.9771 - lr: 0.0010
# Epoch 6/10
# 88/88 [==============================] - 162s 2s/step - loss: 0.0855 - tp: 1528.0000 - fp: 350.0000 - tn: 3583.0000 - fn: 117.0000 - accuracy: 0.9163 - precision: 0.8136 - recall: 0.9289 - auc: 0.9802 - prc: 0.9634 - val_loss: 0.1154 - val_tp: 176.0000 - val_fp: 14.0000 - val_tn: 503.0000 - val_fn: 11.0000 - val_accuracy: 0.9645 - val_precision: 0.9263 - val_recall: 0.9412 - val_auc: 0.9933 - val_prc: 0.9836 - lr: 0.0010
# Epoch 7/10
# 88/88 [==============================] - 171s 2s/step - loss: 0.0797 - tp: 1532.0000 - fp: 302.0000 - tn: 3631.0000 - fn: 113.0000 - accuracy: 0.9256 - precision: 0.8353 - recall: 0.9313 - auc: 0.9827 - prc: 0.9676 - val_loss: 0.1545 - val_tp: 184.0000 - val_fp: 42.0000 - val_tn: 475.0000 - val_fn: 3.0000 - val_accuracy: 0.9361 - val_precision: 0.8142 - val_recall: 0.9840 - val_auc: 0.9929 - val_prc: 0.9791 - lr: 0.0010
# Epoch 8/10
# 88/88 [==============================] - 166s 2s/step - loss: 0.0757 - tp: 1545.0000 - fp: 290.0000 - tn: 3643.0000 - fn: 100.0000 - accuracy: 0.9301 - precision: 0.8420 - recall: 0.9392 - auc: 0.9841 - prc: 0.9715 - val_loss: 0.0996 - val_tp: 174.0000 - val_fp: 10.0000 - val_tn: 507.0000 - val_fn: 13.0000 - val_accuracy: 0.9673 - val_precision: 0.9457 - val_recall: 0.9305 - val_auc: 0.9953 - val_prc: 0.9876 - lr: 0.0010
# Epoch 9/10
# 88/88 [==============================] - 169s 2s/step - loss: 0.0819 - tp: 1515.0000 - fp: 271.0000 - tn: 3662.0000 - fn: 130.0000 - accuracy: 0.9281 - precision: 0.8483 - recall: 0.9210 - auc: 0.9811 - prc: 0.9672 - val_loss: 0.1399 - val_tp: 185.0000 - val_fp: 32.0000 - val_tn: 485.0000 - val_fn: 2.0000 - val_accuracy: 0.9517 - val_precision: 0.8525 - val_recall: 0.9893 - val_auc: 0.9951 - val_prc: 0.9871 - lr: 0.0010
# Epoch 10/10
# 88/88 [==============================] - 159s 2s/step - loss: 0.0735 - tp: 1472.0000 - fp: 249.0000 - tn: 3748.0000 - fn: 109.0000 - accuracy: 0.9358 - precision: 0.8553 - recall: 0.9311 - auc: 0.9846 - prc: 0.9701 - val_loss: 0.1257 - val_tp: 184.0000 - val_fp: 27.0000 - val_tn: 490.0000 - val_fn: 3.0000 - val_accuracy: 0.9574 - val_precision: 0.8720 - val_recall: 0.9840 - val_auc: 0.9950 - val_prc: 0.9834 - lr: 0.0010
# Training Finished

# %%
saved_model_before_withKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_withKPts_path)
# Out:
# /kaggle/working/VGG19_with_keypoints_before_tuning_10epochs.h5

# %% [markdown]
# ### Fine Tuning

# %%
model.load_weights(saved_model_before_withKPts_path)

# %%
model.compile(optimizer=Adam(learning_rate=lr_1),loss= 'binary_crossentropy',metrics=METRICS)
model.evaluate(test_generator)
# Out:
# 11/11 [==============================] - 14s 1s/step - loss: 0.1073 - tp: 187.0000 - fp: 26.0000 - tn: 456.0000 - fn: 5.0000 - accuracy: 0.9540 - precision: 0.8779 - recall: 0.9740 - auc: 0.9956 - prc: 0.9901
# [0.10732877999544144,
#  187.0,
#  26.0,
#  456.0,
#  5.0,
#  0.9540059566497803,
#  0.8779342770576477,
#  0.9739583134651184,
#  0.9955535531044006,
#  0.9900881052017212]

# %%
fine_tuning = 'after_tuning'
base_model.trainable = True
for layer in base_model.layers[:fine_tune_limit]:
    layer.trainable=False


model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('+===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# +===================================
# Total params: 20,550,721
# Trainable params: 5,245,953
# Non-trainable params: 15,304,768
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_11  (None, 224, 224, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_11 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d_11  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  dropout_22 (Dropout)        (None, 512)               0
#
#  dense_22 (Dense)            (None, 1024)              525312
#
#  dropout_23 (Dropout)        (None, 1024)              0
#
#  dense_23 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 20,550,721
# Trainable params: 5,245,953
# Non-trainable params: 15,304,768
# _________________________________________________________________
# None

# %%
#######################################################################################################################33
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
history_after_tune = model.fit(train_generator,
                              epochs=epochs_fine_tuning,
                               #steps_per_epoch=steps_per_epoch,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                               #validation_steps=validation_steps,
                              class_weight=class_weight)

#############################################################################################################33
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator_without_preprocessing.reset()
model.evaluate(test_generator)

##########################################################################################################
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_fine_tuning, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_fine_tuning)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/20
# 89/89 [==============================] - 183s 2s/step - loss: 0.0781 - tp: 1723.0000 - fp: 360.0000 - tn: 4119.0000 - fn: 114.0000 - accuracy: 0.9250 - precision: 0.8272 - recall: 0.9379 - auc: 0.9847 - prc: 0.9716 - val_loss: 0.1167 - val_tp: 192.0000 - val_fp: 25.0000 - val_tn: 492.0000 - val_fn: 11.0000 - val_accuracy: 0.9500 - val_precision: 0.8848 - val_recall: 0.9458 - val_auc: 0.9919 - val_prc: 0.9819
# Epoch 2/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0602 - tp: 1559.0000 - fp: 220.0000 - tn: 3777.0000 - fn: 86.0000 - accuracy: 0.9458 - precision: 0.8763 - recall: 0.9477 - auc: 0.9898 - prc: 0.9802 - val_loss: 0.1113 - val_tp: 193.0000 - val_fp: 24.0000 - val_tn: 493.0000 - val_fn: 10.0000 - val_accuracy: 0.9528 - val_precision: 0.8894 - val_recall: 0.9507 - val_auc: 0.9934 - val_prc: 0.9849
# Epoch 3/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0543 - tp: 1573.0000 - fp: 202.0000 - tn: 3795.0000 - fn: 72.0000 - accuracy: 0.9514 - precision: 0.8862 - recall: 0.9562 - auc: 0.9918 - prc: 0.9829 - val_loss: 0.1630 - val_tp: 201.0000 - val_fp: 49.0000 - val_tn: 468.0000 - val_fn: 2.0000 - val_accuracy: 0.9292 - val_precision: 0.8040 - val_recall: 0.9901 - val_auc: 0.9933 - val_prc: 0.9812
# Epoch 4/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0566 - tp: 1568.0000 - fp: 247.0000 - tn: 3750.0000 - fn: 77.0000 - accuracy: 0.9426 - precision: 0.8639 - recall: 0.9532 - auc: 0.9912 - prc: 0.9824 - val_loss: 0.1025 - val_tp: 196.0000 - val_fp: 25.0000 - val_tn: 492.0000 - val_fn: 7.0000 - val_accuracy: 0.9556 - val_precision: 0.8869 - val_recall: 0.9655 - val_auc: 0.9950 - val_prc: 0.9879
# Epoch 5/20
# 89/89 [==============================] - 177s 2s/step - loss: 0.0500 - tp: 1584.0000 - fp: 209.0000 - tn: 3788.0000 - fn: 61.0000 - accuracy: 0.9521 - precision: 0.8834 - recall: 0.9629 - auc: 0.9931 - prc: 0.9854 - val_loss: 0.1077 - val_tp: 201.0000 - val_fp: 29.0000 - val_tn: 488.0000 - val_fn: 2.0000 - val_accuracy: 0.9569 - val_precision: 0.8739 - val_recall: 0.9901 - val_auc: 0.9947 - val_prc: 0.9841
# Epoch 6/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0468 - tp: 1582.0000 - fp: 190.0000 - tn: 3807.0000 - fn: 63.0000 - accuracy: 0.9552 - precision: 0.8928 - recall: 0.9617 - auc: 0.9937 - prc: 0.9851 - val_loss: 0.1067 - val_tp: 201.0000 - val_fp: 27.0000 - val_tn: 490.0000 - val_fn: 2.0000 - val_accuracy: 0.9597 - val_precision: 0.8816 - val_recall: 0.9901 - val_auc: 0.9949 - val_prc: 0.9843
# Epoch 7/20
# 89/89 [==============================] - 185s 2s/step - loss: 0.0438 - tp: 1593.0000 - fp: 188.0000 - tn: 3809.0000 - fn: 52.0000 - accuracy: 0.9575 - precision: 0.8944 - recall: 0.9684 - auc: 0.9947 - prc: 0.9882 - val_loss: 0.0826 - val_tp: 195.0000 - val_fp: 17.0000 - val_tn: 500.0000 - val_fn: 8.0000 - val_accuracy: 0.9653 - val_precision: 0.9198 - val_recall: 0.9606 - val_auc: 0.9953 - val_prc: 0.9852
# Epoch 8/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0425 - tp: 1594.0000 - fp: 152.0000 - tn: 3845.0000 - fn: 51.0000 - accuracy: 0.9640 - precision: 0.9129 - recall: 0.9690 - auc: 0.9947 - prc: 0.9881 - val_loss: 0.0841 - val_tp: 198.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 5.0000 - val_accuracy: 0.9681 - val_precision: 0.9167 - val_recall: 0.9754 - val_auc: 0.9956 - val_prc: 0.9860
# Epoch 9/20
# 89/89 [==============================] - 177s 2s/step - loss: 0.0354 - tp: 1598.0000 - fp: 140.0000 - tn: 3857.0000 - fn: 47.0000 - accuracy: 0.9669 - precision: 0.9194 - recall: 0.9714 - auc: 0.9966 - prc: 0.9921 - val_loss: 0.0827 - val_tp: 198.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 5.0000 - val_accuracy: 0.9681 - val_precision: 0.9167 - val_recall: 0.9754 - val_auc: 0.9958 - val_prc: 0.9863
# Epoch 10/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0374 - tp: 1605.0000 - fp: 158.0000 - tn: 3839.0000 - fn: 40.0000 - accuracy: 0.9649 - precision: 0.9104 - recall: 0.9757 - auc: 0.9961 - prc: 0.9911 - val_loss: 0.0936 - val_tp: 200.0000 - val_fp: 23.0000 - val_tn: 494.0000 - val_fn: 3.0000 - val_accuracy: 0.9639 - val_precision: 0.8969 - val_recall: 0.9852 - val_auc: 0.9952 - val_prc: 0.9817
# Epoch 11/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0356 - tp: 1596.0000 - fp: 138.0000 - tn: 3859.0000 - fn: 49.0000 - accuracy: 0.9669 - precision: 0.9204 - recall: 0.9702 - auc: 0.9963 - prc: 0.9919 - val_loss: 0.1488 - val_tp: 203.0000 - val_fp: 40.0000 - val_tn: 477.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9444 - val_precision: 0.8354 - val_recall: 1.0000 - val_auc: 0.9953 - val_prc: 0.9825
# Epoch 12/20
# 89/89 [==============================] - 177s 2s/step - loss: 0.0350 - tp: 1609.0000 - fp: 150.0000 - tn: 3847.0000 - fn: 36.0000 - accuracy: 0.9670 - precision: 0.9147 - recall: 0.9781 - auc: 0.9965 - prc: 0.9926 - val_loss: 0.0736 - val_tp: 199.0000 - val_fp: 15.0000 - val_tn: 502.0000 - val_fn: 4.0000 - val_accuracy: 0.9736 - val_precision: 0.9299 - val_recall: 0.9803 - val_auc: 0.9962 - val_prc: 0.9871
# Epoch 13/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0341 - tp: 1603.0000 - fp: 127.0000 - tn: 3870.0000 - fn: 42.0000 - accuracy: 0.9700 - precision: 0.9266 - recall: 0.9745 - auc: 0.9965 - prc: 0.9918 - val_loss: 0.0921 - val_tp: 200.0000 - val_fp: 22.0000 - val_tn: 495.0000 - val_fn: 3.0000 - val_accuracy: 0.9653 - val_precision: 0.9009 - val_recall: 0.9852 - val_auc: 0.9964 - val_prc: 0.9879
# Epoch 14/20
# 89/89 [==============================] - 179s 2s/step - loss: 0.0327 - tp: 1613.0000 - fp: 140.0000 - tn: 3857.0000 - fn: 32.0000 - accuracy: 0.9695 - precision: 0.9201 - recall: 0.9805 - auc: 0.9967 - prc: 0.9924 - val_loss: 0.0810 - val_tp: 198.0000 - val_fp: 16.0000 - val_tn: 501.0000 - val_fn: 5.0000 - val_accuracy: 0.9708 - val_precision: 0.9252 - val_recall: 0.9754 - val_auc: 0.9963 - val_prc: 0.9876
# Epoch 15/20
# 89/89 [==============================] - 180s 2s/step - loss: 0.0312 - tp: 1607.0000 - fp: 121.0000 - tn: 3876.0000 - fn: 38.0000 - accuracy: 0.9718 - precision: 0.9300 - recall: 0.9769 - auc: 0.9971 - prc: 0.9919 - val_loss: 0.0789 - val_tp: 199.0000 - val_fp: 16.0000 - val_tn: 501.0000 - val_fn: 4.0000 - val_accuracy: 0.9722 - val_precision: 0.9256 - val_recall: 0.9803 - val_auc: 0.9963 - val_prc: 0.9876
# Epoch 16/20
# 89/89 [==============================] - 178s 2s/step - loss: 0.0270 - tp: 1614.0000 - fp: 115.0000 - tn: 3882.0000 - fn: 31.0000 - accuracy: 0.9741 - precision: 0.9335 - recall: 0.9812 - auc: 0.9980 - prc: 0.9955 - val_loss: 0.0922 - val_tp: 200.0000 - val_fp: 18.0000 - val_tn: 499.0000 - val_fn: 3.0000 - val_accuracy: 0.9708 - val_precision: 0.9174 - val_recall: 0.9852 - val_auc: 0.9957 - val_prc: 0.9833
# Epoch 17/20
# 89/89 [==============================] - 177s 2s/step - loss: 0.0288 - tp: 1620.0000 - fp: 119.0000 - tn: 3878.0000 - fn: 25.0000 - accuracy: 0.9745 - precision: 0.9316 - recall: 0.9848 - auc: 0.9973 - prc: 0.9924 - val_loss: 0.0669 - val_tp: 195.0000 - val_fp: 11.0000 - val_tn: 506.0000 - val_fn: 8.0000 - val_accuracy: 0.9736 - val_precision: 0.9466 - val_recall: 0.9606 - val_auc: 0.9964 - val_prc: 0.9875
# Epoch 18/20
# 89/89 [==============================] - 177s 2s/step - loss: 0.0283 - tp: 1612.0000 - fp: 116.0000 - tn: 3881.0000 - fn: 33.0000 - accuracy: 0.9736 - precision: 0.9329 - recall: 0.9799 - auc: 0.9975 - prc: 0.9944 - val_loss: 0.0818 - val_tp: 199.0000 - val_fp: 17.0000 - val_tn: 500.0000 - val_fn: 4.0000 - val_accuracy: 0.9708 - val_precision: 0.9213 - val_recall: 0.9803 - val_auc: 0.9957 - val_prc: 0.9829
# Epoch 19/20
# 89/89 [==============================] - 175s 2s/step - loss: 0.0255 - tp: 1619.0000 - fp: 102.0000 - tn: 3895.0000 - fn: 26.0000 - accuracy: 0.9773 - precision: 0.9407 - recall: 0.9842 - auc: 0.9979 - prc: 0.9941 - val_loss: 0.0734 - val_tp: 198.0000 - val_fp: 15.0000 - val_tn: 502.0000 - val_fn: 5.0000 - val_accuracy: 0.9722 - val_precision: 0.9296 - val_recall: 0.9754 - val_auc: 0.9965 - val_prc: 0.9879
# Epoch 20/20
# 89/89 [==============================] - 176s 2s/step - loss: 0.0287 - tp: 1622.0000 - fp: 109.0000 - tn: 3888.0000 - fn: 23.0000 - accuracy: 0.9766 - precision: 0.9370 - recall: 0.9860 - auc: 0.9969 - prc: 0.9930 - val_loss: 0.0804 - val_tp: 199.0000 - val_fp: 16.0000 - val_tn: 501.0000 - val_fn: 4.0000 - val_accuracy: 0.9722 - val_precision: 0.9256 - val_recall: 0.9803 - val_auc: 0.9959 - val_prc: 0.9835
# Evaluation of test Data Generator
# 11/11 [==============================] - 14s 1s/step - loss: 0.0439 - tp: 191.0000 - fp: 7.0000 - tn: 475.0000 - fn: 1.0000 - accuracy: 0.9881 - precision: 0.9646 - recall: 0.9948 - auc: 0.9986 - prc: 0.9968

# %% [markdown]
# # Second Approach: Unfreeze all layers

# %%
#define generators from second data set
#reapeat trainning of dense layers before unfreezing the model
train_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/train'
validation_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/val'
test_path = '/kaggle/input/adult-child-small-train-test-split/Adult_Child_v2 small_copy train_val_test/test'

############################################################################################################################################
# Create a data generator to load and augment the training data
train_datagen_without_preprocessing_2 = ImageDataGenerator(  
    #rescale=1.0/255,  #If using the pre processing fn of the pre trainde models, no need to rescale, and should add featurewise_center=False if so.
    featurewise_center=False, # if using the pre processing of the pre trained models, no need to make featurewise center, and if not false, should fit it before use
    rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest' )

train_generator_without_preprocessing_2 = train_datagen_without_preprocessing_2.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
# Create a data generator to load the validation data
val_datagen_without_preprocessing_2 = ImageDataGenerator( featurewise_center=False)

val_generator_without_preprocessing_2 = val_datagen_without_preprocessing_2.flow_from_directory(
    validation_path,
    target_size= (img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
shuffle=False )

#######################################################################################################################################
# Create a data generator to accept the trainign data with the preprocessing function
train_datagen_with_preprocessing_2 = ImageDataGenerator(
    featurewise_center=False,
     rotation_range=20,  # randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # randomly shift images horizontally by up to 20% of the image width
    height_shift_range=0.2,  # randomly shift images vertically by up to 20% of the image height
    shear_range=0.2,  # randomly shear images by up to 20%
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False,  # do not randomly flip images vertically
    fill_mode='nearest',  # fill any missing pixels with the nearest value
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet,
                                                                         image_output_shape=(img_width, img_height),
                                                                         confidence_threshold= 0.05) )

train_generator_with_preprocessing_2 = train_datagen_with_preprocessing_2.flow_from_directory(
    train_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )

# Create a data generator to load the validation data with the preprocessing function
val_datagen_with_preprocessing_2 = ImageDataGenerator( 
    featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold=0.05) )

val_generator_with_preprocessing_2 = val_datagen_with_preprocessing_2.flow_from_directory(
    validation_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )

#######################################################################################################################################
test_datagen_without_preprocessing_2 = ImageDataGenerator( featurewise_center=False,)

#Load the training data
test_generator_without_preprocessing_2 = test_datagen_without_preprocessing_2.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
###################################
# Create a data generator to accept the trainign data with the preprocessing function
test_datagen_with_preprocessing_2 = ImageDataGenerator( featurewise_center=False,
    #preprocessing_function=preprocess_image_add_pose_keypoints  # apply the preprocessing function
    preprocessing_function=lambda x: preprocess_image_add_pose_keypoints(x, movenet, 
                                                      image_output_shape=(img_width, img_height),confidence_threshold= 0.05) )

# Load the training data
test_generator_with_preprocessing_2 = test_datagen_with_preprocessing_2.flow_from_directory(
    test_path,
    target_size=(img_width, img_height), 
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False )
# Out:
# Found 2535 images belonging to 2 classes.
# Found 1882 images belonging to 2 classes.
# Found 2535 images belonging to 2 classes.
# Found 1882 images belonging to 2 classes.
# Found 1849 images belonging to 2 classes.
# Found 1849 images belonging to 2 classes.

# %% [markdown]
# ## Wihtout Pose Estimation

# %%
train_generator = train_generator_without_preprocessing_2
val_generator = val_generator_without_preprocessing_2
test_generator = test_generator_without_preprocessing_2
#############################################################
preprocess_fn = vgg19_preprocess############################
neurons_final = 1024########################################
base_model = create_base_VGG19()###########################
# fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))-1
model_name= 'VGG19_approach2'#################################
fine_tuning = 'before_tuning'################################
keypoints_added = 'without_keypoints'
###############################################################
epochs_1 = 10
epochs_fine_tuning = 20
epochs_8 = 8
epochs_40 = 40
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################
base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)###########################################
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Done
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 20,550,721
# Trainable params: 526,337
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Model Summary:  None

# %%
counter = Counter(train_generator.classes)
print(str(counter.items())+"\n") # dict_items([(0, 1648), (1, 3614)])
Adult = 3997
Child = 1645
total = Adult + Child
weight_for_Adult =   (total / Adult) 
weight_for_Child =   (total /Child)
weight_for_Adult /= (weight_for_Adult +  weight_for_Child)
weight_for_Child /= (weight_for_Adult +  weight_for_Child)

class_weight = {0: weight_for_Adult, 1: weight_for_Child}
print('Class Weights: ', class_weight)

METRICS = [
      metrics.TruePositives(name='tp'),
      metrics.FalsePositives(name='fp'),
      metrics.TrueNegatives(name='tn'),
      metrics.FalseNegatives(name='fn'), 
      metrics.BinaryAccuracy(name='accuracy'),
      metrics.Precision(name='precision'),
      metrics.Recall(name='recall'),
      metrics.AUC(name='auc'),
      metrics.AUC(name='prc', curve='PR'), ]  # precision-recall curve
# Out:
# dict_items([(0, 1691), (1, 844)])
#
# Class Weights:  {0: 0.2915632754342432, 1: 0.9216512191765469}

# %%
base_model.trainable = False
#Train dense layers:
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS )

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################

################################################################################################################
model_name= 'VGG19_approach2'
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# Training Started
#
# Epoch 1/10
# 40/40 [==============================] - 88s 2s/step - loss: 0.6370 - tp: 703.0000 - fp: 399.0000 - tn: 1292.0000 - fn: 141.0000 - accuracy: 0.7870 - precision: 0.6379 - recall: 0.8329 - auc: 0.8569 - prc: 0.7977 - val_loss: 0.3890 - val_tp: 594.0000 - val_fp: 216.0000 - val_tn: 1060.0000 - val_fn: 12.0000 - val_accuracy: 0.8789 - val_precision: 0.7333 - val_recall: 0.9802 - val_auc: 0.9748 - val_prc: 0.9226 - lr: 0.0010
# Epoch 2/10
# 40/40 [==============================] - 44s 1s/step - loss: 0.1231 - tp: 777.0000 - fp: 195.0000 - tn: 1496.0000 - fn: 67.0000 - accuracy: 0.8966 - precision: 0.7994 - recall: 0.9206 - auc: 0.9682 - prc: 0.9494 - val_loss: 0.2691 - val_tp: 596.0000 - val_fp: 179.0000 - val_tn: 1097.0000 - val_fn: 10.0000 - val_accuracy: 0.8996 - val_precision: 0.7690 - val_recall: 0.9835 - val_auc: 0.9884 - val_prc: 0.9702 - lr: 0.0010
# Epoch 3/10
# 40/40 [==============================] - 44s 1s/step - loss: 0.0910 - tp: 800.0000 - fp: 152.0000 - tn: 1539.0000 - fn: 44.0000 - accuracy: 0.9227 - precision: 0.8403 - recall: 0.9479 - auc: 0.9803 - prc: 0.9578 - val_loss: 0.1119 - val_tp: 550.0000 - val_fp: 30.0000 - val_tn: 1246.0000 - val_fn: 56.0000 - val_accuracy: 0.9543 - val_precision: 0.9483 - val_recall: 0.9076 - val_auc: 0.9903 - val_prc: 0.9846 - lr: 0.0010
# Epoch 4/10
# 40/40 [==============================] - 45s 1s/step - loss: 0.1441 - tp: 773.0000 - fp: 228.0000 - tn: 1463.0000 - fn: 71.0000 - accuracy: 0.8821 - precision: 0.7722 - recall: 0.9159 - auc: 0.9627 - prc: 0.9412 - val_loss: 0.1092 - val_tp: 560.0000 - val_fp: 52.0000 - val_tn: 1224.0000 - val_fn: 46.0000 - val_accuracy: 0.9479 - val_precision: 0.9150 - val_recall: 0.9241 - val_auc: 0.9916 - val_prc: 0.9854 - lr: 0.0010
# Epoch 5/10
# 40/40 [==============================] - 44s 1s/step - loss: 0.1005 - tp: 785.0000 - fp: 168.0000 - tn: 1523.0000 - fn: 59.0000 - accuracy: 0.9105 - precision: 0.8237 - recall: 0.9301 - auc: 0.9771 - prc: 0.9581 - val_loss: 0.1094 - val_tp: 583.0000 - val_fp: 66.0000 - val_tn: 1210.0000 - val_fn: 23.0000 - val_accuracy: 0.9527 - val_precision: 0.8983 - val_recall: 0.9620 - val_auc: 0.9939 - val_prc: 0.9882 - lr: 0.0010
# Epoch 6/10
# 40/40 [==============================] - 45s 1s/step - loss: 0.0644 - tp: 802.0000 - fp: 116.0000 - tn: 1575.0000 - fn: 42.0000 - accuracy: 0.9377 - precision: 0.8736 - recall: 0.9502 - auc: 0.9899 - prc: 0.9825 - val_loss: 0.1952 - val_tp: 602.0000 - val_fp: 131.0000 - val_tn: 1145.0000 - val_fn: 4.0000 - val_accuracy: 0.9283 - val_precision: 0.8213 - val_recall: 0.9934 - val_auc: 0.9949 - val_prc: 0.9900 - lr: 0.0010
# Epoch 7/10
# 40/40 [==============================] - 44s 1s/step - loss: 0.0664 - tp: 816.0000 - fp: 142.0000 - tn: 1549.0000 - fn: 28.0000 - accuracy: 0.9329 - precision: 0.8518 - recall: 0.9668 - auc: 0.9887 - prc: 0.9750 - val_loss: 0.0835 - val_tp: 579.0000 - val_fp: 42.0000 - val_tn: 1234.0000 - val_fn: 27.0000 - val_accuracy: 0.9633 - val_precision: 0.9324 - val_recall: 0.9554 - val_auc: 0.9954 - val_prc: 0.9908 - lr: 0.0010
# Epoch 8/10
# 40/40 [==============================] - 44s 1s/step - loss: 0.0691 - tp: 793.0000 - fp: 104.0000 - tn: 1587.0000 - fn: 51.0000 - accuracy: 0.9389 - precision: 0.8841 - recall: 0.9396 - auc: 0.9880 - prc: 0.9768 - val_loss: 0.1546 - val_tp: 602.0000 - val_fp: 105.0000 - val_tn: 1171.0000 - val_fn: 4.0000 - val_accuracy: 0.9421 - val_precision: 0.8515 - val_recall: 0.9934 - val_auc: 0.9946 - val_prc: 0.9863 - lr: 0.0010
# Epoch 9/10
# 40/40 [==============================] - 45s 1s/step - loss: 0.0726 - tp: 814.0000 - fp: 150.0000 - tn: 1541.0000 - fn: 30.0000 - accuracy: 0.9290 - precision: 0.8444 - recall: 0.9645 - auc: 0.9872 - prc: 0.9772 - val_loss: 0.0782 - val_tp: 568.0000 - val_fp: 32.0000 - val_tn: 1244.0000 - val_fn: 38.0000 - val_accuracy: 0.9628 - val_precision: 0.9467 - val_recall: 0.9373 - val_auc: 0.9957 - val_prc: 0.9915 - lr: 0.0010
# Epoch 10/10
# 19/40 [=============>................] - ETA: 18s - loss: 0.0821 - tp: 309.0000 - fp: 78.0000 - tn: 781.0000 - fn: 23.0000 - accuracy: 0.9152 - precision: 0.7984 - recall: 0.9307 - auc: 0.9822 - prc: 0.9585

# %%
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
# Out:
# Evaluation of test Data Generator:
# \n
# 29/29 [==============================] - 28s 993ms/step - loss: 0.1825 - tp: 585.0000 - fp: 121.0000 - tn: 1138.0000 - fn: 5.0000 - accuracy: 0.9319 - precision: 0.8286 - recall: 0.9915 - auc: 0.9934 - prc: 0.9832
# [0.18249055743217468,
#  585.0,
#  121.0,
#  1138.0,
#  5.0,
#  0.9318550825119019,
#  0.8286119103431702,
#  0.991525411605835,
#  0.9934451580047607,
#  0.9832020998001099]

# %%
base_model.trainable = True
# for layer in base_model.layers[:fine_tune_limit]:
#     layer.trainable=False
    
model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# ===================================
# Total params: 20,550,721.0
# Trainable params: 20,550,721
# Non-trainable params: 0.0
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 20,550,721
# Trainable params: 20,550,721
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Fine Tuning 8 epcohs

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_8,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning_8'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'VGG19_approach2'
fine_tuning = 'tuning_8epochs'
keypoints_added = 'without_keypoints'

plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_8, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_8)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))

# %% [markdown]
# ### Fine Tuning 40

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune2 = model.fit(train_generator,
                              epochs=epochs_30,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'VGG19_approach2'
fine_tuning = 'tuning_40epochs'
keypoints_added = 'without_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_30, batch_size, history_after_tune2)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_30)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/40
# 40/40 [==============================] - 54s 1s/step - loss: 0.0238 - tp: 834.0000 - fp: 42.0000 - tn: 1649.0000 - fn: 10.0000 - accuracy: 0.9795 - precision: 0.9521 - recall: 0.9882 - auc: 0.9980 - prc: 0.9946 - val_loss: 0.0636 - val_tp: 594.0000 - val_fp: 36.0000 - val_tn: 1240.0000 - val_fn: 12.0000 - val_accuracy: 0.9745 - val_precision: 0.9429 - val_recall: 0.9802 - val_auc: 0.9978 - val_prc: 0.9945
# Epoch 2/40
# 40/40 [==============================] - 54s 1s/step - loss: 0.0222 - tp: 836.0000 - fp: 37.0000 - tn: 1654.0000 - fn: 8.0000 - accuracy: 0.9822 - precision: 0.9576 - recall: 0.9905 - auc: 0.9986 - prc: 0.9972 - val_loss: 0.0523 - val_tp: 587.0000 - val_fp: 19.0000 - val_tn: 1257.0000 - val_fn: 19.0000 - val_accuracy: 0.9798 - val_precision: 0.9686 - val_recall: 0.9686 - val_auc: 0.9980 - val_prc: 0.9961
# Epoch 3/40
# 40/40 [==============================] - 54s 1s/step - loss: 0.0154 - tp: 839.0000 - fp: 34.0000 - tn: 1657.0000 - fn: 5.0000 - accuracy: 0.9846 - precision: 0.9611 - recall: 0.9941 - auc: 0.9992 - prc: 0.9977 - val_loss: 0.0553 - val_tp: 583.0000 - val_fp: 15.0000 - val_tn: 1261.0000 - val_fn: 23.0000 - val_accuracy: 0.9798 - val_precision: 0.9749 - val_recall: 0.9620 - val_auc: 0.9965 - val_prc: 0.9949
# Epoch 4/40
# 40/40 [==============================] - 54s 1s/step - loss: 0.0260 - tp: 832.0000 - fp: 47.0000 - tn: 1644.0000 - fn: 12.0000 - accuracy: 0.9767 - precision: 0.9465 - recall: 0.9858 - auc: 0.9976 - prc: 0.9932 - val_loss: 0.0680 - val_tp: 598.0000 - val_fp: 37.0000 - val_tn: 1239.0000 - val_fn: 8.0000 - val_accuracy: 0.9761 - val_precision: 0.9417 - val_recall: 0.9868 - val_auc: 0.9978 - val_prc: 0.9946
# Epoch 5/40
# 40/40 [==============================] - 54s 1s/step - loss: 0.0167 - tp: 838.0000 - fp: 29.0000 - tn: 1662.0000 - fn: 6.0000 - accuracy: 0.9862 - precision: 0.9666 - recall: 0.9929 - auc: 0.9993 - prc: 0.9986 - val_loss: 0.1039 - val_tp: 601.0000 - val_fp: 53.0000 - val_tn: 1223.0000 - val_fn: 5.0000 - val_accuracy: 0.9692 - val_precision: 0.9190 - val_recall: 0.9917 - val_auc: 0.9956 - val_prc: 0.9849
# Epoch 6/40
# 40/40 [==============================] - 53s 1s/step - loss: 0.0151 - tp: 838.0000 - fp: 24.0000 - tn: 1667.0000 - fn: 6.0000 - accuracy: 0.9882 - precision: 0.9722 - recall: 0.9929 - auc: 0.9994 - prc: 0.9987 - val_loss: 0.1416 - val_tp: 601.0000 - val_fp: 66.0000 - val_tn: 1210.0000 - val_fn: 5.0000 - val_accuracy: 0.9623 - val_precision: 0.9010 - val_recall: 0.9917 - val_auc: 0.9938 - val_prc: 0.9773
# Epoch 7/40
# 40/40 [==============================] - 54s 1s/step - loss: 0.0162 - tp: 840.0000 - fp: 35.0000 - tn: 1656.0000 - fn: 4.0000 - accuracy: 0.9846 - precision: 0.9600 - recall: 0.9953 - auc: 0.9991 - prc: 0.9975 - val_loss: 0.1058 - val_tp: 601.0000 - val_fp: 48.0000 - val_tn: 1228.0000 - val_fn: 5.0000 - val_accuracy: 0.9718 - val_precision: 0.9260 - val_recall: 0.9917 - val_auc: 0.9956 - val_prc: 0.9841
# Epoch 8/40
# 40/40 [==============================] - 54s 1s/step - loss: 0.0159 - tp: 839.0000 - fp: 29.0000 - tn: 1662.0000 - fn: 5.0000 - accuracy: 0.9866 - precision: 0.9666 - recall: 0.9941 - auc: 0.9991 - prc: 0.9975 - val_loss: 0.0618 - val_tp: 594.0000 - val_fp: 31.0000 - val_tn: 1245.0000 - val_fn: 12.0000 - val_accuracy: 0.9772 - val_precision: 0.9504 - val_recall: 0.9802 - val_auc: 0.9969 - val_prc: 0.9900
#
#
# Evaluation of test Data Generator:
# \n
# 29/29 [==============================] - 9s 296ms/step - loss: 0.0559 - tp: 578.0000 - fp: 25.0000 - tn: 1234.0000 - fn: 12.0000 - accuracy: 0.9800 - precision: 0.9585 - recall: 0.9797 - auc: 0.9981 - prc: 0.9952

# %% [markdown]
# ## With Pose Estimation

# %%
train_generator = train_generator_with_preprocessing_2
val_generator = val_generator_with_preprocessing_2
test_generator = test_generator_with_preprocessing_2
preprocess_fn = vgg19_preprocess
neurons_final = 1024
base_model = create_base_VGG19()
fine_tune_limit = len(base_model.layers) - int(0.1 * len(base_model.layers))-1
model_name= 'VGG19_AllUnfreeze'
fine_tuning = 'before_tuning'
keypoints_added = 'without_keypoints'

epochs_1 = 10
epochs_fine_tuning = 20
epcohs_8 = 8
epochs_40 = 40
lr_1 = 1e-3
lr_2 = 1e-5
print("Done")
##########################################################################
base_model.trainable = False
inputs = Input(shape=(224,224,3))
x = preprocess_fn(inputs) 
#Run base model in Inference mode by passing training=false,This is important for fine-tuning.
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(neurons_final, activation='relu')(x)
x = Dropout(0.5)(x)
outputs =  Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)
print("Model Summary: " , model.summary())
# Out:
# Done
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1024)              525312
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 20,550,721
# Trainable params: 526,337
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Model Summary:  None

# %%
#Load weights
# model.load_weights('/kaggle/input/vgg19-before-tuning/BeforeFineTuning/VGG19__with_keypoints__before_tuning__10epcohs__64batch.h5')

#Train dense layers
base_model.trainable = False
#Train dense layers:
call_backs = [EarlyStopping(monitor='val_loss', patience=6),
              ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)]

model.compile(optimizer=Adam(learning_rate=lr_1), loss= 'binary_crossentropy', metrics=METRICS)

steps_per_epoch = train_generator.n // batch_size  
validation_steps = val_generator.n // batch_size
print("Training Started\n")   
#############################################################################
history = model.fit(train_generator,
                    epochs=epochs_1,
                    callbacks=call_backs,
                    validation_data=val_generator,
                    class_weight=class_weight)
print("Training Finished\n") 
###############################################################################
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
################################################################################################################
model_name= 'VGG19_approach2'
fine_tuning = 'before_tuning'
keypoints_added = 'with_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_1, batch_size, history)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_1)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
saved_model_before_wihoutKPts_path = '/kaggle/working/{}.h5'.format(name)
print(saved_model_before_wihoutKPts_path)
# Out:
# Training Started
#
# Epoch 1/10
# 40/40 [==============================] - 139s 3s/step - loss: 1.3355 - tp: 1218.0000 - fp: 629.0000 - tn: 2321.0000 - fn: 216.0000 - accuracy: 0.8073 - precision: 0.6594 - recall: 0.8494 - auc: 0.8673 - prc: 0.7091 - val_loss: 0.2729 - val_tp: 547.0000 - val_fp: 160.0000 - val_tn: 1116.0000 - val_fn: 59.0000 - val_accuracy: 0.8836 - val_precision: 0.7737 - val_recall: 0.9026 - val_auc: 0.9676 - val_prc: 0.9471 - lr: 0.0010
# Epoch 2/10
# 40/40 [==============================] - 136s 3s/step - loss: 0.2019 - tp: 738.0000 - fp: 343.0000 - tn: 1348.0000 - fn: 106.0000 - accuracy: 0.8229 - precision: 0.6827 - recall: 0.8744 - auc: 0.9281 - prc: 0.8982 - val_loss: 0.1703 - val_tp: 501.0000 - val_fp: 27.0000 - val_tn: 1249.0000 - val_fn: 105.0000 - val_accuracy: 0.9299 - val_precision: 0.9489 - val_recall: 0.8267 - val_auc: 0.9770 - val_prc: 0.9639 - lr: 0.0010
# Epoch 3/10
# 40/40 [==============================] - 167s 4s/step - loss: 0.1330 - tp: 765.0000 - fp: 223.0000 - tn: 1468.0000 - fn: 79.0000 - accuracy: 0.8809 - precision: 0.7743 - recall: 0.9064 - auc: 0.9567 - prc: 0.9398 - val_loss: 0.1913 - val_tp: 579.0000 - val_fp: 123.0000 - val_tn: 1153.0000 - val_fn: 27.0000 - val_accuracy: 0.9203 - val_precision: 0.8248 - val_recall: 0.9554 - val_auc: 0.9862 - val_prc: 0.9769 - lr: 0.0010
# Epoch 5/10
# 40/40 [==============================] - 135s 3s/step - loss: 0.1161 - tp: 784.0000 - fp: 248.0000 - tn: 1443.0000 - fn: 60.0000 - accuracy: 0.8785 - precision: 0.7597 - recall: 0.9289 - auc: 0.9666 - prc: 0.9510 - val_loss: 0.1453 - val_tp: 562.0000 - val_fp: 65.0000 - val_tn: 1211.0000 - val_fn: 44.0000 - val_accuracy: 0.9421 - val_precision: 0.8963 - val_recall: 0.9274 - val_auc: 0.9875 - val_prc: 0.9785 - lr: 0.0010
# Epoch 6/10
# 40/40 [==============================] - 135s 3s/step - loss: 0.1217 - tp: 746.0000 - fp: 184.0000 - tn: 1507.0000 - fn: 98.0000 - accuracy: 0.8888 - precision: 0.8022 - recall: 0.8839 - auc: 0.9627 - prc: 0.9458 - val_loss: 0.1394 - val_tp: 554.0000 - val_fp: 58.0000 - val_tn: 1218.0000 - val_fn: 52.0000 - val_accuracy: 0.9416 - val_precision: 0.9052 - val_recall: 0.9142 - val_auc: 0.9886 - val_prc: 0.9800 - lr: 0.0010
# Epoch 7/10
# 40/40 [==============================] - 134s 3s/step - loss: 0.0961 - tp: 800.0000 - fp: 203.0000 - tn: 1488.0000 - fn: 44.0000 - accuracy: 0.9026 - precision: 0.7976 - recall: 0.9479 - auc: 0.9767 - prc: 0.9640 - val_loss: 0.1385 - val_tp: 561.0000 - val_fp: 59.0000 - val_tn: 1217.0000 - val_fn: 45.0000 - val_accuracy: 0.9447 - val_precision: 0.9048 - val_recall: 0.9257 - val_auc: 0.9888 - val_prc: 0.9803 - lr: 0.0010
# Epoch 8/10
# 40/40 [==============================] - 132s 3s/step - loss: 0.0926 - tp: 785.0000 - fp: 182.0000 - tn: 1509.0000 - fn: 59.0000 - accuracy: 0.9049 - precision: 0.8118 - recall: 0.9301 - auc: 0.9780 - prc: 0.9652 - val_loss: 0.1418 - val_tp: 501.0000 - val_fp: 4.0000 - val_tn: 1272.0000 - val_fn: 105.0000 - val_accuracy: 0.9421 - val_precision: 0.9921 - val_recall: 0.8267 - val_auc: 0.9874 - val_prc: 0.9785 - lr: 0.0010
# Epoch 9/10
# 40/40 [==============================] - 131s 3s/step - loss: 0.1103 - tp: 749.0000 - fp: 164.0000 - tn: 1527.0000 - fn: 95.0000 - accuracy: 0.8978 - precision: 0.8204 - recall: 0.8874 - auc: 0.9684 - prc: 0.9543 - val_loss: 0.2111 - val_tp: 594.0000 - val_fp: 170.0000 - val_tn: 1106.0000 - val_fn: 12.0000 - val_accuracy: 0.9033 - val_precision: 0.7775 - val_recall: 0.9802 - val_auc: 0.9902 - val_prc: 0.9825 - lr: 0.0010
# Epoch 10/10
# 40/40 [==============================] - 132s 3s/step - loss: 0.0993 - tp: 792.0000 - fp: 219.0000 - tn: 1472.0000 - fn: 52.0000 - accuracy: 0.8931 - precision: 0.7834 - recall: 0.9384 - auc: 0.9752 - prc: 0.9636 - val_loss: 0.1509 - val_tp: 582.0000 - val_fp: 88.0000 - val_tn: 1188.0000 - val_fn: 24.0000 - val_accuracy: 0.9405 - val_precision: 0.8687 - val_recall: 0.9604 - val_auc: 0.9914 - val_prc: 0.9842 - lr: 0.0010
# Training Finished
#
#
#
# Evaluation of test Data Generator:
# \n
# 29/29 [==============================] - 47s 2s/step - loss: 0.1544 - tp: 573.0000 - fp: 89.0000 - tn: 1170.0000 - fn: 17.0000 - accuracy: 0.9427 - precision: 0.8656 - recall: 0.9712 - auc: 0.9923 - prc: 0.9857
# /kaggle/working/VGG19_approach2_with_keypoints_before_tuning_10epochs.h5

# %%
base_model.trainable = True
# for layer in base_model.layers[:fine_tune_limit]:
#     layer.trainable=False
    
model.compile(optimizer=Adam(learning_rate=lr_2),loss= 'binary_crossentropy',metrics=METRICS)
print('===================================')
print_parameters_count(model)
print(model.summary())
# Out:
# ===================================
# Total params: 20,550,721.0
# Trainable params: 20,550,721
# Non-trainable params: 0.0
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1024)              525312
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 20,550,721
# Trainable params: 20,550,721
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Fine Tuning 8 epochs

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune = model.fit(train_generator,
                              epochs=epochs_8,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning_8'
###########################################################################################################
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)

################################################################################################################
model_name= 'VGG19_approach2'
fine_tuning = 'tuning_8epochs'
keypoints_added = 'with_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_8, batch_size, history_after_tune)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_8)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
# Out:
# Epoch 1/8
# 40/40 [==============================] - 162s 4s/step - loss: 0.0912 - tp: 1351.0000 - fp: 255.0000 - tn: 2695.0000 - fn: 83.0000 - accuracy: 0.9229 - precision: 0.8412 - recall: 0.9421 - auc: 0.9842 - prc: 0.9725 - val_loss: 0.1488 - val_tp: 595.0000 - val_fp: 114.0000 - val_tn: 1162.0000 - val_fn: 11.0000 - val_accuracy: 0.9336 - val_precision: 0.8392 - val_recall: 0.9818 - val_auc: 0.9938 - val_prc: 0.9870
# Epoch 2/8
# 31/40 [======================>.......] - ETA: 25s - loss: 0.0936 - tp: 552.0000 - fp: 162.0000 - tn: 1209.0000 - fn: 36.0000 - accuracy: 0.8989 - precision: 0.7731 - recall: 0.9388 - auc: 0.9771 - prc: 0.9599Epoch 3/8
# 40/40 [==============================] - 157s 4s/step - loss: 0.0544 - tp: 821.0000 - fp: 103.0000 - tn: 1588.0000 - fn: 23.0000 - accuracy: 0.9503 - precision: 0.8885 - recall: 0.9727 - auc: 0.9925 - prc: 0.9859 - val_loss: 0.0792 - val_tp: 554.0000 - val_fp: 16.0000 - val_tn: 1260.0000 - val_fn: 52.0000 - val_accuracy: 0.9639 - val_precision: 0.9719 - val_recall: 0.9142 - val_auc: 0.9958 - val_prc: 0.9920
# Epoch 4/8
# 40/40 [==============================] - 157s 4s/step - loss: 0.0452 - tp: 822.0000 - fp: 85.0000 - tn: 1606.0000 - fn: 22.0000 - accuracy: 0.9578 - precision: 0.9063 - recall: 0.9739 - auc: 0.9950 - prc: 0.9911 - val_loss: 0.0799 - val_tp: 598.0000 - val_fp: 48.0000 - val_tn: 1228.0000 - val_fn: 8.0000 - val_accuracy: 0.9702 - val_precision: 0.9257 - val_recall: 0.9868 - val_auc: 0.9972 - val_prc: 0.9945
# Epoch 5/8
# 40/40 [==============================] - 157s 4s/step - loss: 0.0517 - tp: 810.0000 - fp: 87.0000 - tn: 1604.0000 - fn: 34.0000 - accuracy: 0.9523 - precision: 0.9030 - recall: 0.9597 - auc: 0.9932 - prc: 0.9865 - val_loss: 0.1224 - val_tp: 604.0000 - val_fp: 99.0000 - val_tn: 1177.0000 - val_fn: 2.0000 - val_accuracy: 0.9463 - val_precision: 0.8592 - val_recall: 0.9967 - val_auc: 0.9971 - val_prc: 0.9932
# Epoch 6/8
# 40/40 [==============================] - 156s 4s/step - loss: 0.0389 - tp: 823.0000 - fp: 76.0000 - tn: 1615.0000 - fn: 21.0000 - accuracy: 0.9617 - precision: 0.9155 - recall: 0.9751 - auc: 0.9956 - prc: 0.9895 - val_loss: 0.0656 - val_tp: 593.0000 - val_fp: 36.0000 - val_tn: 1240.0000 - val_fn: 13.0000 - val_accuracy: 0.9740 - val_precision: 0.9428 - val_recall: 0.9785 - val_auc: 0.9969 - val_prc: 0.9949
# Epoch 7/8
# 40/40 [==============================] - 157s 4s/step - loss: 0.0415 - tp: 822.0000 - fp: 78.0000 - tn: 1613.0000 - fn: 22.0000 - accuracy: 0.9606 - precision: 0.9133 - recall: 0.9739 - auc: 0.9954 - prc: 0.9902 - val_loss: 0.0598 - val_tp: 592.0000 - val_fp: 29.0000 - val_tn: 1247.0000 - val_fn: 14.0000 - val_accuracy: 0.9772 - val_precision: 0.9533 - val_recall: 0.9769 - val_auc: 0.9972 - val_prc: 0.9956
# Epoch 8/8
# 40/40 [==============================] - 157s 4s/step - loss: 0.0374 - tp: 822.0000 - fp: 68.0000 - tn: 1623.0000 - fn: 22.0000 - accuracy: 0.9645 - precision: 0.9236 - recall: 0.9739 - auc: 0.9963 - prc: 0.9924 - val_loss: 0.0748 - val_tp: 598.0000 - val_fp: 46.0000 - val_tn: 1230.0000 - val_fn: 8.0000 - val_accuracy: 0.9713 - val_precision: 0.9286 - val_recall: 0.9868 - val_auc: 0.9972 - val_prc: 0.9926
#
#
# Evaluation of test Data Generator:
# \n
# 29/29 [==============================] - 47s 2s/step - loss: 0.0859 - tp: 583.0000 - fp: 40.0000 - tn: 1219.0000 - fn: 7.0000 - accuracy: 0.9746 - precision: 0.9358 - recall: 0.9881 - auc: 0.9957 - prc: 0.9906

# %% [markdown]
# ### Fine Tuning 40

# %%
call_backs_2 = [EarlyStopping(monitor='val_loss',patience=6)]
history_after_tune2 = model.fit(train_generator,
                              epochs=epochs_30,
                              callbacks=call_backs_2 ,
                              validation_data=val_generator,
                              class_weight=class_weight)
fine_tuning = 'after_tuning_32'
###########################################################################################################

################################################################################################################
model_name= 'VGG19_approach2'
fine_tuning = 'tuning_40epochs'
keypoints_added = 'without_keypoints'
plot_save_results(model, model_name, fine_tuning, keypoints_added, epochs_30, batch_size, history_after_tune2)

path ='/kaggle/working/{}'.format(model_name)
name = model_name+'_'+keypoints_added+'_'+fine_tuning+'_'+str(epochs_30)+'epochs'
zip_delete(name, path)

#plot_save_results(model,model_name,fine_tuning,keypoints_added,epochs_1,batch_size,history)
model.save('/kaggle/working/{}.h5'.format(name))
print("Training Finished")
# Out:
# Epoch 1/32
# 40/40 [==============================] - 158s 4s/step - loss: 0.0391 - tp: 826.0000 - fp: 78.0000 - tn: 1613.0000 - fn: 18.0000 - accuracy: 0.9621 - precision: 0.9137 - recall: 0.9787 - auc: 0.9955 - prc: 0.9899 - val_loss: 0.0643 - val_tp: 566.0000 - val_fp: 13.0000 - val_tn: 1263.0000 - val_fn: 40.0000 - val_accuracy: 0.9718 - val_precision: 0.9775 - val_recall: 0.9340 - val_auc: 0.9974 - val_prc: 0.9950
# Epoch 2/32
# 40/40 [==============================] - 156s 4s/step - loss: 0.0337 - tp: 825.0000 - fp: 54.0000 - tn: 1637.0000 - fn: 19.0000 - accuracy: 0.9712 - precision: 0.9386 - recall: 0.9775 - auc: 0.9964 - prc: 0.9913 - val_loss: 0.0608 - val_tp: 585.0000 - val_fp: 21.0000 - val_tn: 1255.0000 - val_fn: 21.0000 - val_accuracy: 0.9777 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9971 - val_prc: 0.9953
# Epoch 3/32
# 40/40 [==============================] - 156s 4s/step - loss: 0.0339 - tp: 829.0000 - fp: 57.0000 - tn: 1634.0000 - fn: 15.0000 - accuracy: 0.9716 - precision: 0.9357 - recall: 0.9822 - auc: 0.9965 - prc: 0.9922 - val_loss: 0.0801 - val_tp: 602.0000 - val_fp: 51.0000 - val_tn: 1225.0000 - val_fn: 4.0000 - val_accuracy: 0.9708 - val_precision: 0.9219 - val_recall: 0.9934 - val_auc: 0.9974 - val_prc: 0.9960
# Epoch 4/32
# 40/40 [==============================] - 156s 4s/step - loss: 0.0364 - tp: 830.0000 - fp: 70.0000 - tn: 1621.0000 - fn: 14.0000 - accuracy: 0.9669 - precision: 0.9222 - recall: 0.9834 - auc: 0.9965 - prc: 0.9927 - val_loss: 0.0958 - val_tp: 601.0000 - val_fp: 69.0000 - val_tn: 1207.0000 - val_fn: 5.0000 - val_accuracy: 0.9607 - val_precision: 0.8970 - val_recall: 0.9917 - val_auc: 0.9960 - val_prc: 0.9895
# Epoch 5/32
# 40/40 [==============================] - 158s 4s/step - loss: 0.0297 - tp: 835.0000 - fp: 50.0000 - tn: 1641.0000 - fn: 9.0000 - accuracy: 0.9767 - precision: 0.9435 - recall: 0.9893 - auc: 0.9971 - prc: 0.9929 - val_loss: 0.0621 - val_tp: 596.0000 - val_fp: 33.0000 - val_tn: 1243.0000 - val_fn: 10.0000 - val_accuracy: 0.9772 - val_precision: 0.9475 - val_recall: 0.9835 - val_auc: 0.9975 - val_prc: 0.9961
# Epoch 6/32
# 40/40 [==============================] - 155s 4s/step - loss: 0.0255 - tp: 837.0000 - fp: 56.0000 - tn: 1635.0000 - fn: 7.0000 - accuracy: 0.9751 - precision: 0.9373 - recall: 0.9917 - auc: 0.9981 - prc: 0.9956 - val_loss: 0.0595 - val_tp: 558.0000 - val_fp: 8.0000 - val_tn: 1268.0000 - val_fn: 48.0000 - val_accuracy: 0.9702 - val_precision: 0.9859 - val_recall: 0.9208 - val_auc: 0.9977 - val_prc: 0.9963
# Epoch 7/32
# 40/40 [==============================] - 160s 4s/step - loss: 0.0451 - tp: 820.0000 - fp: 92.0000 - tn: 1599.0000 - fn: 24.0000 - accuracy: 0.9542 - precision: 0.8991 - recall: 0.9716 - auc: 0.9947 - prc: 0.9895 - val_loss: 0.0667 - val_tp: 602.0000 - val_fp: 39.0000 - val_tn: 1237.0000 - val_fn: 4.0000 - val_accuracy: 0.9772 - val_precision: 0.9392 - val_recall: 0.9934 - val_auc: 0.9981 - val_prc: 0.9953
# Epoch 8/32
# 40/40 [==============================] - 159s 4s/step - loss: 0.0288 - tp: 829.0000 - fp: 43.0000 - tn: 1648.0000 - fn: 15.0000 - accuracy: 0.9771 - precision: 0.9507 - recall: 0.9822 - auc: 0.9969 - prc: 0.9914 - val_loss: 0.0501 - val_tp: 589.0000 - val_fp: 20.0000 - val_tn: 1256.0000 - val_fn: 17.0000 - val_accuracy: 0.9803 - val_precision: 0.9672 - val_recall: 0.9719 - val_auc: 0.9979 - val_prc: 0.9966
# Epoch 9/32
# 40/40 [==============================] - 159s 4s/step - loss: 0.0210 - tp: 837.0000 - fp: 38.0000 - tn: 1653.0000 - fn: 7.0000 - accuracy: 0.9822 - precision: 0.9566 - recall: 0.9917 - auc: 0.9987 - prc: 0.9967 - val_loss: 0.0724 - val_tp: 600.0000 - val_fp: 39.0000 - val_tn: 1237.0000 - val_fn: 6.0000 - val_accuracy: 0.9761 - val_precision: 0.9390 - val_recall: 0.9901 - val_auc: 0.9962 - val_prc: 0.9887
# Epoch 10/32
# 40/40 [==============================] - 160s 4s/step - loss: 0.0224 - tp: 836.0000 - fp: 43.0000 - tn: 1648.0000 - fn: 8.0000 - accuracy: 0.9799 - precision: 0.9511 - recall: 0.9905 - auc: 0.9983 - prc: 0.9953 - val_loss: 0.0563 - val_tp: 575.0000 - val_fp: 16.0000 - val_tn: 1260.0000 - val_fn: 31.0000 - val_accuracy: 0.9750 - val_precision: 0.9729 - val_recall: 0.9488 - val_auc: 0.9975 - val_prc: 0.9957
# Epoch 11/32
# 40/40 [==============================] - 157s 4s/step - loss: 0.0236 - tp: 834.0000 - fp: 34.0000 - tn: 1657.0000 - fn: 10.0000 - accuracy: 0.9826 - precision: 0.9608 - recall: 0.9882 - auc: 0.9982 - prc: 0.9960 - val_loss: 0.0628 - val_tp: 604.0000 - val_fp: 37.0000 - val_tn: 1239.0000 - val_fn: 2.0000 - val_accuracy: 0.9793 - val_precision: 0.9423 - val_recall: 0.9967 - val_auc: 0.9973 - val_prc: 0.9937
# Epoch 12/32
# 40/40 [==============================] - 157s 4s/step - loss: 0.0188 - tp: 839.0000 - fp: 32.0000 - tn: 1659.0000 - fn: 5.0000 - accuracy: 0.9854 - precision: 0.9633 - recall: 0.9941 - auc: 0.9986 - prc: 0.9958 - val_loss: 0.0539 - val_tp: 590.0000 - val_fp: 20.0000 - val_tn: 1256.0000 - val_fn: 16.0000 - val_accuracy: 0.9809 - val_precision: 0.9672 - val_recall: 0.9736 - val_auc: 0.9971 - val_prc: 0.9933
# Epoch 13/32
# 40/40 [==============================] - 157s 4s/step - loss: 0.0177 - tp: 836.0000 - fp: 30.0000 - tn: 1661.0000 - fn: 8.0000 - accuracy: 0.9850 - precision: 0.9654 - recall: 0.9905 - auc: 0.9992 - prc: 0.9984 - val_loss: 0.1095 - val_tp: 603.0000 - val_fp: 71.0000 - val_tn: 1205.0000 - val_fn: 3.0000 - val_accuracy: 0.9607 - val_precision: 0.8947 - val_recall: 0.9950 - val_auc: 0.9958 - val_prc: 0.9872
# Epoch 14/32
# 40/40 [==============================] - ETA: 0s - loss: 0.0272 - tp: 834.0000 - fp: 47.0000 - tn: 1644.0000 - fn: 10.0000 - accuracy: 0.9775 - precision: 0.9467 - recall: 0.9882 - auc: 0.9972 - prc: 0.9939

# %%
print("\n\nEvaluation of test Data Generator:\n\\n")
# Evaluate the accuracy of the MobileNet_model on the test dataset using the `evaluate` method
test_generator.reset()
model.evaluate(test_generator)
print("Done")
# Out:
# Evaluation of test Data Generator:
# \n
# 29/29 [==============================] - 47s 2s/step - loss: 0.0740 - tp: 582.0000 - fp: 36.0000 - tn: 1223.0000 - fn: 8.0000 - accuracy: 0.9762 - precision: 0.9417 - recall: 0.9864 - auc: 0.9968 - prc: 0.9927
# Done
